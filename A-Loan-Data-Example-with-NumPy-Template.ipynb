# %% [markdown]
# ## Importación de paquetes

# %%
import os
import numpy as np
import pandas as pd
np.set_printoptions(
    suppress=True,
    linewidth=100,
    precision=2
)

# %% [markdown]
# ## Obtención de la ruta del script

# %%
os.getcwd()
# Out:
# 'c:\\Users\\ernesto.molina\\OneDrive - FUNKEN\\Documentos\\FKTrabajo\\Internos\\Curso Data Analyst\\S28 - A Loan Data Example with NumPy'

# %% [markdown]
# ## Importación de los datos

# %%
data_name = 'loan-data.csv' # Nombre del archivo que contiene los datos a procesar

# %%
raw_data_np = np.genfromtxt(data_name, delimiter=';', dtype='str')
raw_data_np[:10,:]
# Out:
# array([['id', 'issue_d', 'loan_amnt', 'loan_status', 'funded_amnt', 'term', 'int_rate',
#         'installment', 'grade', 'sub_grade', 'verification_status', 'url', 'addr_state',
#         'total_pymnt'],
#        ['48010226', 'May-15', '35000.0', 'Current', '35000.0', ' 36 months', '13.33', '1184.86',
#         'C', 'C3', 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226', 'CA', '9452.96'],
#        ['57693261', '', '30000.0', 'Current', '30000.0', ' 36 months', 'þëè.89', '938.57', 'A',
#         'A5', 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261', 'NY', '4679.7'],
#        ['59432726', 'Sep-15', '15000.0', 'Current', '15000.0', ' 36 months', 'íîå.53', '494.86',
#         'B', 'B5', 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726', 'PA', '1969.83'],
#        ['53222800', 'Jul-15', '9600.0', 'Current', '9600.0', ' 36 months', 'þëè.89', '300.35',
#         'A', 'A5', 'Not Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=53222800', 'OH', '1793.68'],
#        ['57803010', 'Aug-15', '8075.0', 'Current', '8075.0', ' 36 months', '19.19', '296.78', '',
#         'E3', 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57803010', 'TX', '1178.51'],
#        ['63398019', 'Oct-15', '14400.0', 'Current', '14400.0', ' 60 months', '13.99', '334.99',
#         '', 'C4', 'Not Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=63398019', 'AL', '681.17'],
#        ['60850626', 'Sep-15', '', 'Current', '13000.0', ' 60 months', '24.99', '381.5', 'F', 'F4',
#         'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=60850626', 'CA', '1126.45'],
#        ['46816139', 'Apr-15', '7500.0', 'Current', '7500.0', ' 36 months', '13.33', '253.9', 'C',
#         'C3', '', 'https://www.lendingclub.com/browse/loanDetail.action?loan_id=46816139', 'GA',
#         '2025.65'],
#        ['63918356', 'Nov-15', '8000.0', 'Current', '8000.0', ' 36 months', 'þëè.89', '250.29',
#         'A', 'A5', 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=63918356', 'MA', '497.07']],
#       dtype='<U69')

# %% [markdown]
# Los datos originales se encuentran organizados de la siguiente manera:
# - La primera fila del arreglo contiene las etiquetas que identifican cada una de las variables registradas en la base de datos.
# - Las filas subsecuentes contienen los datos asociados a cada instancia o registro. Cada registro debe contar con un identificador (ID) único que garantice su correcta diferenciación dentro del conjunto de datos.

# %%
raw_data_np = raw_data_np.transpose()
raw_data_np
# Out:
# array([['id', '48010226', '57693261', ..., '50415990', '46154151', '66055249'],
#        ['issue_d', 'May-15', '', ..., 'Jun-15', 'Apr-15', 'Dec-15'],
#        ['loan_amnt', '35000.0', '30000.0', ..., '10000.0', '', '10000.0'],
#        ...,
#        ['url', 'https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261', ...,
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249'],
#        ['addr_state', 'CA', 'NY', ..., 'CA', 'OH', 'IL'],
#        ['total_pymnt', '9452.96', '4679.7', ..., '2185.64', '3199.4', '301.9']],
#       shape=(14, 10001), dtype='<U69')

# %% [markdown]
# Los datos se reorganizan de manera que cada elemento del arreglo corresponda a una de las columnas del conjunto de datos original. Esta transformación se realiza con el propósito de facilitar la identificación y el análisis de posibles valores erróneos, inconsistentes o atípicos presentes en los registros.

# %% [markdown]
# ## Segmentación de los Datos Crudos por Categoría

# %%
raw_data_copy = raw_data_np.copy()
caracteristicas_data = {}
for i in range(len(raw_data_copy[:,1:])):
    valores_unicos = np.unique(raw_data_copy[i,1:], return_counts=True)
    contenedor_temporal = []
    dict_temporal = {}
    for j in range(0,(len(valores_unicos)),2):
        contenedor_temporal = (valores_unicos[j], valores_unicos[j+1])
        for k in range(len(contenedor_temporal[0])):
            dict_temporal[contenedor_temporal[0][k]] = contenedor_temporal[1][k]
    caracteristicas_data[raw_data_copy[i,0]] = dict_temporal
label_data = [key for key, _ in caracteristicas_data.items()]
label_data
# Out:
# [np.str_('id'),
#  np.str_('issue_d'),
#  np.str_('loan_amnt'),
#  np.str_('loan_status'),
#  np.str_('funded_amnt'),
#  np.str_('term'),
#  np.str_('int_rate'),
#  np.str_('installment'),
#  np.str_('grade'),
#  np.str_('sub_grade'),
#  np.str_('verification_status'),
#  np.str_('url'),
#  np.str_('addr_state'),
#  np.str_('total_pymnt')]

# %% [markdown]
# A partir de esta etapa se obtienen dos estructuras de datos:
# - label_data: Contiene las etiquetas asociadas a cada una de las columnas de la base de datos.
# - caracteristicas_data: Diccionario que resume las características de cada columna, incluyendo los valores únicos que la componen y la frecuencia de ocurrencia de cada uno de ellos. Esta información resulta útil para el análisis exploratorio de datos y la detección de posibles inconsistencias en los registros.

# %% [markdown]
# ## Exploración de los valores por categoría

# %% [markdown]
# ### Categoría 'id'

# %% [markdown]
# Esta categoría corresponde a los identificadores únicos asignados a cada registro de préstamo.
#
# Los valores contenidos en esta columna actúan como claves de identificación, garantizando la unicidad de cada observación dentro de la base de datos.

# %%
caracteristicas_data[label_data[0]]
# Out:
# {np.str_('12606806'): np.int64(1),
#  np.str_('13026045'): np.int64(1),
#  np.str_('1312426'): np.int64(1),
#  np.str_('14187903'): np.int64(1),
#  np.str_('14428496'): np.int64(1),
#  np.str_('14470171'): np.int64(1),
#  np.str_('14550531'): np.int64(1),
#  np.str_('14669896'): np.int64(1),
#  np.str_('15389420'): np.int64(1),
#  np.str_('16130931'): np.int64(1),
#  np.str_('19137119'): np.int64(1),
#  np.str_('19646726'): np.int64(1),
#  np.str_('22403153'): np.int64(1),
#  np.str_('25276117'): np.int64(1),
#  np.str_('31207716'): np.int64(1),
#  np.str_('31888135'): np.int64(1),
#  np.str_('34462110'): np.int64(1),
#  np.str_('34883768'): np.int64(1),
#  np.str_('35683282'): np.int64(1),
#  np.str_('36169417'): np.int64(1),
#  np.str_('36201871'): np.int64(1),
#  np.str_('36241014'): np.int64(1),
#  np.str_('36561402'): np.int64(1),
#  np.str_('36763239'): np.int64(1),
#  np.str_('36802496'): np.int64(1),
#  np.str_('36806601'): np.int64(1),
#  np.str_('36950419'): np.int64(1),
#  np.str_('37011266'): np.int64(1),
#  np.str_('37051229'): np.int64(1),
#  np.str_('37068509'): np.int64(1),
#  np.str_('37107114'): np.int64(1),
#  np.str_('37257668'): np.int64(1),
#  np.str_('37267742'): np.int64(1),
#  np.str_('37329129'): np.int64(1),
#  np.str_('373332'): np.int64(1),
#  np.str_('37600541'): np.int64(1),
#  np.str_('37601431'): np.int64(1),
#  np.str_('37612109'): np.int64(1),
#  np.str_('37612196'): np.int64(1),
#  np.str_('37620643'): np.int64(1),
#  np.str_('37621437'): np.int64(1),
#  np.str_('37621803'): np.int64(1),
#  np.str_('37640409'): np.int64(1),
#  np.str_('37641179'): np.int64(1),
#  np.str_('37641650'): np.int64(1),
#  np.str_('37651425'): np.int64(1),
#  np.str_('37652106'): np.int64(1),
#  np.str_('37671458'): np.int64(1),
#  np.str_('37671833'): np.int64(1),
#  np.str_('37672125'): np.int64(1),
#  np.str_('37680706'): np.int64(1),
#  np.str_('37680875'): np.int64(1),
#  np.str_('37691298'): np.int64(1),
#  np.str_('37691377'): np.int64(1),
#  np.str_('37691997'): np.int64(1),
#  np.str_('37692393'): np.int64(1),
#  np.str_('37700602'): np.int64(1),
#  np.str_('37730598'): np.int64(1),
#  np.str_('37731126'): np.int64(1),
#  np.str_('37750229'): np.int64(1),
#  np.str_('37750958'): np.int64(1),
#  np.str_('37751648'): np.int64(1),
#  np.str_('37752011'): np.int64(1),
#  np.str_('37811574'): np.int64(1),
#  np.str_('37811673'): np.int64(1),
#  np.str_('37821356'): np.int64(1),
#  np.str_('37841440'): np.int64(1),
#  np.str_('37866237'): np.int64(1),
#  np.str_('37866544'): np.int64(1),
#  np.str_('37887123'): np.int64(1),
#  np.str_('37887364'): np.int64(1),
#  np.str_('37907332'): np.int64(1),
#  np.str_('37917304'): np.int64(1),
#  np.str_('37927296'): np.int64(1),
#  np.str_('37927549'): np.int64(1),
#  np.str_('37938334'): np.int64(1),
#  np.str_('37948249'): np.int64(1),
#  np.str_('37948610'): np.int64(1),
#  np.str_('37958255'): np.int64(1),
#  np.str_('37978181'): np.int64(1),
#  np.str_('37998364'): np.int64(1),
#  np.str_('37998603'): np.int64(1),
#  np.str_('38018251'): np.int64(1),
#  np.str_('38028516'): np.int64(1),
#  np.str_('38058468'): np.int64(1),
#  np.str_('38078645'): np.int64(1),
#  np.str_('38098252'): np.int64(1),
#  np.str_('38108327'): np.int64(1),
#  np.str_('38141178'): np.int64(1),
#  np.str_('38141958'): np.int64(1),
#  np.str_('38151414'): np.int64(1),
#  np.str_('38151481'): np.int64(1),
#  np.str_('38151638'): np.int64(1),
#  np.str_('38162231'): np.int64(1),
#  np.str_('38162496'): np.int64(1),
#  np.str_('38171495'): np.int64(1),
#  np.str_('38171566'): np.int64(1),
#  np.str_('38171736'): np.int64(1),
#  np.str_('38171949'): np.int64(1),
#  np.str_('38171990'): np.int64(1),
#  np.str_('38172140'): np.int64(1),
#  np.str_('38181359'): np.int64(1),
#  np.str_('38182010'): np.int64(1),
#  np.str_('38191359'): np.int64(1),
#  np.str_('38201230'): np.int64(1),
#  np.str_('38211297'): np.int64(1),
#  np.str_('38211876'): np.int64(1),
#  np.str_('38212467'): np.int64(1),
#  np.str_('38212617'): np.int64(1),
#  np.str_('38212702'): np.int64(1),
#  np.str_('38221902'): np.int64(1),
#  np.str_('38232469'): np.int64(1),
#  np.str_('38242030'): np.int64(1),
#  np.str_('38242401'): np.int64(1),
#  np.str_('38261283'): np.int64(1),
#  np.str_('38261765'): np.int64(1),
#  np.str_('38272059'): np.int64(1),
#  np.str_('38272154'): np.int64(1),
#  np.str_('38281530'): np.int64(1),
#  np.str_('38282489'): np.int64(1),
#  np.str_('38291244'): np.int64(1),
#  np.str_('38301173'): np.int64(1),
#  np.str_('38311414'): np.int64(1),
#  np.str_('38311693'): np.int64(1),
#  np.str_('38312082'): np.int64(1),
#  np.str_('38312255'): np.int64(1),
#  np.str_('38321857'): np.int64(1),
#  np.str_('38341427'): np.int64(1),
#  np.str_('38342108'): np.int64(1),
#  np.str_('38342391'): np.int64(1),
#  np.str_('38342504'): np.int64(1),
#  np.str_('38362671'): np.int64(1),
#  np.str_('38382064'): np.int64(1),
#  np.str_('38413636'): np.int64(1),
#  np.str_('38413974'): np.int64(1),
#  np.str_('38414180'): np.int64(1),
#  np.str_('38414664'): np.int64(1),
#  np.str_('38414904'): np.int64(1),
#  np.str_('38415266'): np.int64(1),
#  np.str_('38415532'): np.int64(1),
#  np.str_('38416309'): np.int64(1),
#  np.str_('38417018'): np.int64(1),
#  np.str_('38417249'): np.int64(1),
#  np.str_('38417514'): np.int64(1),
#  np.str_('38417815'): np.int64(1),
#  np.str_('38419045'): np.int64(1),
#  np.str_('38425210'): np.int64(1),
#  np.str_('38426634'): np.int64(1),
#  np.str_('38426735'): np.int64(1),
#  np.str_('38426884'): np.int64(1),
#  np.str_('38427284'): np.int64(1),
#  np.str_('38427410'): np.int64(1),
#  np.str_('38427713'): np.int64(1),
#  np.str_('38428098'): np.int64(1),
#  np.str_('38428632'): np.int64(1),
#  np.str_('38428667'): np.int64(1),
#  np.str_('38429476'): np.int64(1),
#  np.str_('38429497'): np.int64(1),
#  np.str_('38429690'): np.int64(1),
#  np.str_('38434284'): np.int64(1),
#  np.str_('38434338'): np.int64(1),
#  np.str_('38434390'): np.int64(1),
#  np.str_('38434416'): np.int64(1),
#  np.str_('38434647'): np.int64(1),
#  np.str_('38435127'): np.int64(1),
#  np.str_('38435159'): np.int64(1),
#  np.str_('38435222'): np.int64(1),
#  np.str_('38435515'): np.int64(1),
#  np.str_('38435631'): np.int64(1),
#  np.str_('38436092'): np.int64(1),
#  np.str_('38436311'): np.int64(1),
#  np.str_('38436314'): np.int64(1),
#  np.str_('38436474'): np.int64(1),
#  np.str_('38436492'): np.int64(1),
#  np.str_('38436495'): np.int64(1),
#  np.str_('38437174'): np.int64(1),
#  np.str_('38437586'): np.int64(1),
#  np.str_('38439103'): np.int64(1),
#  np.str_('38439595'): np.int64(1),
#  np.str_('38439668'): np.int64(1),
#  np.str_('38439758'): np.int64(1),
#  np.str_('38439893'): np.int64(1),
#  np.str_('38444939'): np.int64(1),
#  np.str_('38445485'): np.int64(1),
#  np.str_('38445586'): np.int64(1),
#  np.str_('38446091'): np.int64(1),
#  np.str_('38446337'): np.int64(1),
#  np.str_('38447759'): np.int64(1),
#  np.str_('38448056'): np.int64(1),
#  np.str_('38448057'): np.int64(1),
#  np.str_('38448211'): np.int64(1),
#  np.str_('38448348'): np.int64(1),
#  np.str_('38449284'): np.int64(1),
#  np.str_('38449346'): np.int64(1),
#  np.str_('38449503'): np.int64(1),
#  np.str_('38450494'): np.int64(1),
#  np.str_('38454679'): np.int64(1),
#  np.str_('38455220'): np.int64(1),
#  np.str_('38455361'): np.int64(1),
#  np.str_('38455422'): np.int64(1),
#  np.str_('38455671'): np.int64(1),
#  np.str_('38455740'): np.int64(1),
#  np.str_('38456609'): np.int64(1),
#  np.str_('38456848'): np.int64(1),
#  np.str_('38456879'): np.int64(1),
#  np.str_('38457485'): np.int64(1),
#  np.str_('38457561'): np.int64(1),
#  np.str_('38457668'): np.int64(1),
#  np.str_('38458678'): np.int64(1),
#  np.str_('38458785'): np.int64(1),
#  np.str_('38459357'): np.int64(1),
#  np.str_('38459726'): np.int64(1),
#  np.str_('38459802'): np.int64(1),
#  np.str_('38464726'): np.int64(1),
#  np.str_('38465066'): np.int64(1),
#  np.str_('38465134'): np.int64(1),
#  np.str_('38465473'): np.int64(1),
#  np.str_('38465877'): np.int64(1),
#  np.str_('38467100'): np.int64(1),
#  np.str_('38467122'): np.int64(1),
#  np.str_('38467316'): np.int64(1),
#  np.str_('38467857'): np.int64(1),
#  np.str_('38468646'): np.int64(1),
#  np.str_('38469313'): np.int64(1),
#  np.str_('38469626'): np.int64(1),
#  np.str_('38470015'): np.int64(1),
#  np.str_('38474257'): np.int64(1),
#  np.str_('38474546'): np.int64(1),
#  np.str_('38476233'): np.int64(1),
#  np.str_('38476464'): np.int64(1),
#  np.str_('38477213'): np.int64(1),
#  np.str_('38477292'): np.int64(1),
#  np.str_('38477419'): np.int64(1),
#  np.str_('38477648'): np.int64(1),
#  np.str_('38477891'): np.int64(1),
#  np.str_('38478413'): np.int64(1),
#  np.str_('38478641'): np.int64(1),
#  np.str_('38479225'): np.int64(1),
#  np.str_('38479270'): np.int64(1),
#  np.str_('38479558'): np.int64(1),
#  np.str_('38479775'): np.int64(1),
#  np.str_('38480061'): np.int64(1),
#  np.str_('38480400'): np.int64(1),
#  np.str_('38484479'): np.int64(1),
#  np.str_('38484682'): np.int64(1),
#  np.str_('38485781'): np.int64(1),
#  np.str_('38494184'): np.int64(1),
#  np.str_('38494616'): np.int64(1),
#  np.str_('38495019'): np.int64(1),
#  np.str_('38495196'): np.int64(1),
#  np.str_('38495839'): np.int64(1),
#  np.str_('38496080'): np.int64(1),
#  np.str_('38496714'): np.int64(1),
#  np.str_('38497610'): np.int64(1),
#  np.str_('38497750'): np.int64(1),
#  np.str_('38498199'): np.int64(1),
#  np.str_('38498304'): np.int64(1),
#  np.str_('38498680'): np.int64(1),
#  np.str_('38500334'): np.int64(1),
#  np.str_('38504696'): np.int64(1),
#  np.str_('38504905'): np.int64(1),
#  np.str_('38505703'): np.int64(1),
#  np.str_('38505862'): np.int64(1),
#  np.str_('38506488'): np.int64(1),
#  np.str_('38506528'): np.int64(1),
#  np.str_('38507183'): np.int64(1),
#  np.str_('38507637'): np.int64(1),
#  np.str_('38508138'): np.int64(1),
#  np.str_('38508253'): np.int64(1),
#  np.str_('38508580'): np.int64(1),
#  np.str_('38509090'): np.int64(1),
#  np.str_('38509242'): np.int64(1),
#  np.str_('38509947'): np.int64(1),
#  np.str_('38515018'): np.int64(1),
#  np.str_('38515863'): np.int64(1),
#  np.str_('38516011'): np.int64(1),
#  np.str_('38516054'): np.int64(1),
#  np.str_('38517448'): np.int64(1),
#  np.str_('38518138'): np.int64(1),
#  np.str_('38518155'): np.int64(1),
#  np.str_('38518809'): np.int64(1),
#  np.str_('38519042'): np.int64(1),
#  np.str_('38519064'): np.int64(1),
#  np.str_('38519068'): np.int64(1),
#  np.str_('38519245'): np.int64(1),
#  np.str_('38519327'): np.int64(1),
#  np.str_('38519742'): np.int64(1),
#  np.str_('38519839'): np.int64(1),
#  np.str_('38520209'): np.int64(1),
#  np.str_('38524353'): np.int64(1),
#  np.str_('38524611'): np.int64(1),
#  np.str_('38525079'): np.int64(1),
#  np.str_('38525761'): np.int64(1),
#  np.str_('38525848'): np.int64(1),
#  np.str_('38526030'): np.int64(1),
#  np.str_('38526448'): np.int64(1),
#  np.str_('38527247'): np.int64(1),
#  np.str_('38527442'): np.int64(1),
#  np.str_('38528338'): np.int64(1),
#  np.str_('38528662'): np.int64(1),
#  np.str_('38529134'): np.int64(1),
#  np.str_('38529138'): np.int64(1),
#  np.str_('38534197'): np.int64(1),
#  np.str_('38534445'): np.int64(1),
#  np.str_('38534584'): np.int64(1),
#  np.str_('38534727'): np.int64(1),
#  np.str_('38534884'): np.int64(1),
#  np.str_('38535013'): np.int64(1),
#  np.str_('38535165'): np.int64(1),
#  np.str_('38535478'): np.int64(1),
#  np.str_('38535676'): np.int64(1),
#  np.str_('38536432'): np.int64(1),
#  np.str_('38537661'): np.int64(1),
#  np.str_('38537676'): np.int64(1),
#  np.str_('38538355'): np.int64(1),
#  np.str_('38544832'): np.int64(1),
#  np.str_('38545991'): np.int64(1),
#  np.str_('38546208'): np.int64(1),
#  np.str_('38546363'): np.int64(1),
#  np.str_('38548704'): np.int64(1),
#  np.str_('38549165'): np.int64(1),
#  np.str_('38550070'): np.int64(1),
#  np.str_('38554633'): np.int64(1),
#  np.str_('38554825'): np.int64(1),
#  np.str_('38555408'): np.int64(1),
#  np.str_('38555647'): np.int64(1),
#  np.str_('38556527'): np.int64(1),
#  np.str_('38557516'): np.int64(1),
#  np.str_('38557749'): np.int64(1),
#  np.str_('38558918'): np.int64(1),
#  np.str_('38559051'): np.int64(1),
#  np.str_('38559841'): np.int64(1),
#  np.str_('38559923'): np.int64(1),
#  np.str_('38559964'): np.int64(1),
#  np.str_('38559971'): np.int64(1),
#  np.str_('38560190'): np.int64(1),
#  np.str_('38560580'): np.int64(1),
#  np.str_('38565646'): np.int64(1),
#  np.str_('38565781'): np.int64(1),
#  np.str_('38566235'): np.int64(1),
#  np.str_('38568231'): np.int64(1),
#  np.str_('38568445'): np.int64(1),
#  np.str_('38568923'): np.int64(1),
#  np.str_('38574329'): np.int64(1),
#  np.str_('38574688'): np.int64(1),
#  np.str_('38575020'): np.int64(1),
#  np.str_('38575427'): np.int64(1),
#  np.str_('38575507'): np.int64(1),
#  np.str_('38575647'): np.int64(1),
#  np.str_('38576232'): np.int64(1),
#  np.str_('38576432'): np.int64(1),
#  np.str_('38578152'): np.int64(1),
#  np.str_('38578253'): np.int64(1),
#  np.str_('38578316'): np.int64(1),
#  np.str_('38578335'): np.int64(1),
#  np.str_('38578771'): np.int64(1),
#  np.str_('38578931'): np.int64(1),
#  np.str_('38579491'): np.int64(1),
#  np.str_('38579703'): np.int64(1),
#  np.str_('38580404'): np.int64(1),
#  np.str_('38584625'): np.int64(1),
#  np.str_('38585064'): np.int64(1),
#  np.str_('38585277'): np.int64(1),
#  np.str_('38586210'): np.int64(1),
#  np.str_('38586639'): np.int64(1),
#  np.str_('38586770'): np.int64(1),
#  np.str_('38587208'): np.int64(1),
#  np.str_('38587222'): np.int64(1),
#  np.str_('38587453'): np.int64(1),
#  np.str_('38587664'): np.int64(1),
#  np.str_('38587667'): np.int64(1),
#  np.str_('38587850'): np.int64(1),
#  np.str_('38589003'): np.int64(1),
#  np.str_('38589249'): np.int64(1),
#  np.str_('38589397'): np.int64(1),
#  np.str_('38589992'): np.int64(1),
#  np.str_('38596011'): np.int64(1),
#  np.str_('38596064'): np.int64(1),
#  np.str_('38596666'): np.int64(1),
#  np.str_('38597008'): np.int64(1),
#  np.str_('38597444'): np.int64(1),
#  np.str_('38597623'): np.int64(1),
#  np.str_('38598686'): np.int64(1),
#  np.str_('38598730'): np.int64(1),
#  np.str_('38598757'): np.int64(1),
#  np.str_('38599004'): np.int64(1),
#  np.str_('38599307'): np.int64(1),
#  np.str_('38599875'): np.int64(1),
#  np.str_('38604429'): np.int64(1),
#  np.str_('38605496'): np.int64(1),
#  np.str_('38606303'): np.int64(1),
#  np.str_('38607129'): np.int64(1),
#  np.str_('38607774'): np.int64(1),
#  np.str_('38608511'): np.int64(1),
#  np.str_('38608899'): np.int64(1),
#  np.str_('38609776'): np.int64(1),
#  np.str_('38610104'): np.int64(1),
#  np.str_('38614123'): np.int64(1),
#  np.str_('38614136'): np.int64(1),
#  np.str_('38614453'): np.int64(1),
#  np.str_('38614686'): np.int64(1),
#  np.str_('38614987'): np.int64(1),
#  np.str_('38615026'): np.int64(1),
#  np.str_('38615856'): np.int64(1),
#  np.str_('38619221'): np.int64(1),
#  np.str_('38619427'): np.int64(1),
#  np.str_('38619484'): np.int64(1),
#  np.str_('38624147'): np.int64(1),
#  np.str_('38624484'): np.int64(1),
#  np.str_('38625595'): np.int64(1),
#  np.str_('38625960'): np.int64(1),
#  np.str_('38626358'): np.int64(1),
#  np.str_('38626539'): np.int64(1),
#  np.str_('38626776'): np.int64(1),
#  np.str_('38627361'): np.int64(1),
#  np.str_('38627577'): np.int64(1),
#  np.str_('38627820'): np.int64(1),
#  np.str_('38628265'): np.int64(1),
#  np.str_('38628800'): np.int64(1),
#  np.str_('38628823'): np.int64(1),
#  np.str_('38629293'): np.int64(1),
#  np.str_('38629302'): np.int64(1),
#  np.str_('38629429'): np.int64(1),
#  np.str_('38630171'): np.int64(1),
#  np.str_('38630522'): np.int64(1),
#  np.str_('38634333'): np.int64(1),
#  np.str_('38634902'): np.int64(1),
#  np.str_('38635104'): np.int64(1),
#  np.str_('38635231'): np.int64(1),
#  np.str_('38635267'): np.int64(1),
#  np.str_('38636413'): np.int64(1),
#  np.str_('38636452'): np.int64(1),
#  np.str_('38636540'): np.int64(1),
#  np.str_('38636713'): np.int64(1),
#  np.str_('38637029'): np.int64(1),
#  np.str_('38637943'): np.int64(1),
#  np.str_('38638030'): np.int64(1),
#  np.str_('38638088'): np.int64(1),
#  np.str_('38638104'): np.int64(1),
#  np.str_('38638436'): np.int64(1),
#  np.str_('38638464'): np.int64(1),
#  np.str_('38638818'): np.int64(1),
#  np.str_('38640466'): np.int64(1),
#  np.str_('38644242'): np.int64(1),
#  np.str_('38644517'): np.int64(1),
#  np.str_('38644866'): np.int64(1),
#  np.str_('38645079'): np.int64(1),
#  np.str_('38645088'): np.int64(1),
#  np.str_('38645124'): np.int64(1),
#  np.str_('38645450'): np.int64(1),
#  np.str_('38645585'): np.int64(1),
#  np.str_('38645761'): np.int64(1),
#  np.str_('38646795'): np.int64(1),
#  np.str_('38647108'): np.int64(1),
#  np.str_('38648002'): np.int64(1),
#  np.str_('38648480'): np.int64(1),
#  np.str_('38648684'): np.int64(1),
#  np.str_('38649441'): np.int64(1),
#  np.str_('38654540'): np.int64(1),
#  np.str_('38656135'): np.int64(1),
#  np.str_('38656672'): np.int64(1),
#  np.str_('38656934'): np.int64(1),
#  np.str_('38657174'): np.int64(1),
#  np.str_('38657221'): np.int64(1),
#  np.str_('38658314'): np.int64(1),
#  np.str_('38658847'): np.int64(1),
#  np.str_('38659637'): np.int64(1),
#  np.str_('38659640'): np.int64(1),
#  np.str_('38659673'): np.int64(1),
#  np.str_('38660125'): np.int64(1),
#  np.str_('38660226'): np.int64(1),
#  np.str_('38676187'): np.int64(1),
#  np.str_('38697764'): np.int64(1),
#  np.str_('38697859'): np.int64(1),
#  np.str_('38697967'): np.int64(1),
#  np.str_('38699481'): np.int64(1),
#  np.str_('38699512'): np.int64(1),
#  np.str_('38700451'): np.int64(1),
#  np.str_('38700485'): np.int64(1),
#  np.str_('38762135'): np.int64(1),
#  np.str_('38762271'): np.int64(1),
#  np.str_('38762530'): np.int64(1),
#  np.str_('38772119'): np.int64(1),
#  np.str_('38802324'): np.int64(1),
#  np.str_('38812524'): np.int64(1),
#  np.str_('38812579'): np.int64(1),
#  np.str_('38832159'): np.int64(1),
#  np.str_('38862362'): np.int64(1),
#  np.str_('38882248'): np.int64(1),
#  np.str_('38892180'): np.int64(1),
#  np.str_('38892250'): np.int64(1),
#  np.str_('38902508'): np.int64(1),
#  np.str_('38922367'): np.int64(1),
#  np.str_('38922413'): np.int64(1),
#  np.str_('38942214'): np.int64(1),
#  np.str_('38942256'): np.int64(1),
#  np.str_('38988185'): np.int64(1),
#  np.str_('38988234'): np.int64(1),
#  np.str_('38998263'): np.int64(1),
#  np.str_('39048278'): np.int64(1),
#  np.str_('39058252'): np.int64(1),
#  np.str_('39058407'): np.int64(1),
#  np.str_('39078332'): np.int64(1),
#  np.str_('39098337'): np.int64(1),
#  np.str_('39118425'): np.int64(1),
#  np.str_('39128234'): np.int64(1),
#  np.str_('39128320'): np.int64(1),
#  np.str_('39168162'): np.int64(1),
#  np.str_('39168284'): np.int64(1),
#  np.str_('39240215'): np.int64(1),
#  np.str_('39240589'): np.int64(1),
#  np.str_('39249568'): np.int64(1),
#  np.str_('39250456'): np.int64(1),
#  np.str_('39250494'): np.int64(1),
#  np.str_('39259248'): np.int64(1),
#  np.str_('39259539'): np.int64(1),
#  np.str_('39259551'): np.int64(1),
#  np.str_('39259830'): np.int64(1),
#  np.str_('39259940'): np.int64(1),
#  np.str_('39260464'): np.int64(1),
#  np.str_('39260628'): np.int64(1),
#  np.str_('39260731'): np.int64(1),
#  np.str_('39269427'): np.int64(1),
#  np.str_('39269612'): np.int64(1),
#  np.str_('39269734'): np.int64(1),
#  np.str_('39279139'): np.int64(1),
#  np.str_('39280058'): np.int64(1),
#  np.str_('39289510'): np.int64(1),
#  np.str_('39290138'): np.int64(1),
#  np.str_('39299787'): np.int64(1),
#  np.str_('39300094'): np.int64(1),
#  np.str_('39309730'): np.int64(1),
#  np.str_('39310328'): np.int64(1),
#  np.str_('39319360'): np.int64(1),
#  np.str_('39319640'): np.int64(1),
#  np.str_('39320189'): np.int64(1),
#  np.str_('39320671'): np.int64(1),
#  np.str_('39330445'): np.int64(1),
#  np.str_('39339361'): np.int64(1),
#  np.str_('39340141'): np.int64(1),
#  np.str_('39340509'): np.int64(1),
#  np.str_('39340699'): np.int64(1),
#  np.str_('39350103'): np.int64(1),
#  np.str_('39359312'): np.int64(1),
#  np.str_('39359805'): np.int64(1),
#  np.str_('39369476'): np.int64(1),
#  np.str_('39370099'): np.int64(1),
#  np.str_('39370561'): np.int64(1),
#  np.str_('39370685'): np.int64(1),
#  np.str_('39370702'): np.int64(1),
#  np.str_('39379121'): np.int64(1),
#  np.str_('39379339'): np.int64(1),
#  np.str_('39379695'): np.int64(1),
#  np.str_('39379954'): np.int64(1),
#  np.str_('39389147'): np.int64(1),
#  np.str_('39390678'): np.int64(1),
#  np.str_('39399351'): np.int64(1),
#  np.str_('39409449'): np.int64(1),
#  np.str_('39409970'): np.int64(1),
#  np.str_('39410191'): np.int64(1),
#  np.str_('39410323'): np.int64(1),
#  np.str_('39410508'): np.int64(1),
#  np.str_('39419612'): np.int64(1),
#  np.str_('39419646'): np.int64(1),
#  np.str_('39419773'): np.int64(1),
#  np.str_('39420049'): np.int64(1),
#  np.str_('39420263'): np.int64(1),
#  np.str_('39430510'): np.int64(1),
#  np.str_('39439434'): np.int64(1),
#  np.str_('39440006'): np.int64(1),
#  np.str_('39440282'): np.int64(1),
#  np.str_('39440416'): np.int64(1),
#  np.str_('39449156'): np.int64(1),
#  np.str_('39449232'): np.int64(1),
#  np.str_('39449277'): np.int64(1),
#  np.str_('39450001'): np.int64(1),
#  np.str_('39450006'): np.int64(1),
#  np.str_('39450072'): np.int64(1),
#  np.str_('39450129'): np.int64(1),
#  np.str_('39450174'): np.int64(1),
#  np.str_('39450516'): np.int64(1),
#  np.str_('39450533'): np.int64(1),
#  np.str_('39450563'): np.int64(1),
#  np.str_('39459152'): np.int64(1),
#  np.str_('39459212'): np.int64(1),
#  np.str_('39459320'): np.int64(1),
#  np.str_('39459418'): np.int64(1),
#  np.str_('39459745'): np.int64(1),
#  np.str_('39460281'): np.int64(1),
#  np.str_('39469124'): np.int64(1),
#  np.str_('39470123'): np.int64(1),
#  np.str_('39470475'): np.int64(1),
#  np.str_('39470492'): np.int64(1),
#  np.str_('39479346'): np.int64(1),
#  np.str_('39479538'): np.int64(1),
#  np.str_('39479816'): np.int64(1),
#  np.str_('39479928'): np.int64(1),
#  np.str_('39480387'): np.int64(1),
#  np.str_('39519554'): np.int64(1),
#  np.str_('39519601'): np.int64(1),
#  np.str_('39519659'): np.int64(1),
#  np.str_('39522398'): np.int64(1),
#  np.str_('39522667'): np.int64(1),
#  np.str_('39529306'): np.int64(1),
#  np.str_('39529544'): np.int64(1),
#  np.str_('39530507'): np.int64(1),
#  np.str_('39530542'): np.int64(1),
#  np.str_('39531255'): np.int64(1),
#  np.str_('39531676'): np.int64(1),
#  np.str_('39531855'): np.int64(1),
#  np.str_('39532115'): np.int64(1),
#  np.str_('39532354'): np.int64(1),
#  np.str_('39532736'): np.int64(1),
#  np.str_('39539216'): np.int64(1),
#  np.str_('39539476'): np.int64(1),
#  np.str_('39539790'): np.int64(1),
#  np.str_('39540351'): np.int64(1),
#  np.str_('39540758'): np.int64(1),
#  np.str_('39541526'): np.int64(1),
#  np.str_('39541568'): np.int64(1),
#  np.str_('39541739'): np.int64(1),
#  np.str_('39541824'): np.int64(1),
#  np.str_('39541829'): np.int64(1),
#  np.str_('39542090'): np.int64(1),
#  np.str_('39542430'): np.int64(1),
#  np.str_('39542761'): np.int64(1),
#  np.str_('39549224'): np.int64(1),
#  np.str_('39549547'): np.int64(1),
#  np.str_('39550436'): np.int64(1),
#  np.str_('39551022'): np.int64(1),
#  np.str_('39551238'): np.int64(1),
#  np.str_('39551248'): np.int64(1),
#  np.str_('39551271'): np.int64(1),
#  np.str_('39551452'): np.int64(1),
#  np.str_('39551584'): np.int64(1),
#  np.str_('39552632'): np.int64(1),
#  np.str_('39559175'): np.int64(1),
#  np.str_('39560141'): np.int64(1),
#  np.str_('39560250'): np.int64(1),
#  np.str_('39560268'): np.int64(1),
#  np.str_('39560985'): np.int64(1),
#  np.str_('39562566'): np.int64(1),
#  np.str_('39570206'): np.int64(1),
#  np.str_('39570345'): np.int64(1),
#  np.str_('39570400'): np.int64(1),
#  np.str_('39571187'): np.int64(1),
#  np.str_('39571474'): np.int64(1),
#  np.str_('39571607'): np.int64(1),
#  np.str_('39571704'): np.int64(1),
#  np.str_('39571858'): np.int64(1),
#  np.str_('39572026'): np.int64(1),
#  np.str_('39579364'): np.int64(1),
#  np.str_('39579506'): np.int64(1),
#  np.str_('39580213'): np.int64(1),
#  np.str_('39580707'): np.int64(1),
#  np.str_('39582031'): np.int64(1),
#  np.str_('39582156'): np.int64(1),
#  np.str_('39589211'): np.int64(1),
#  np.str_('39589608'): np.int64(1),
#  np.str_('39589892'): np.int64(1),
#  np.str_('39591170'): np.int64(1),
#  np.str_('39591592'): np.int64(1),
#  np.str_('39592471'): np.int64(1),
#  np.str_('39600196'): np.int64(1),
#  np.str_('39600453'): np.int64(1),
#  np.str_('39600950'): np.int64(1),
#  np.str_('39601021'): np.int64(1),
#  np.str_('39601622'): np.int64(1),
#  np.str_('39602077'): np.int64(1),
#  np.str_('39602078'): np.int64(1),
#  np.str_('39609270'): np.int64(1),
#  np.str_('39609749'): np.int64(1),
#  np.str_('39610057'): np.int64(1),
#  np.str_('39610922'): np.int64(1),
#  np.str_('39611461'): np.int64(1),
#  np.str_('39611467'): np.int64(1),
#  np.str_('39621774'): np.int64(1),
#  np.str_('39629566'): np.int64(1),
#  np.str_('39629590'): np.int64(1),
#  np.str_('39630102'): np.int64(1),
#  np.str_('39630518'): np.int64(1),
#  np.str_('39631189'): np.int64(1),
#  np.str_('39631370'): np.int64(1),
#  np.str_('39632009'): np.int64(1),
#  np.str_('39639437'): np.int64(1),
#  np.str_('39639780'): np.int64(1),
#  np.str_('39640575'): np.int64(1),
#  np.str_('39640792'): np.int64(1),
#  np.str_('39640972'): np.int64(1),
#  np.str_('39641066'): np.int64(1),
#  np.str_('39641128'): np.int64(1),
#  np.str_('39641145'): np.int64(1),
#  np.str_('39641287'): np.int64(1),
#  np.str_('39641379'): np.int64(1),
#  np.str_('39642303'): np.int64(1),
#  np.str_('39642358'): np.int64(1),
#  np.str_('39649645'): np.int64(1),
#  np.str_('39649727'): np.int64(1),
#  np.str_('39649735'): np.int64(1),
#  np.str_('39649886'): np.int64(1),
#  np.str_('39650471'): np.int64(1),
#  np.str_('39650479'): np.int64(1),
#  np.str_('39650816'): np.int64(1),
#  np.str_('39650824'): np.int64(1),
#  np.str_('39650865'): np.int64(1),
#  np.str_('39651183'): np.int64(1),
#  np.str_('39651264'): np.int64(1),
#  np.str_('39651723'): np.int64(1),
#  np.str_('39651780'): np.int64(1),
#  np.str_('39651810'): np.int64(1),
#  np.str_('39652294'): np.int64(1),
#  np.str_('39660587'): np.int64(1),
#  np.str_('39660902'): np.int64(1),
#  np.str_('39662294'): np.int64(1),
#  np.str_('39662450'): np.int64(1),
#  np.str_('39662454'): np.int64(1),
#  np.str_('39662461'): np.int64(1),
#  np.str_('39670432'): np.int64(1),
#  np.str_('39671485'): np.int64(1),
#  np.str_('39671873'): np.int64(1),
#  np.str_('39671997'): np.int64(1),
#  np.str_('39672299'): np.int64(1),
#  np.str_('39672441'): np.int64(1),
#  np.str_('39679235'): np.int64(1),
#  np.str_('39679820'): np.int64(1),
#  np.str_('39681083'): np.int64(1),
#  np.str_('39681190'): np.int64(1),
#  np.str_('39681860'): np.int64(1),
#  np.str_('39681937'): np.int64(1),
#  np.str_('39682461'): np.int64(1),
#  np.str_('39682522'): np.int64(1),
#  np.str_('39682729'): np.int64(1),
#  np.str_('39689649'): np.int64(1),
#  np.str_('39691506'): np.int64(1),
#  np.str_('39692008'): np.int64(1),
#  np.str_('39692957'): np.int64(1),
#  np.str_('39699406'): np.int64(1),
#  np.str_('39700420'): np.int64(1),
#  np.str_('39701166'): np.int64(1),
#  np.str_('39701655'): np.int64(1),
#  np.str_('39701874'): np.int64(1),
#  np.str_('39702453'): np.int64(1),
#  np.str_('39702615'): np.int64(1),
#  np.str_('39709283'): np.int64(1),
#  np.str_('39710687'): np.int64(1),
#  np.str_('39711094'): np.int64(1),
#  np.str_('39711438'): np.int64(1),
#  np.str_('39711741'): np.int64(1),
#  np.str_('39712054'): np.int64(1),
#  np.str_('39712384'): np.int64(1),
#  np.str_('39719763'): np.int64(1),
#  np.str_('39720831'): np.int64(1),
#  np.str_('39721185'): np.int64(1),
#  np.str_('39730077'): np.int64(1),
#  np.str_('39730512'): np.int64(1),
#  np.str_('39730671'): np.int64(1),
#  np.str_('39739479'): np.int64(1),
#  np.str_('39739574'): np.int64(1),
#  np.str_('39740247'): np.int64(1),
#  np.str_('39740289'): np.int64(1),
#  np.str_('39741110'): np.int64(1),
#  np.str_('39741164'): np.int64(1),
#  np.str_('39741221'): np.int64(1),
#  np.str_('39741341'): np.int64(1),
#  np.str_('39741834'): np.int64(1),
#  np.str_('39749193'): np.int64(1),
#  np.str_('39749843'): np.int64(1),
#  np.str_('39750698'): np.int64(1),
#  np.str_('39750883'): np.int64(1),
#  np.str_('39751366'): np.int64(1),
#  np.str_('39751412'): np.int64(1),
#  np.str_('39752508'): np.int64(1),
#  np.str_('39760552'): np.int64(1),
#  np.str_('39761181'): np.int64(1),
#  np.str_('39761889'): np.int64(1),
#  np.str_('39762029'): np.int64(1),
#  np.str_('39762179'): np.int64(1),
#  np.str_('39762341'): np.int64(1),
#  np.str_('39770427'): np.int64(1),
#  np.str_('39770600'): np.int64(1),
#  np.str_('39770635'): np.int64(1),
#  np.str_('39770698'): np.int64(1),
#  np.str_('39771227'): np.int64(1),
#  np.str_('39792266'): np.int64(1),
#  np.str_('39817908'): np.int64(1),
#  np.str_('39817918'): np.int64(1),
#  np.str_('39818255'): np.int64(1),
#  np.str_('39818264'): np.int64(1),
#  np.str_('39828040'): np.int64(1),
#  np.str_('39837219'): np.int64(1),
#  np.str_('39837901'): np.int64(1),
#  np.str_('39837969'): np.int64(1),
#  np.str_('39848036'): np.int64(1),
#  np.str_('39867227'): np.int64(1),
#  np.str_('39867234'): np.int64(1),
#  np.str_('39877750'): np.int64(1),
#  np.str_('39917775'): np.int64(1),
#  np.str_('39917986'): np.int64(1),
#  np.str_('39947376'): np.int64(1),
#  np.str_('39967640'): np.int64(1),
#  np.str_('39987477'): np.int64(1),
#  np.str_('39987957'): np.int64(1),
#  np.str_('39997469'): np.int64(1),
#  np.str_('39998040'): np.int64(1),
#  np.str_('39998058'): np.int64(1),
#  np.str_('40007811'): np.int64(1),
#  np.str_('40007971'): np.int64(1),
#  np.str_('40017258'): np.int64(1),
#  np.str_('40017785'): np.int64(1),
#  np.str_('40017927'): np.int64(1),
#  np.str_('40027519'): np.int64(1),
#  np.str_('40027881'): np.int64(1),
#  np.str_('40027897'): np.int64(1),
#  np.str_('40107154'): np.int64(1),
#  np.str_('40107178'): np.int64(1),
#  np.str_('40127766'): np.int64(1),
#  np.str_('40147374'): np.int64(1),
#  np.str_('40147728'): np.int64(1),
#  np.str_('40148175'): np.int64(1),
#  np.str_('40148192'): np.int64(1),
#  np.str_('40157523'): np.int64(1),
#  np.str_('40157557'): np.int64(1),
#  np.str_('40157706'): np.int64(1),
#  np.str_('40157956'): np.int64(1),
#  np.str_('40167338'): np.int64(1),
#  np.str_('40167835'): np.int64(1),
#  np.str_('40168068'): np.int64(1),
#  np.str_('40177193'): np.int64(1),
#  np.str_('40177198'): np.int64(1),
#  np.str_('40177757'): np.int64(1),
#  np.str_('40177813'): np.int64(1),
#  np.str_('40187625'): np.int64(1),
#  np.str_('40188022'): np.int64(1),
#  np.str_('40198039'): np.int64(1),
#  np.str_('40198057'): np.int64(1),
#  np.str_('40207609'): np.int64(1),
#  np.str_('40207654'): np.int64(1),
#  np.str_('40207716'): np.int64(1),
#  np.str_('40227434'): np.int64(1),
#  np.str_('40227982'): np.int64(1),
#  np.str_('40237830'): np.int64(1),
#  np.str_('40238227'): np.int64(1),
#  np.str_('40247530'): np.int64(1),
#  np.str_('40247792'): np.int64(1),
#  np.str_('40247818'): np.int64(1),
#  np.str_('40257152'): np.int64(1),
#  np.str_('40257398'): np.int64(1),
#  np.str_('40277306'): np.int64(1),
#  np.str_('40277437'): np.int64(1),
#  np.str_('40277838'): np.int64(1),
#  np.str_('40278243'): np.int64(1),
#  np.str_('40278432'): np.int64(1),
#  np.str_('40278450'): np.int64(1),
#  np.str_('40287177'): np.int64(1),
#  np.str_('40287182'): np.int64(1),
#  np.str_('40287591'): np.int64(1),
#  np.str_('40287602'): np.int64(1),
#  np.str_('40287639'): np.int64(1),
#  np.str_('40288176'): np.int64(1),
#  np.str_('40297405'): np.int64(1),
#  np.str_('40297586'): np.int64(1),
#  np.str_('40297845'): np.int64(1),
#  np.str_('40297965'): np.int64(1),
#  np.str_('40298097'): np.int64(1),
#  np.str_('40298157'): np.int64(1),
#  np.str_('40307781'): np.int64(1),
#  np.str_('40317498'): np.int64(1),
#  np.str_('40317524'): np.int64(1),
#  np.str_('40317686'): np.int64(1),
#  np.str_('40317777'): np.int64(1),
#  np.str_('40317917'): np.int64(1),
#  np.str_('40317923'): np.int64(1),
#  np.str_('40318017'): np.int64(1),
#  np.str_('40318214'): np.int64(1),
#  np.str_('40327372'): np.int64(1),
#  np.str_('40327388'): np.int64(1),
#  np.str_('40327799'): np.int64(1),
#  np.str_('40337449'): np.int64(1),
#  np.str_('40337954'): np.int64(1),
#  np.str_('40350535'): np.int64(1),
#  np.str_('40351221'): np.int64(1),
#  np.str_('40351451'): np.int64(1),
#  np.str_('40352068'): np.int64(1),
#  np.str_('40353115'): np.int64(1),
#  np.str_('40353543'): np.int64(1),
#  np.str_('40353819'): np.int64(1),
#  np.str_('40353941'): np.int64(1),
#  np.str_('40354398'): np.int64(1),
#  np.str_('40354465'): np.int64(1),
#  np.str_('40355705'): np.int64(1),
#  np.str_('40355978'): np.int64(1),
#  np.str_('40360547'): np.int64(1),
#  np.str_('40361860'): np.int64(1),
#  np.str_('40362564'): np.int64(1),
#  np.str_('40362953'): np.int64(1),
#  np.str_('40363003'): np.int64(1),
#  np.str_('40370487'): np.int64(1),
#  np.str_('40370548'): np.int64(1),
#  np.str_('40370555'): np.int64(1),
#  np.str_('40370940'): np.int64(1),
#  np.str_('40371236'): np.int64(1),
#  np.str_('40371294'): np.int64(1),
#  np.str_('40371340'): np.int64(1),
#  np.str_('40371748'): np.int64(1),
#  np.str_('40372163'): np.int64(1),
#  np.str_('40373016'): np.int64(1),
#  np.str_('40373432'): np.int64(1),
#  np.str_('40373750'): np.int64(1),
#  np.str_('40374030'): np.int64(1),
#  np.str_('40380886'): np.int64(1),
#  np.str_('40381857'): np.int64(1),
#  np.str_('40381892'): np.int64(1),
#  np.str_('40382671'): np.int64(1),
#  np.str_('40382999'): np.int64(1),
#  np.str_('40383569'): np.int64(1),
#  np.str_('40385571'): np.int64(1),
#  np.str_('40385677'): np.int64(1),
#  np.str_('40386161'): np.int64(1),
#  np.str_('40386670'): np.int64(1),
#  np.str_('40386976'): np.int64(1),
#  np.str_('40390116'): np.int64(1),
#  np.str_('40390177'): np.int64(1),
#  np.str_('40390915'): np.int64(1),
#  np.str_('40391120'): np.int64(1),
#  np.str_('40392063'): np.int64(1),
#  np.str_('40392082'): np.int64(1),
#  np.str_('40392106'): np.int64(1),
#  np.str_('40392183'): np.int64(1),
#  np.str_('40392383'): np.int64(1),
#  np.str_('40393112'): np.int64(1),
#  np.str_('40393128'): np.int64(1),
#  np.str_('40400294'): np.int64(1),
#  np.str_('40400432'): np.int64(1),
#  np.str_('40401029'): np.int64(1),
#  np.str_('40401923'): np.int64(1),
#  np.str_('40410530'): np.int64(1),
#  np.str_('40410609'): np.int64(1),
#  np.str_('40410767'): np.int64(1),
#  np.str_('40410869'): np.int64(1),
#  np.str_('40410895'): np.int64(1),
#  np.str_('40410999'): np.int64(1),
#  np.str_('40411440'): np.int64(1),
#  np.str_('40412356'): np.int64(1),
#  np.str_('40412749'): np.int64(1),
#  np.str_('40412780'): np.int64(1),
#  np.str_('40413028'): np.int64(1),
#  np.str_('40413463'): np.int64(1),
#  np.str_('40413857'): np.int64(1),
#  np.str_('40420175'): np.int64(1),
#  np.str_('40420481'): np.int64(1),
#  np.str_('40420486'): np.int64(1),
#  np.str_('40420550'): np.int64(1),
#  np.str_('40421263'): np.int64(1),
#  np.str_('40421561'): np.int64(1),
#  np.str_('40421656'): np.int64(1),
#  np.str_('40422290'): np.int64(1),
#  np.str_('40422488'): np.int64(1),
#  np.str_('40422579'): np.int64(1),
#  np.str_('40422791'): np.int64(1),
#  np.str_('40422955'): np.int64(1),
#  np.str_('40423455'): np.int64(1),
#  np.str_('40430209'): np.int64(1),
#  np.str_('40431558'): np.int64(1),
#  np.str_('40431779'): np.int64(1),
#  np.str_('40431975'): np.int64(1),
#  np.str_('40432239'): np.int64(1),
#  np.str_('40432754'): np.int64(1),
#  np.str_('40440185'): np.int64(1),
#  np.str_('40440338'): np.int64(1),
#  np.str_('40440654'): np.int64(1),
#  np.str_('40441043'): np.int64(1),
#  np.str_('40441627'): np.int64(1),
#  np.str_('40442015'): np.int64(1),
#  np.str_('40442429'): np.int64(1),
#  np.str_('40443816'): np.int64(1),
#  np.str_('40450227'): np.int64(1),
#  np.str_('40451331'): np.int64(1),
#  np.str_('40451886'): np.int64(1),
#  np.str_('40451890'): np.int64(1),
#  np.str_('40452204'): np.int64(1),
#  np.str_('40452937'): np.int64(1),
#  np.str_('40453066'): np.int64(1),
#  np.str_('40453665'): np.int64(1),
#  np.str_('40453767'): np.int64(1),
#  np.str_('40453979'): np.int64(1),
#  np.str_('40460385'): np.int64(1),
#  np.str_('40461150'): np.int64(1),
#  np.str_('40461164'): np.int64(1),
#  np.str_('40462361'): np.int64(1),
#  np.str_('40462752'): np.int64(1),
#  np.str_('40463001'): np.int64(1),
#  np.str_('40463110'): np.int64(1),
#  np.str_('40463741'): np.int64(1),
#  np.str_('40470280'): np.int64(1),
#  np.str_('40470420'): np.int64(1),
#  np.str_('40470700'): np.int64(1),
#  np.str_('40471138'): np.int64(1),
#  np.str_('40471729'): np.int64(1),
#  np.str_('40472332'): np.int64(1),
#  np.str_('40472398'): np.int64(1),
#  ...}

# %%
arreglo_count = [item for _, item in caracteristicas_data[label_data[0]].items()]
max(arreglo_count)
# Out:
# np.int64(1)

# %% [markdown]
# El análisis de los identificadores presentes en la categoría 'id' evidencia que:
#
# - Mantienen una correspondencia única con cada uno de los registros extraídos, por lo que pueden considerarse claves únicas dentro del conjunto de datos.
# - Se descarta la presencia de registros duplicados, ya que cada identificador presenta una única ocurrencia en la base de datos analizada.
# - Los identificadores proporcionados siguen una codificación consistente basada en un serial numérico. No obstante, debido a que su función es exclusivamente identificativa y no representan una variable cuantitativa, se considera apropiado preservarlos en formato de cadena de caracteres durante las etapas posteriores del procesamiento de datos.

# %% [markdown]
# ### Categoría 'issue_d'

# %% [markdown]
# Esta categoría corresponde al mes en el que el préstamo fue financiado. Su contenido permite identificar el período temporal asociado a la formalización y desembolso de cada préstamo.

# %%
caracteristicas_data[label_data[1]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('Apr-15'): np.int64(757),
#  np.str_('Aug-15'): np.int64(846),
#  np.str_('Dec-15'): np.int64(997),
#  np.str_('Feb-15'): np.int64(530),
#  np.str_('Jan-15'): np.int64(770),
#  np.str_('Jul-15'): np.int64(1061),
#  np.str_('Jun-15'): np.int64(654),
#  np.str_('Mar-15'): np.int64(559),
#  np.str_('May-15'): np.int64(741),
#  np.str_('Nov-15'): np.int64(847),
#  np.str_('Oct-15'): np.int64(1095),
#  np.str_('Sep-15'): np.int64(643)}

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'issue_d' se observa lo siguiente:
#
# - Los registros proporcionados corresponden a préstamos otorgados a lo largo del año 2015.
# - No se identifican etiquetas diferentes que hagan referencia a un mismo mes.
# - Se detectan 500 registros para los cuales el mes de otorgamiento no fue almacenado correctamente, apareciendo en la base de datos como una cadena vacía ('').
#
# Recomendación: reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior dentro de las estructuras de datos de NumPy.

# %% [markdown]
# ### Categoría 'loan_amnt'

# %% [markdown]
#  Esta categoría representa el monto del préstamo solicitado por el prestatario. En caso de que el departamento de crédito haya realizado una reducción del monto inicialmente solicitado durante el proceso de evaluación, el valor registrado en esta variable corresponde al monto ajustado y finalmente aprobado.

# %%
caracteristicas_data[label_data[2]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('1000.0'): np.int64(30),
#  np.str_('10000.0'): np.int64(628),
#  np.str_('10025.0'): np.int64(1),
#  np.str_('10050.0'): np.int64(3),
#  np.str_('10075.0'): np.int64(1),
#  np.str_('10100.0'): np.int64(6),
#  np.str_('10150.0'): np.int64(2),
#  np.str_('10175.0'): np.int64(1),
#  np.str_('10200.0'): np.int64(13),
#  np.str_('10225.0'): np.int64(1),
#  np.str_('10250.0'): np.int64(3),
#  np.str_('10300.0'): np.int64(2),
#  np.str_('10325.0'): np.int64(3),
#  np.str_('10350.0'): np.int64(2),
#  np.str_('10375.0'): np.int64(3),
#  np.str_('10400.0'): np.int64(14),
#  np.str_('10425.0'): np.int64(4),
#  np.str_('10475.0'): np.int64(1),
#  np.str_('10500.0'): np.int64(30),
#  np.str_('10525.0'): np.int64(6),
#  np.str_('10550.0'): np.int64(7),
#  np.str_('10575.0'): np.int64(2),
#  np.str_('10600.0'): np.int64(3),
#  np.str_('10650.0'): np.int64(2),
#  np.str_('10700.0'): np.int64(6),
#  np.str_('10725.0'): np.int64(3),
#  np.str_('10750.0'): np.int64(2),
#  np.str_('10775.0'): np.int64(6),
#  np.str_('10800.0'): np.int64(39),
#  np.str_('10825.0'): np.int64(2),
#  np.str_('10850.0'): np.int64(1),
#  np.str_('10875.0'): np.int64(5),
#  np.str_('10900.0'): np.int64(3),
#  np.str_('10925.0'): np.int64(1),
#  np.str_('10950.0'): np.int64(2),
#  np.str_('10975.0'): np.int64(4),
#  np.str_('1100.0'): np.int64(2),
#  np.str_('11000.0'): np.int64(83),
#  np.str_('11025.0'): np.int64(1),
#  np.str_('11075.0'): np.int64(3),
#  np.str_('11100.0'): np.int64(3),
#  np.str_('11125.0'): np.int64(5),
#  np.str_('11150.0'): np.int64(4),
#  np.str_('11175.0'): np.int64(1),
#  np.str_('11200.0'): np.int64(57),
#  np.str_('11225.0'): np.int64(2),
#  np.str_('11250.0'): np.int64(7),
#  np.str_('11275.0'): np.int64(2),
#  np.str_('11300.0'): np.int64(7),
#  np.str_('11325.0'): np.int64(3),
#  np.str_('11350.0'): np.int64(1),
#  np.str_('11375.0'): np.int64(1),
#  np.str_('11400.0'): np.int64(15),
#  np.str_('11425.0'): np.int64(3),
#  np.str_('11450.0'): np.int64(1),
#  np.str_('11500.0'): np.int64(18),
#  np.str_('11550.0'): np.int64(2),
#  np.str_('11575.0'): np.int64(1),
#  np.str_('11600.0'): np.int64(4),
#  np.str_('11625.0'): np.int64(4),
#  np.str_('11650.0'): np.int64(3),
#  np.str_('11675.0'): np.int64(1),
#  np.str_('11700.0'): np.int64(4),
#  np.str_('11725.0'): np.int64(2),
#  np.str_('1175.0'): np.int64(1),
#  np.str_('11750.0'): np.int64(5),
#  np.str_('11775.0'): np.int64(3),
#  np.str_('11800.0'): np.int64(4),
#  np.str_('11825.0'): np.int64(2),
#  np.str_('11850.0'): np.int64(3),
#  np.str_('11875.0'): np.int64(6),
#  np.str_('11900.0'): np.int64(3),
#  np.str_('11925.0'): np.int64(5),
#  np.str_('11950.0'): np.int64(4),
#  np.str_('11975.0'): np.int64(3),
#  np.str_('1200.0'): np.int64(10),
#  np.str_('12000.0'): np.int64(594),
#  np.str_('12050.0'): np.int64(1),
#  np.str_('12075.0'): np.int64(2),
#  np.str_('12100.0'): np.int64(2),
#  np.str_('12150.0'): np.int64(3),
#  np.str_('12175.0'): np.int64(1),
#  np.str_('12200.0'): np.int64(2),
#  np.str_('12225.0'): np.int64(3),
#  np.str_('1225.0'): np.int64(1),
#  np.str_('12250.0'): np.int64(2),
#  np.str_('12275.0'): np.int64(1),
#  np.str_('12300.0'): np.int64(3),
#  np.str_('12325.0'): np.int64(1),
#  np.str_('12350.0'): np.int64(1),
#  np.str_('12375.0'): np.int64(1),
#  np.str_('12400.0'): np.int64(1),
#  np.str_('12425.0'): np.int64(5),
#  np.str_('12450.0'): np.int64(3),
#  np.str_('12500.0'): np.int64(23),
#  np.str_('12525.0'): np.int64(3),
#  np.str_('12550.0'): np.int64(2),
#  np.str_('12575.0'): np.int64(3),
#  np.str_('12600.0'): np.int64(7),
#  np.str_('12625.0'): np.int64(1),
#  np.str_('12675.0'): np.int64(1),
#  np.str_('12700.0'): np.int64(2),
#  np.str_('12725.0'): np.int64(3),
#  np.str_('12750.0'): np.int64(3),
#  np.str_('12775.0'): np.int64(2),
#  np.str_('12800.0'): np.int64(28),
#  np.str_('12825.0'): np.int64(1),
#  np.str_('12850.0'): np.int64(3),
#  np.str_('12900.0'): np.int64(3),
#  np.str_('12925.0'): np.int64(1),
#  np.str_('12950.0'): np.int64(4),
#  np.str_('12975.0'): np.int64(5),
#  np.str_('13000.0'): np.int64(70),
#  np.str_('13025.0'): np.int64(3),
#  np.str_('13075.0'): np.int64(1),
#  np.str_('13125.0'): np.int64(2),
#  np.str_('13150.0'): np.int64(5),
#  np.str_('13175.0'): np.int64(2),
#  np.str_('13200.0'): np.int64(18),
#  np.str_('13225.0'): np.int64(3),
#  np.str_('1325.0'): np.int64(1),
#  np.str_('13250.0'): np.int64(2),
#  np.str_('13300.0'): np.int64(2),
#  np.str_('13325.0'): np.int64(2),
#  np.str_('13350.0'): np.int64(2),
#  np.str_('13375.0'): np.int64(4),
#  np.str_('13425.0'): np.int64(2),
#  np.str_('13450.0'): np.int64(5),
#  np.str_('13475.0'): np.int64(2),
#  np.str_('13500.0'): np.int64(20),
#  np.str_('13525.0'): np.int64(2),
#  np.str_('13550.0'): np.int64(1),
#  np.str_('13600.0'): np.int64(9),
#  np.str_('13625.0'): np.int64(5),
#  np.str_('13675.0'): np.int64(2),
#  np.str_('13700.0'): np.int64(3),
#  np.str_('13750.0'): np.int64(3),
#  np.str_('13775.0'): np.int64(2),
#  np.str_('13800.0'): np.int64(3),
#  np.str_('13825.0'): np.int64(3),
#  np.str_('13850.0'): np.int64(2),
#  np.str_('13900.0'): np.int64(3),
#  np.str_('13925.0'): np.int64(3),
#  np.str_('13950.0'): np.int64(1),
#  np.str_('13975.0'): np.int64(1),
#  np.str_('1400.0'): np.int64(4),
#  np.str_('14000.0'): np.int64(173),
#  np.str_('14025.0'): np.int64(3),
#  np.str_('14050.0'): np.int64(2),
#  np.str_('14075.0'): np.int64(2),
#  np.str_('14100.0'): np.int64(3),
#  np.str_('14125.0'): np.int64(3),
#  np.str_('14175.0'): np.int64(1),
#  np.str_('14225.0'): np.int64(2),
#  np.str_('14250.0'): np.int64(1),
#  np.str_('14275.0'): np.int64(2),
#  np.str_('14300.0'): np.int64(1),
#  np.str_('14325.0'): np.int64(2),
#  np.str_('14350.0'): np.int64(4),
#  np.str_('14375.0'): np.int64(2),
#  np.str_('14400.0'): np.int64(55),
#  np.str_('14425.0'): np.int64(2),
#  np.str_('14450.0'): np.int64(1),
#  np.str_('14475.0'): np.int64(2),
#  np.str_('1450.0'): np.int64(3),
#  np.str_('14500.0'): np.int64(9),
#  np.str_('14525.0'): np.int64(5),
#  np.str_('14550.0'): np.int64(3),
#  np.str_('14600.0'): np.int64(2),
#  np.str_('14650.0'): np.int64(1),
#  np.str_('14675.0'): np.int64(2),
#  np.str_('14700.0'): np.int64(9),
#  np.str_('14750.0'): np.int64(2),
#  np.str_('14800.0'): np.int64(1),
#  np.str_('14825.0'): np.int64(2),
#  np.str_('14875.0'): np.int64(1),
#  np.str_('14900.0'): np.int64(4),
#  np.str_('14950.0'): np.int64(4),
#  np.str_('14975.0'): np.int64(4),
#  np.str_('1500.0'): np.int64(12),
#  np.str_('15000.0'): np.int64(528),
#  np.str_('15025.0'): np.int64(1),
#  np.str_('15050.0'): np.int64(3),
#  np.str_('15075.0'): np.int64(2),
#  np.str_('15100.0'): np.int64(2),
#  np.str_('15125.0'): np.int64(4),
#  np.str_('15150.0'): np.int64(1),
#  np.str_('15175.0'): np.int64(1),
#  np.str_('15200.0'): np.int64(8),
#  np.str_('15250.0'): np.int64(4),
#  np.str_('15275.0'): np.int64(1),
#  np.str_('15300.0'): np.int64(3),
#  np.str_('15325.0'): np.int64(1),
#  np.str_('15400.0'): np.int64(8),
#  np.str_('15425.0'): np.int64(2),
#  np.str_('15450.0'): np.int64(1),
#  np.str_('15475.0'): np.int64(2),
#  np.str_('15500.0'): np.int64(15),
#  np.str_('15525.0'): np.int64(3),
#  np.str_('15550.0'): np.int64(3),
#  np.str_('15600.0'): np.int64(21),
#  np.str_('15625.0'): np.int64(3),
#  np.str_('15700.0'): np.int64(1),
#  np.str_('15750.0'): np.int64(1),
#  np.str_('15775.0'): np.int64(2),
#  np.str_('15800.0'): np.int64(1),
#  np.str_('15850.0'): np.int64(2),
#  np.str_('15875.0'): np.int64(2),
#  np.str_('15925.0'): np.int64(2),
#  np.str_('15950.0'): np.int64(3),
#  np.str_('1600.0'): np.int64(7),
#  np.str_('16000.0'): np.int64(249),
#  np.str_('16025.0'): np.int64(2),
#  np.str_('16050.0'): np.int64(1),
#  np.str_('16075.0'): np.int64(2),
#  np.str_('16100.0'): np.int64(4),
#  np.str_('16150.0'): np.int64(4),
#  np.str_('16200.0'): np.int64(4),
#  np.str_('16225.0'): np.int64(1),
#  np.str_('16250.0'): np.int64(1),
#  np.str_('16300.0'): np.int64(3),
#  np.str_('16325.0'): np.int64(2),
#  np.str_('16375.0'): np.int64(3),
#  np.str_('16400.0'): np.int64(2),
#  np.str_('16425.0'): np.int64(1),
#  np.str_('16450.0'): np.int64(3),
#  np.str_('1650.0'): np.int64(1),
#  np.str_('16500.0'): np.int64(14),
#  np.str_('16525.0'): np.int64(2),
#  np.str_('16550.0'): np.int64(2),
#  np.str_('16575.0'): np.int64(1),
#  np.str_('16600.0'): np.int64(3),
#  np.str_('16625.0'): np.int64(1),
#  np.str_('16675.0'): np.int64(1),
#  np.str_('16700.0'): np.int64(3),
#  np.str_('16725.0'): np.int64(2),
#  np.str_('1675.0'): np.int64(1),
#  np.str_('16750.0'): np.int64(4),
#  np.str_('16775.0'): np.int64(1),
#  np.str_('16800.0'): np.int64(26),
#  np.str_('16850.0'): np.int64(1),
#  np.str_('16875.0'): np.int64(2),
#  np.str_('16950.0'): np.int64(3),
#  np.str_('17000.0'): np.int64(58),
#  np.str_('17050.0'): np.int64(3),
#  np.str_('17100.0'): np.int64(6),
#  np.str_('17125.0'): np.int64(3),
#  np.str_('17150.0'): np.int64(1),
#  np.str_('17200.0'): np.int64(5),
#  np.str_('17225.0'): np.int64(1),
#  np.str_('1725.0'): np.int64(1),
#  np.str_('17250.0'): np.int64(1),
#  np.str_('17275.0'): np.int64(2),
#  np.str_('17300.0'): np.int64(1),
#  np.str_('17325.0'): np.int64(2),
#  np.str_('17350.0'): np.int64(1),
#  np.str_('17400.0'): np.int64(2),
#  np.str_('17425.0'): np.int64(4),
#  np.str_('17475.0'): np.int64(1),
#  np.str_('1750.0'): np.int64(1),
#  np.str_('17500.0'): np.int64(28),
#  np.str_('17550.0'): np.int64(2),
#  np.str_('17600.0'): np.int64(7),
#  np.str_('17625.0'): np.int64(6),
#  np.str_('17650.0'): np.int64(2),
#  np.str_('17675.0'): np.int64(2),
#  np.str_('17700.0'): np.int64(1),
#  np.str_('17725.0'): np.int64(1),
#  np.str_('17775.0'): np.int64(1),
#  np.str_('17800.0'): np.int64(1),
#  np.str_('17825.0'): np.int64(2),
#  np.str_('17850.0'): np.int64(4),
#  np.str_('17900.0'): np.int64(4),
#  np.str_('17925.0'): np.int64(1),
#  np.str_('17950.0'): np.int64(1),
#  np.str_('17975.0'): np.int64(2),
#  np.str_('1800.0'): np.int64(8),
#  np.str_('18000.0'): np.int64(256),
#  np.str_('18025.0'): np.int64(4),
#  np.str_('18050.0'): np.int64(2),
#  np.str_('18075.0'): np.int64(1),
#  np.str_('18100.0'): np.int64(3),
#  np.str_('18150.0'): np.int64(4),
#  np.str_('18200.0'): np.int64(3),
#  np.str_('18225.0'): np.int64(1),
#  np.str_('18250.0'): np.int64(2),
#  np.str_('18275.0'): np.int64(1),
#  np.str_('18300.0'): np.int64(1),
#  np.str_('18325.0'): np.int64(2),
#  np.str_('18350.0'): np.int64(7),
#  np.str_('18400.0'): np.int64(7),
#  np.str_('18425.0'): np.int64(2),
#  np.str_('18450.0'): np.int64(4),
#  np.str_('18475.0'): np.int64(3),
#  np.str_('18500.0'): np.int64(15),
#  np.str_('18600.0'): np.int64(1),
#  np.str_('18625.0'): np.int64(1),
#  np.str_('18650.0'): np.int64(1),
#  np.str_('18675.0'): np.int64(2),
#  np.str_('18700.0'): np.int64(3),
#  np.str_('1875.0'): np.int64(1),
#  np.str_('18750.0'): np.int64(1),
#  np.str_('18800.0'): np.int64(3),
#  np.str_('18825.0'): np.int64(1),
#  np.str_('18850.0'): np.int64(2),
#  np.str_('18900.0'): np.int64(5),
#  np.str_('18925.0'): np.int64(1),
#  np.str_('18950.0'): np.int64(1),
#  np.str_('1900.0'): np.int64(3),
#  np.str_('19000.0'): np.int64(29),
#  np.str_('19025.0'): np.int64(2),
#  np.str_('19050.0'): np.int64(3),
#  np.str_('19075.0'): np.int64(2),
#  np.str_('19100.0'): np.int64(2),
#  np.str_('19125.0'): np.int64(2),
#  np.str_('19150.0'): np.int64(2),
#  np.str_('19200.0'): np.int64(39),
#  np.str_('19225.0'): np.int64(1),
#  np.str_('19250.0'): np.int64(2),
#  np.str_('19275.0'): np.int64(3),
#  np.str_('19325.0'): np.int64(2),
#  np.str_('19350.0'): np.int64(1),
#  np.str_('19375.0'): np.int64(2),
#  np.str_('19400.0'): np.int64(1),
#  np.str_('19425.0'): np.int64(1),
#  np.str_('19475.0'): np.int64(2),
#  np.str_('1950.0'): np.int64(1),
#  np.str_('19500.0'): np.int64(4),
#  np.str_('19525.0'): np.int64(1),
#  np.str_('19575.0'): np.int64(2),
#  np.str_('19600.0'): np.int64(2),
#  np.str_('19625.0'): np.int64(1),
#  np.str_('19650.0'): np.int64(2),
#  np.str_('19725.0'): np.int64(2),
#  np.str_('19750.0'): np.int64(2),
#  np.str_('19775.0'): np.int64(3),
#  np.str_('19800.0'): np.int64(10),
#  np.str_('19825.0'): np.int64(2),
#  np.str_('19850.0'): np.int64(1),
#  np.str_('19875.0'): np.int64(3),
#  np.str_('19925.0'): np.int64(2),
#  np.str_('19950.0'): np.int64(3),
#  np.str_('2000.0'): np.int64(40),
#  np.str_('20000.0'): np.int64(565),
#  np.str_('20025.0'): np.int64(1),
#  np.str_('20050.0'): np.int64(4),
#  np.str_('20100.0'): np.int64(1),
#  np.str_('20125.0'): np.int64(3),
#  np.str_('20150.0'): np.int64(5),
#  np.str_('20200.0'): np.int64(1),
#  np.str_('20225.0'): np.int64(4),
#  np.str_('20250.0'): np.int64(1),
#  np.str_('20300.0'): np.int64(1),
#  np.str_('20325.0'): np.int64(1),
#  np.str_('20400.0'): np.int64(12),
#  np.str_('20425.0'): np.int64(2),
#  np.str_('20450.0'): np.int64(1),
#  np.str_('20475.0'): np.int64(5),
#  np.str_('20500.0'): np.int64(4),
#  np.str_('20550.0'): np.int64(1),
#  np.str_('20575.0'): np.int64(1),
#  np.str_('20600.0'): np.int64(4),
#  np.str_('20625.0'): np.int64(2),
#  np.str_('20675.0'): np.int64(2),
#  np.str_('20700.0'): np.int64(6),
#  np.str_('20725.0'): np.int64(1),
#  np.str_('20750.0'): np.int64(3),
#  np.str_('20800.0'): np.int64(2),
#  np.str_('20850.0'): np.int64(1),
#  np.str_('20875.0'): np.int64(1),
#  np.str_('20925.0'): np.int64(1),
#  np.str_('20950.0'): np.int64(4),
#  np.str_('20975.0'): np.int64(2),
#  np.str_('2100.0'): np.int64(2),
#  np.str_('21000.0'): np.int64(139),
#  np.str_('21050.0'): np.int64(3),
#  np.str_('21075.0'): np.int64(1),
#  np.str_('21100.0'): np.int64(3),
#  np.str_('21125.0'): np.int64(2),
#  np.str_('21150.0'): np.int64(1),
#  np.str_('21175.0'): np.int64(3),
#  np.str_('21200.0'): np.int64(1),
#  np.str_('21225.0'): np.int64(1),
#  np.str_('21275.0'): np.int64(1),
#  np.str_('21300.0'): np.int64(3),
#  np.str_('21325.0'): np.int64(1),
#  np.str_('21350.0'): np.int64(1),
#  np.str_('21400.0'): np.int64(1),
#  np.str_('21450.0'): np.int64(1),
#  np.str_('21500.0'): np.int64(8),
#  np.str_('21550.0'): np.int64(2),
#  np.str_('21575.0'): np.int64(1),
#  np.str_('21600.0'): np.int64(22),
#  np.str_('21625.0'): np.int64(1),
#  np.str_('21650.0'): np.int64(1),
#  np.str_('21700.0'): np.int64(1),
#  np.str_('21750.0'): np.int64(4),
#  np.str_('21800.0'): np.int64(1),
#  np.str_('21825.0'): np.int64(2),
#  np.str_('21850.0'): np.int64(2),
#  np.str_('21875.0'): np.int64(1),
#  np.str_('21900.0'): np.int64(1),
#  np.str_('21925.0'): np.int64(2),
#  np.str_('21975.0'): np.int64(1),
#  np.str_('2200.0'): np.int64(6),
#  np.str_('22000.0'): np.int64(60),
#  np.str_('22025.0'): np.int64(1),
#  np.str_('22075.0'): np.int64(2),
#  np.str_('22100.0'): np.int64(1),
#  np.str_('22125.0'): np.int64(1),
#  np.str_('22150.0'): np.int64(1),
#  np.str_('22200.0'): np.int64(3),
#  np.str_('22225.0'): np.int64(4),
#  np.str_('22250.0'): np.int64(1),
#  np.str_('22375.0'): np.int64(1),
#  np.str_('22400.0'): np.int64(24),
#  np.str_('22450.0'): np.int64(1),
#  np.str_('22475.0'): np.int64(1),
#  np.str_('2250.0'): np.int64(2),
#  np.str_('22500.0'): np.int64(4),
#  np.str_('22525.0'): np.int64(1),
#  np.str_('22575.0'): np.int64(1),
#  np.str_('22600.0'): np.int64(2),
#  np.str_('22625.0'): np.int64(1),
#  np.str_('22675.0'): np.int64(2),
#  np.str_('22700.0'): np.int64(1),
#  np.str_('22725.0'): np.int64(1),
#  np.str_('22750.0'): np.int64(2),
#  np.str_('22775.0'): np.int64(1),
#  np.str_('22800.0'): np.int64(9),
#  np.str_('22825.0'): np.int64(1),
#  np.str_('22850.0'): np.int64(1),
#  np.str_('22875.0'): np.int64(2),
#  np.str_('22900.0'): np.int64(2),
#  np.str_('22925.0'): np.int64(1),
#  np.str_('22950.0'): np.int64(5),
#  np.str_('2300.0'): np.int64(3),
#  np.str_('23000.0'): np.int64(40),
#  np.str_('23050.0'): np.int64(2),
#  np.str_('23100.0'): np.int64(4),
#  np.str_('23175.0'): np.int64(1),
#  np.str_('23200.0'): np.int64(2),
#  np.str_('23225.0'): np.int64(3),
#  np.str_('23275.0'): np.int64(2),
#  np.str_('23350.0'): np.int64(3),
#  np.str_('23375.0'): np.int64(1),
#  np.str_('23400.0'): np.int64(2),
#  np.str_('23425.0'): np.int64(1),
#  np.str_('23475.0'): np.int64(1),
#  np.str_('2350.0'): np.int64(1),
#  np.str_('23500.0'): np.int64(4),
#  np.str_('23525.0'): np.int64(1),
#  np.str_('23550.0'): np.int64(1),
#  np.str_('23575.0'): np.int64(1),
#  np.str_('23600.0'): np.int64(2),
#  np.str_('23625.0'): np.int64(1),
#  np.str_('23650.0'): np.int64(1),
#  np.str_('23700.0'): np.int64(2),
#  np.str_('23750.0'): np.int64(3),
#  np.str_('23800.0'): np.int64(1),
#  np.str_('23825.0'): np.int64(1),
#  np.str_('23875.0'): np.int64(3),
#  np.str_('23900.0'): np.int64(1),
#  np.str_('23925.0'): np.int64(2),
#  np.str_('23950.0'): np.int64(2),
#  np.str_('23975.0'): np.int64(3),
#  np.str_('2400.0'): np.int64(23),
#  np.str_('24000.0'): np.int64(258),
#  np.str_('24025.0'): np.int64(1),
#  np.str_('24150.0'): np.int64(1),
#  np.str_('24200.0'): np.int64(5),
#  np.str_('24225.0'): np.int64(2),
#  np.str_('24300.0'): np.int64(2),
#  np.str_('24350.0'): np.int64(1),
#  np.str_('24375.0'): np.int64(1),
#  np.str_('24425.0'): np.int64(2),
#  np.str_('24475.0'): np.int64(2),
#  np.str_('24500.0'): np.int64(2),
#  np.str_('24525.0'): np.int64(2),
#  np.str_('24600.0'): np.int64(3),
#  np.str_('24625.0'): np.int64(2),
#  np.str_('24650.0'): np.int64(3),
#  np.str_('24700.0'): np.int64(4),
#  np.str_('24725.0'): np.int64(1),
#  np.str_('24750.0'): np.int64(1),
#  np.str_('24800.0'): np.int64(2),
#  np.str_('24825.0'): np.int64(1),
#  np.str_('24850.0'): np.int64(1),
#  np.str_('24925.0'): np.int64(2),
#  np.str_('24950.0'): np.int64(3),
#  np.str_('24975.0'): np.int64(2),
#  np.str_('2500.0'): np.int64(23),
#  np.str_('25000.0'): np.int64(306),
#  np.str_('25075.0'): np.int64(1),
#  np.str_('25125.0'): np.int64(2),
#  np.str_('25150.0'): np.int64(1),
#  np.str_('25200.0'): np.int64(5),
#  np.str_('2525.0'): np.int64(1),
#  np.str_('25300.0'): np.int64(2),
#  np.str_('25325.0'): np.int64(2),
#  np.str_('25375.0'): np.int64(1),
#  np.str_('25400.0'): np.int64(1),
#  np.str_('25425.0'): np.int64(1),
#  np.str_('25450.0'): np.int64(1),
#  np.str_('25500.0'): np.int64(2),
#  np.str_('25550.0'): np.int64(3),
#  np.str_('25600.0'): np.int64(6),
#  np.str_('25750.0'): np.int64(1),
#  np.str_('25800.0'): np.int64(3),
#  np.str_('25850.0'): np.int64(1),
#  np.str_('25900.0'): np.int64(1),
#  np.str_('25925.0'): np.int64(1),
#  np.str_('2600.0'): np.int64(4),
#  np.str_('26000.0'): np.int64(20),
#  np.str_('26125.0'): np.int64(2),
#  np.str_('26200.0'): np.int64(1),
#  np.str_('2625.0'): np.int64(3),
#  np.str_('26325.0'): np.int64(1),
#  np.str_('26375.0'): np.int64(4),
#  np.str_('26400.0'): np.int64(10),
#  np.str_('26425.0'): np.int64(1),
#  np.str_('26450.0'): np.int64(1),
#  np.str_('2650.0'): np.int64(1),
#  np.str_('26500.0'): np.int64(2),
#  np.str_('26525.0'): np.int64(2),
#  np.str_('26550.0'): np.int64(1),
#  np.str_('26575.0'): np.int64(2),
#  np.str_('26600.0'): np.int64(1),
#  np.str_('26625.0'): np.int64(1),
#  np.str_('26650.0'): np.int64(1),
#  np.str_('26675.0'): np.int64(1),
#  np.str_('2675.0'): np.int64(1),
#  np.str_('26750.0'): np.int64(2),
#  np.str_('26800.0'): np.int64(2),
#  np.str_('26825.0'): np.int64(2),
#  np.str_('26850.0'): np.int64(1),
#  np.str_('26950.0'): np.int64(1),
#  np.str_('26975.0'): np.int64(1),
#  np.str_('2700.0'): np.int64(3),
#  np.str_('27000.0'): np.int64(19),
#  np.str_('27050.0'): np.int64(2),
#  np.str_('27125.0'): np.int64(2),
#  np.str_('27200.0'): np.int64(8),
#  np.str_('27225.0'): np.int64(1),
#  np.str_('2725.0'): np.int64(1),
#  np.str_('27450.0'): np.int64(2),
#  np.str_('27500.0'): np.int64(7),
#  np.str_('27525.0'): np.int64(1),
#  np.str_('27575.0'): np.int64(4),
#  np.str_('27600.0'): np.int64(5),
#  np.str_('27625.0'): np.int64(1),
#  np.str_('2775.0'): np.int64(2),
#  np.str_('27750.0'): np.int64(1),
#  np.str_('27925.0'): np.int64(1),
#  np.str_('27950.0'): np.int64(1),
#  np.str_('27975.0'): np.int64(1),
#  np.str_('2800.0'): np.int64(11),
#  np.str_('28000.0'): np.int64(194),
#  np.str_('28250.0'): np.int64(2),
#  np.str_('28275.0'): np.int64(1),
#  np.str_('28375.0'): np.int64(1),
#  np.str_('28425.0'): np.int64(1),
#  np.str_('28450.0'): np.int64(1),
#  np.str_('28500.0'): np.int64(3),
#  np.str_('28550.0'): np.int64(1),
#  np.str_('28575.0'): np.int64(1),
#  np.str_('28600.0'): np.int64(3),
#  np.str_('2875.0'): np.int64(4),
#  np.str_('28775.0'): np.int64(2),
#  np.str_('28800.0'): np.int64(6),
#  np.str_('28825.0'): np.int64(1),
#  np.str_('28850.0'): np.int64(1),
#  np.str_('28875.0'): np.int64(1),
#  np.str_('28900.0'): np.int64(2),
#  np.str_('28925.0'): np.int64(1),
#  np.str_('28975.0'): np.int64(1),
#  np.str_('2900.0'): np.int64(3),
#  np.str_('29000.0'): np.int64(11),
#  np.str_('29300.0'): np.int64(1),
#  np.str_('29325.0'): np.int64(1),
#  np.str_('29400.0'): np.int64(3),
#  np.str_('2950.0'): np.int64(1),
#  np.str_('29500.0'): np.int64(1),
#  np.str_('29550.0'): np.int64(1),
#  np.str_('29575.0'): np.int64(1),
#  np.str_('29600.0'): np.int64(1),
#  np.str_('29625.0'): np.int64(1),
#  np.str_('29675.0'): np.int64(1),
#  np.str_('29700.0'): np.int64(1),
#  np.str_('2975.0'): np.int64(1),
#  np.str_('29850.0'): np.int64(3),
#  np.str_('29875.0'): np.int64(3),
#  np.str_('29900.0'): np.int64(1),
#  np.str_('29925.0'): np.int64(1),
#  np.str_('29950.0'): np.int64(1),
#  np.str_('29975.0'): np.int64(3),
#  np.str_('3000.0'): np.int64(87),
#  np.str_('30000.0'): np.int64(209),
#  np.str_('30400.0'): np.int64(1),
#  np.str_('30425.0'): np.int64(1),
#  np.str_('30450.0'): np.int64(1),
#  np.str_('3050.0'): np.int64(2),
#  np.str_('30500.0'): np.int64(1),
#  np.str_('30550.0'): np.int64(2),
#  np.str_('30725.0'): np.int64(1),
#  np.str_('3075.0'): np.int64(2),
#  np.str_('30750.0'): np.int64(2),
#  np.str_('30800.0'): np.int64(2),
#  np.str_('30825.0'): np.int64(1),
#  np.str_('3100.0'): np.int64(1),
#  np.str_('31000.0'): np.int64(4),
#  np.str_('31025.0'): np.int64(1),
#  np.str_('31075.0'): np.int64(2),
#  np.str_('31125.0'): np.int64(1),
#  np.str_('31150.0'): np.int64(1),
#  np.str_('31200.0'): np.int64(3),
#  np.str_('31275.0'): np.int64(1),
#  np.str_('31300.0'): np.int64(1),
#  np.str_('31475.0'): np.int64(1),
#  np.str_('3150.0'): np.int64(1),
#  np.str_('31500.0'): np.int64(5),
#  np.str_('31625.0'): np.int64(1),
#  np.str_('31825.0'): np.int64(1),
#  np.str_('31850.0'): np.int64(1),
#  np.str_('31950.0'): np.int64(1),
#  np.str_('31975.0'): np.int64(1),
#  np.str_('3200.0'): np.int64(15),
#  np.str_('32000.0'): np.int64(39),
#  np.str_('32225.0'): np.int64(1),
#  np.str_('3225.0'): np.int64(1),
#  np.str_('32425.0'): np.int64(1),
#  np.str_('32450.0'): np.int64(1),
#  np.str_('3250.0'): np.int64(6),
#  np.str_('32500.0'): np.int64(1),
#  np.str_('32525.0'): np.int64(1),
#  np.str_('32650.0'): np.int64(2),
#  np.str_('3275.0'): np.int64(4),
#  np.str_('32750.0'): np.int64(2),
#  np.str_('3300.0'): np.int64(1),
#  np.str_('33000.0'): np.int64(10),
#  np.str_('3325.0'): np.int64(1),
#  np.str_('33300.0'): np.int64(2),
#  np.str_('33425.0'): np.int64(3),
#  np.str_('33450.0'): np.int64(2),
#  np.str_('3350.0'): np.int64(1),
#  np.str_('33525.0'): np.int64(1),
#  np.str_('33550.0'): np.int64(1),
#  np.str_('33600.0'): np.int64(5),
#  np.str_('33700.0'): np.int64(1),
#  np.str_('33750.0'): np.int64(1),
#  np.str_('33975.0'): np.int64(1),
#  np.str_('3400.0'): np.int64(1),
#  np.str_('34000.0'): np.int64(11),
#  np.str_('34075.0'): np.int64(1),
#  np.str_('34100.0'): np.int64(1),
#  np.str_('34200.0'): np.int64(2),
#  np.str_('34375.0'): np.int64(1),
#  np.str_('34425.0'): np.int64(1),
#  np.str_('34475.0'): np.int64(1),
#  np.str_('3450.0'): np.int64(2),
#  np.str_('34500.0'): np.int64(4),
#  np.str_('34550.0'): np.int64(2),
#  np.str_('34675.0'): np.int64(1),
#  np.str_('34725.0'): np.int64(1),
#  np.str_('3475.0'): np.int64(1),
#  np.str_('34800.0'): np.int64(2),
#  np.str_('34875.0'): np.int64(1),
#  np.str_('3500.0'): np.int64(44),
#  np.str_('35000.0'): np.int64(443),
#  np.str_('3525.0'): np.int64(2),
#  np.str_('3550.0'): np.int64(2),
#  np.str_('3575.0'): np.int64(1),
#  np.str_('3600.0'): np.int64(31),
#  np.str_('3650.0'): np.int64(2),
#  np.str_('3700.0'): np.int64(5),
#  np.str_('3725.0'): np.int64(3),
#  np.str_('3750.0'): np.int64(2),
#  np.str_('3800.0'): np.int64(5),
#  np.str_('3850.0'): np.int64(1),
#  np.str_('3900.0'): np.int64(3),
#  np.str_('3925.0'): np.int64(1),
#  np.str_('3950.0'): np.int64(2),
#  np.str_('3975.0'): np.int64(2),
#  np.str_('4000.0'): np.int64(104),
#  np.str_('4025.0'): np.int64(2),
#  np.str_('4100.0'): np.int64(3),
#  np.str_('4125.0'): np.int64(1),
#  np.str_('4150.0'): np.int64(1),
#  np.str_('4175.0'): np.int64(3),
#  np.str_('4200.0'): np.int64(19),
#  np.str_('4225.0'): np.int64(1),
#  np.str_('4250.0'): np.int64(3),
#  np.str_('4300.0'): np.int64(1),
#  np.str_('4325.0'): np.int64(2),
#  np.str_('4350.0'): np.int64(1),
#  np.str_('4375.0'): np.int64(2),
#  np.str_('4400.0'): np.int64(3),
#  np.str_('4450.0'): np.int64(3),
#  np.str_('4475.0'): np.int64(2),
#  np.str_('4500.0'): np.int64(29),
#  np.str_('4525.0'): np.int64(2),
#  np.str_('4550.0'): np.int64(2),
#  np.str_('4575.0'): np.int64(2),
#  np.str_('4600.0'): np.int64(1),
#  np.str_('4625.0'): np.int64(1),
#  np.str_('4650.0'): np.int64(2),
#  np.str_('4700.0'): np.int64(2),
#  np.str_('4725.0'): np.int64(3),
#  np.str_('4750.0'): np.int64(4),
#  np.str_('4800.0'): np.int64(51),
#  np.str_('4825.0'): np.int64(1),
#  np.str_('4875.0'): np.int64(2),
#  np.str_('4900.0'): np.int64(3),
#  np.str_('4925.0'): np.int64(1),
#  np.str_('4950.0'): np.int64(5),
#  np.str_('4975.0'): np.int64(1),
#  np.str_('5000.0'): np.int64(299),
#  np.str_('5025.0'): np.int64(3),
#  np.str_('5050.0'): np.int64(7),
#  np.str_('5075.0'): np.int64(1),
#  np.str_('5100.0'): np.int64(5),
#  np.str_('5125.0'): np.int64(2),
#  np.str_('5150.0'): np.int64(1),
#  np.str_('5175.0'): np.int64(3),
#  np.str_('5200.0'): np.int64(6),
#  np.str_('5225.0'): np.int64(4),
#  np.str_('5250.0'): np.int64(1),
#  np.str_('5275.0'): np.int64(3),
#  np.str_('5300.0'): np.int64(4),
#  np.str_('5350.0'): np.int64(1),
#  np.str_('5400.0'): np.int64(7),
#  np.str_('5425.0'): np.int64(1),
#  np.str_('5450.0'): np.int64(1),
#  np.str_('5500.0'): np.int64(22),
#  np.str_('5525.0'): np.int64(1),
#  np.str_('5550.0'): np.int64(2),
#  np.str_('5575.0'): np.int64(1),
#  np.str_('5600.0'): np.int64(26),
#  np.str_('5650.0'): np.int64(3),
#  np.str_('5675.0'): np.int64(1),
#  np.str_('5700.0'): np.int64(3),
#  np.str_('5750.0'): np.int64(2),
#  np.str_('5775.0'): np.int64(2),
#  np.str_('5800.0'): np.int64(2),
#  np.str_('5825.0'): np.int64(3),
#  np.str_('5875.0'): np.int64(1),
#  np.str_('5900.0'): np.int64(2),
#  np.str_('5950.0'): np.int64(2),
#  np.str_('5975.0'): np.int64(1),
#  np.str_('6000.0'): np.int64(263),
#  np.str_('6025.0'): np.int64(5),
#  np.str_('6050.0'): np.int64(2),
#  np.str_('6075.0'): np.int64(1),
#  np.str_('6100.0'): np.int64(3),
#  np.str_('6125.0'): np.int64(2),
#  np.str_('6150.0'): np.int64(2),
#  np.str_('6200.0'): np.int64(6),
#  np.str_('6225.0'): np.int64(3),
#  np.str_('6250.0'): np.int64(3),
#  np.str_('6300.0'): np.int64(3),
#  np.str_('6325.0'): np.int64(2),
#  np.str_('6350.0'): np.int64(4),
#  np.str_('6375.0'): np.int64(2),
#  np.str_('6400.0'): np.int64(34),
#  np.str_('6425.0'): np.int64(3),
#  np.str_('6450.0'): np.int64(2),
#  np.str_('6475.0'): np.int64(2),
#  np.str_('6500.0'): np.int64(44),
#  np.str_('6550.0'): np.int64(1),
#  np.str_('6600.0'): np.int64(5),
#  np.str_('6650.0'): np.int64(2),
#  np.str_('6700.0'): np.int64(2),
#  np.str_('6725.0'): np.int64(3),
#  np.str_('6750.0'): np.int64(2),
#  np.str_('6775.0'): np.int64(2),
#  np.str_('6800.0'): np.int64(4),
#  np.str_('6825.0'): np.int64(1),
#  np.str_('6850.0'): np.int64(2),
#  np.str_('6875.0'): np.int64(1),
#  np.str_('6900.0'): np.int64(2),
#  np.str_('6925.0'): np.int64(1),
#  np.str_('7000.0'): np.int64(152),
#  np.str_('7025.0'): np.int64(2),
#  np.str_('7050.0'): np.int64(4),
#  np.str_('7075.0'): np.int64(2),
#  np.str_('7100.0'): np.int64(4),
#  np.str_('7125.0'): np.int64(4),
#  np.str_('7150.0'): np.int64(1),
#  np.str_('7200.0'): np.int64(69),
#  np.str_('7225.0'): np.int64(2),
#  np.str_('7250.0'): np.int64(5),
#  np.str_('7300.0'): np.int64(3),
#  np.str_('7325.0'): np.int64(2),
#  np.str_('7350.0'): np.int64(3),
#  np.str_('7375.0'): np.int64(1),
#  np.str_('7400.0'): np.int64(1),
#  np.str_('7425.0'): np.int64(2),
#  np.str_('7450.0'): np.int64(1),
#  np.str_('7475.0'): np.int64(1),
#  np.str_('7500.0'): np.int64(53),
#  np.str_('7525.0'): np.int64(1),
#  np.str_('7575.0'): np.int64(3),
#  np.str_('7600.0'): np.int64(5),
#  np.str_('7625.0'): np.int64(3),
#  np.str_('7650.0'): np.int64(2),
#  np.str_('7675.0'): np.int64(1),
#  np.str_('7700.0'): np.int64(4),
#  np.str_('7725.0'): np.int64(1),
#  np.str_('7800.0'): np.int64(19),
#  np.str_('7825.0'): np.int64(1),
#  np.str_('7850.0'): np.int64(3),
#  np.str_('7875.0'): np.int64(4),
#  np.str_('7900.0'): np.int64(9),
#  np.str_('7925.0'): np.int64(1),
#  np.str_('7950.0'): np.int64(3),
#  np.str_('7975.0'): np.int64(2),
#  np.str_('8000.0'): np.int64(306),
#  np.str_('8025.0'): np.int64(2),
#  np.str_('8075.0'): np.int64(6),
#  np.str_('8100.0'): np.int64(1),
#  np.str_('8125.0'): np.int64(3),
#  np.str_('8150.0'): np.int64(2),
#  np.str_('8200.0'): np.int64(4),
#  np.str_('8225.0'): np.int64(1),
#  np.str_('8250.0'): np.int64(3),
#  np.str_('8275.0'): np.int64(5),
#  np.str_('8300.0'): np.int64(4),
#  np.str_('8325.0'): np.int64(1),
#  np.str_('8350.0'): np.int64(3),
#  np.str_('8375.0'): np.int64(2),
#  np.str_('8400.0'): np.int64(43),
#  np.str_('8425.0'): np.int64(2),
#  np.str_('8450.0'): np.int64(1),
#  np.str_('8475.0'): np.int64(2),
#  np.str_('8500.0'): np.int64(38),
#  np.str_('8525.0'): np.int64(2),
#  np.str_('8550.0'): np.int64(2),
#  np.str_('8600.0'): np.int64(2),
#  np.str_('8625.0'): np.int64(1),
#  np.str_('8650.0'): np.int64(4),
#  np.str_('8675.0'): np.int64(2),
#  np.str_('8700.0'): np.int64(2),
#  np.str_('8725.0'): np.int64(1),
#  np.str_('8750.0'): np.int64(2),
#  np.str_('8775.0'): np.int64(3),
#  np.str_('8800.0'): np.int64(10),
#  np.str_('8850.0'): np.int64(2),
#  np.str_('8875.0'): np.int64(5),
#  np.str_('8900.0'): np.int64(1),
#  np.str_('8925.0'): np.int64(1),
#  np.str_('8950.0'): np.int64(4),
#  np.str_('8975.0'): np.int64(1),
#  np.str_('9000.0'): np.int64(100),
#  np.str_('9025.0'): np.int64(4),
#  np.str_('9075.0'): np.int64(1),
#  np.str_('9100.0'): np.int64(4),
#  np.str_('9125.0'): np.int64(2),
#  np.str_('9150.0'): np.int64(3),
#  np.str_('9175.0'): np.int64(4),
#  np.str_('9200.0'): np.int64(3),
#  np.str_('9225.0'): np.int64(2),
#  np.str_('9250.0'): np.int64(5),
#  np.str_('9275.0'): np.int64(2),
#  np.str_('9300.0'): np.int64(1),
#  np.str_('9350.0'): np.int64(3),
#  np.str_('9375.0'): np.int64(3),
#  np.str_('9400.0'): np.int64(3),
#  np.str_('9425.0'): np.int64(3),
#  np.str_('9450.0'): np.int64(5),
#  np.str_('9500.0'): np.int64(19),
#  np.str_('9525.0'): np.int64(3),
#  np.str_('9550.0'): np.int64(1),
#  np.str_('9575.0'): np.int64(3),
#  np.str_('9600.0'): np.int64(70),
#  np.str_('9650.0'): np.int64(2),
#  np.str_('9675.0'): np.int64(2),
#  np.str_('9700.0'): np.int64(4),
#  np.str_('9725.0'): np.int64(2),
#  np.str_('9775.0'): np.int64(1),
#  np.str_('9800.0'): np.int64(15),
#  np.str_('9825.0'): np.int64(1),
#  np.str_('9900.0'): np.int64(3),
#  np.str_('9925.0'): np.int64(1),
#  np.str_('9950.0'): np.int64(3),
#  np.str_('9975.0'): np.int64(5)}

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'loan_amnt' se observa lo siguiente:
#
# - Los registros proporcionados corresponden al monto de los préstamos asociados a cada solicitud contenida en la base de datos.
# - Los valores almacenados representan cantidades numéricas y, por tanto, pueden ser tratados como datos de tipo flotante para facilitar su análisis y procesamiento.
# - Se detectan 500 registros en los que el monto del préstamo no fue almacenado correctamente, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron valores con formatos atípicos o inconsistentes en comparación con el resto de los registros de esta categoría, lo que indica una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.
# - Convertir los valores válidos de la categoría desde cadenas de texto a un tipo de dato numérico (por ejemplo, float), permitiendo la aplicación de técnicas estadísticas y de análisis cuantitativo sobre esta variable.

# %% [markdown]
# ### Categoría 'loan_status'

# %% [markdown]
# Categoría que contiene el estado actual del préstamo realizado.

# %%
caracteristicas_data[label_data[3]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('Charged Off'): np.int64(61),
#  np.str_('Current'): np.int64(8538),
#  np.str_('Default'): np.int64(11),
#  np.str_('Fully Paid'): np.int64(505),
#  np.str_('In Grace Period'): np.int64(56),
#  np.str_('Issued'): np.int64(184),
#  np.str_('Late (16-30 days)'): np.int64(30),
#  np.str_('Late (31-120 days)'): np.int64(115)}

# %% [markdown]
# Las categorías identificadas son las siguientes:
#
# - Fully Paid: El préstamo fue liquidado en su totalidad.
# - Issued: El préstamo ha sido aprobado y emitido recientemente.
# - Current: El préstamo se encuentra activo y los pagos se realizan conforme a lo establecido.
# - In Grace Period: El préstamo se encuentra dentro del período de gracia permitido para regularizar pagos atrasados.
# - Default: El préstamo ha entrado en incumplimiento de pago.
# - Late (16-30 days): El préstamo presenta un retraso en los pagos de entre 16 y 30 días.
# - Late (31-120 days): El préstamo presenta un retraso en los pagos de entre 31 y 120 días.
# - Charged Off: El préstamo ha sido clasificado como incobrable por la entidad financiera.
#
# Del análisis de los datos contenidos en la categoría 'loan_status' se observa lo siguiente:
#
# - Los registros proporcionados describen el estado asociado a cada préstamo contenido en la base de datos.
# - Los valores almacenados corresponden a categorías cualitativas y, por tanto, pueden ser representados mediante cadenas de texto.
# - Se detectan 500 registros en los que el estado del préstamo no fue registrado adecuadamente, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.
# - Considerar la creación de una categoría adicional que agrupe los estados asociados a incumplimiento o mora (por ejemplo, Default, Charged Off y categorías Late), en caso de que la variable vaya a emplearse posteriormente en tareas de análisis de riesgo o modelado predictivo.

# %% [markdown]
# ### Categoría 'funded_amnt'

# %% [markdown]
# Esta categoría representa el monto total comprometido para el préstamo en el momento de su aprobación. El valor registrado puede diferir del monto inicialmente solicitado por el prestatario, ya que la entidad financiera puede realizar ajustes durante el proceso de evaluación crediticia. En consecuencia, esta variable refleja el importe efectivamente aprobado para el préstamo en el instante de su emisión.

# %%
caracteristicas_data[label_data[4]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('1000.0'): np.int64(28),
#  np.str_('10000.0'): np.int64(628),
#  np.str_('10025.0'): np.int64(1),
#  np.str_('10050.0'): np.int64(3),
#  np.str_('10075.0'): np.int64(1),
#  np.str_('10100.0'): np.int64(4),
#  np.str_('10150.0'): np.int64(3),
#  np.str_('10175.0'): np.int64(1),
#  np.str_('10200.0'): np.int64(13),
#  np.str_('10225.0'): np.int64(1),
#  np.str_('10250.0'): np.int64(3),
#  np.str_('10300.0'): np.int64(2),
#  np.str_('10325.0'): np.int64(3),
#  np.str_('10350.0'): np.int64(1),
#  np.str_('10375.0'): np.int64(3),
#  np.str_('10400.0'): np.int64(16),
#  np.str_('10425.0'): np.int64(4),
#  np.str_('10475.0'): np.int64(1),
#  np.str_('10500.0'): np.int64(31),
#  np.str_('10525.0'): np.int64(5),
#  np.str_('10550.0'): np.int64(6),
#  np.str_('10575.0'): np.int64(2),
#  np.str_('10600.0'): np.int64(3),
#  np.str_('10625.0'): np.int64(1),
#  np.str_('10650.0'): np.int64(2),
#  np.str_('10700.0'): np.int64(6),
#  np.str_('10725.0'): np.int64(3),
#  np.str_('10750.0'): np.int64(2),
#  np.str_('10775.0'): np.int64(6),
#  np.str_('10800.0'): np.int64(40),
#  np.str_('10825.0'): np.int64(3),
#  np.str_('10850.0'): np.int64(1),
#  np.str_('10875.0'): np.int64(4),
#  np.str_('10900.0'): np.int64(3),
#  np.str_('10925.0'): np.int64(1),
#  np.str_('10950.0'): np.int64(2),
#  np.str_('10975.0'): np.int64(4),
#  np.str_('1100.0'): np.int64(2),
#  np.str_('11000.0'): np.int64(82),
#  np.str_('11025.0'): np.int64(1),
#  np.str_('11075.0'): np.int64(3),
#  np.str_('11100.0'): np.int64(3),
#  np.str_('11125.0'): np.int64(5),
#  np.str_('11150.0'): np.int64(4),
#  np.str_('11175.0'): np.int64(1),
#  np.str_('11200.0'): np.int64(59),
#  np.str_('11225.0'): np.int64(2),
#  np.str_('11250.0'): np.int64(7),
#  np.str_('11275.0'): np.int64(3),
#  np.str_('11300.0'): np.int64(7),
#  np.str_('11325.0'): np.int64(3),
#  np.str_('11350.0'): np.int64(1),
#  np.str_('11375.0'): np.int64(1),
#  np.str_('11400.0'): np.int64(15),
#  np.str_('11425.0'): np.int64(3),
#  np.str_('11450.0'): np.int64(1),
#  np.str_('11500.0'): np.int64(16),
#  np.str_('11550.0'): np.int64(2),
#  np.str_('11575.0'): np.int64(1),
#  np.str_('11600.0'): np.int64(3),
#  np.str_('11625.0'): np.int64(4),
#  np.str_('11650.0'): np.int64(3),
#  np.str_('11675.0'): np.int64(1),
#  np.str_('11700.0'): np.int64(3),
#  np.str_('11725.0'): np.int64(3),
#  np.str_('1175.0'): np.int64(1),
#  np.str_('11750.0'): np.int64(5),
#  np.str_('11775.0'): np.int64(3),
#  np.str_('11800.0'): np.int64(4),
#  np.str_('11825.0'): np.int64(2),
#  np.str_('11850.0'): np.int64(4),
#  np.str_('11875.0'): np.int64(6),
#  np.str_('11900.0'): np.int64(3),
#  np.str_('11925.0'): np.int64(5),
#  np.str_('11950.0'): np.int64(3),
#  np.str_('11975.0'): np.int64(5),
#  np.str_('1200.0'): np.int64(10),
#  np.str_('12000.0'): np.int64(584),
#  np.str_('12050.0'): np.int64(1),
#  np.str_('12075.0'): np.int64(2),
#  np.str_('12100.0'): np.int64(2),
#  np.str_('12150.0'): np.int64(2),
#  np.str_('12175.0'): np.int64(1),
#  np.str_('12200.0'): np.int64(2),
#  np.str_('12225.0'): np.int64(3),
#  np.str_('1225.0'): np.int64(1),
#  np.str_('12250.0'): np.int64(2),
#  np.str_('12275.0'): np.int64(1),
#  np.str_('12300.0'): np.int64(3),
#  np.str_('12325.0'): np.int64(1),
#  np.str_('12350.0'): np.int64(1),
#  np.str_('12375.0'): np.int64(1),
#  np.str_('12400.0'): np.int64(1),
#  np.str_('12425.0'): np.int64(5),
#  np.str_('12450.0'): np.int64(3),
#  np.str_('12500.0'): np.int64(22),
#  np.str_('12525.0'): np.int64(3),
#  np.str_('12550.0'): np.int64(2),
#  np.str_('12575.0'): np.int64(4),
#  np.str_('12600.0'): np.int64(8),
#  np.str_('12625.0'): np.int64(1),
#  np.str_('12675.0'): np.int64(1),
#  np.str_('12700.0'): np.int64(2),
#  np.str_('12725.0'): np.int64(3),
#  np.str_('12750.0'): np.int64(3),
#  np.str_('12775.0'): np.int64(2),
#  np.str_('12800.0'): np.int64(26),
#  np.str_('12825.0'): np.int64(1),
#  np.str_('12850.0'): np.int64(3),
#  np.str_('12900.0'): np.int64(3),
#  np.str_('12925.0'): np.int64(1),
#  np.str_('12950.0'): np.int64(3),
#  np.str_('12975.0'): np.int64(5),
#  np.str_('13000.0'): np.int64(69),
#  np.str_('13025.0'): np.int64(3),
#  np.str_('13050.0'): np.int64(1),
#  np.str_('13075.0'): np.int64(1),
#  np.str_('13125.0'): np.int64(3),
#  np.str_('13150.0'): np.int64(5),
#  np.str_('13175.0'): np.int64(2),
#  np.str_('13200.0'): np.int64(19),
#  np.str_('13225.0'): np.int64(3),
#  np.str_('1325.0'): np.int64(1),
#  np.str_('13250.0'): np.int64(2),
#  np.str_('13300.0'): np.int64(2),
#  np.str_('13325.0'): np.int64(2),
#  np.str_('13350.0'): np.int64(2),
#  np.str_('13375.0'): np.int64(4),
#  np.str_('13425.0'): np.int64(3),
#  np.str_('13450.0'): np.int64(4),
#  np.str_('13475.0'): np.int64(2),
#  np.str_('13500.0'): np.int64(20),
#  np.str_('13525.0'): np.int64(2),
#  np.str_('13550.0'): np.int64(1),
#  np.str_('13600.0'): np.int64(8),
#  np.str_('13625.0'): np.int64(4),
#  np.str_('13675.0'): np.int64(2),
#  np.str_('13700.0'): np.int64(3),
#  np.str_('13750.0'): np.int64(3),
#  np.str_('13775.0'): np.int64(3),
#  np.str_('13800.0'): np.int64(3),
#  np.str_('13825.0'): np.int64(3),
#  np.str_('13850.0'): np.int64(2),
#  np.str_('13900.0'): np.int64(2),
#  np.str_('13925.0'): np.int64(3),
#  np.str_('13950.0'): np.int64(1),
#  np.str_('13975.0'): np.int64(1),
#  np.str_('1400.0'): np.int64(5),
#  np.str_('14000.0'): np.int64(178),
#  np.str_('14025.0'): np.int64(2),
#  np.str_('14050.0'): np.int64(3),
#  np.str_('14075.0'): np.int64(2),
#  np.str_('14100.0'): np.int64(3),
#  np.str_('14125.0'): np.int64(2),
#  np.str_('14175.0'): np.int64(1),
#  np.str_('14225.0'): np.int64(2),
#  np.str_('14250.0'): np.int64(1),
#  np.str_('14275.0'): np.int64(2),
#  np.str_('14325.0'): np.int64(2),
#  np.str_('14350.0'): np.int64(3),
#  np.str_('14375.0'): np.int64(2),
#  np.str_('14400.0'): np.int64(54),
#  np.str_('14425.0'): np.int64(2),
#  np.str_('14450.0'): np.int64(1),
#  np.str_('14475.0'): np.int64(2),
#  np.str_('1450.0'): np.int64(3),
#  np.str_('14500.0'): np.int64(9),
#  np.str_('14525.0'): np.int64(5),
#  np.str_('14550.0'): np.int64(3),
#  np.str_('14575.0'): np.int64(1),
#  np.str_('14600.0'): np.int64(2),
#  np.str_('14650.0'): np.int64(1),
#  np.str_('14675.0'): np.int64(3),
#  np.str_('14700.0'): np.int64(9),
#  np.str_('14750.0'): np.int64(3),
#  np.str_('14800.0'): np.int64(1),
#  np.str_('14825.0'): np.int64(2),
#  np.str_('14875.0'): np.int64(1),
#  np.str_('14900.0'): np.int64(4),
#  np.str_('14950.0'): np.int64(5),
#  np.str_('14975.0'): np.int64(4),
#  np.str_('1500.0'): np.int64(13),
#  np.str_('15000.0'): np.int64(537),
#  np.str_('15025.0'): np.int64(1),
#  np.str_('15050.0'): np.int64(3),
#  np.str_('15075.0'): np.int64(2),
#  np.str_('15100.0'): np.int64(2),
#  np.str_('15125.0'): np.int64(3),
#  np.str_('15150.0'): np.int64(1),
#  np.str_('15175.0'): np.int64(1),
#  np.str_('15200.0'): np.int64(10),
#  np.str_('15250.0'): np.int64(4),
#  np.str_('15275.0'): np.int64(1),
#  np.str_('15300.0'): np.int64(3),
#  np.str_('15325.0'): np.int64(1),
#  np.str_('15400.0'): np.int64(9),
#  np.str_('15425.0'): np.int64(2),
#  np.str_('15450.0'): np.int64(2),
#  np.str_('15475.0'): np.int64(2),
#  np.str_('15500.0'): np.int64(14),
#  np.str_('15525.0'): np.int64(3),
#  np.str_('15550.0'): np.int64(3),
#  np.str_('15600.0'): np.int64(19),
#  np.str_('15625.0'): np.int64(4),
#  np.str_('15700.0'): np.int64(1),
#  np.str_('15750.0'): np.int64(2),
#  np.str_('15775.0'): np.int64(2),
#  np.str_('15800.0'): np.int64(1),
#  np.str_('15850.0'): np.int64(3),
#  np.str_('15875.0'): np.int64(2),
#  np.str_('15925.0'): np.int64(2),
#  np.str_('15950.0'): np.int64(3),
#  np.str_('1600.0'): np.int64(9),
#  np.str_('16000.0'): np.int64(247),
#  np.str_('16025.0'): np.int64(2),
#  np.str_('16050.0'): np.int64(1),
#  np.str_('16075.0'): np.int64(2),
#  np.str_('16100.0'): np.int64(4),
#  np.str_('16150.0'): np.int64(5),
#  np.str_('16200.0'): np.int64(4),
#  np.str_('16225.0'): np.int64(1),
#  np.str_('16250.0'): np.int64(1),
#  np.str_('16300.0'): np.int64(3),
#  np.str_('16325.0'): np.int64(2),
#  np.str_('16350.0'): np.int64(1),
#  np.str_('16375.0'): np.int64(3),
#  np.str_('16400.0'): np.int64(2),
#  np.str_('16425.0'): np.int64(1),
#  np.str_('16450.0'): np.int64(3),
#  np.str_('1650.0'): np.int64(1),
#  np.str_('16500.0'): np.int64(15),
#  np.str_('16525.0'): np.int64(1),
#  np.str_('16550.0'): np.int64(2),
#  np.str_('16575.0'): np.int64(1),
#  np.str_('16600.0'): np.int64(3),
#  np.str_('16625.0'): np.int64(1),
#  np.str_('16675.0'): np.int64(1),
#  np.str_('16700.0'): np.int64(4),
#  np.str_('16725.0'): np.int64(1),
#  np.str_('1675.0'): np.int64(1),
#  np.str_('16750.0'): np.int64(3),
#  np.str_('16775.0'): np.int64(1),
#  np.str_('16800.0'): np.int64(25),
#  np.str_('16850.0'): np.int64(1),
#  np.str_('16875.0'): np.int64(2),
#  np.str_('16925.0'): np.int64(1),
#  np.str_('16950.0'): np.int64(3),
#  np.str_('17000.0'): np.int64(60),
#  np.str_('17050.0'): np.int64(3),
#  np.str_('17100.0'): np.int64(7),
#  np.str_('17125.0'): np.int64(3),
#  np.str_('17150.0'): np.int64(1),
#  np.str_('17200.0'): np.int64(5),
#  np.str_('17225.0'): np.int64(1),
#  np.str_('1725.0'): np.int64(1),
#  np.str_('17250.0'): np.int64(1),
#  np.str_('17275.0'): np.int64(2),
#  np.str_('17300.0'): np.int64(1),
#  np.str_('17325.0'): np.int64(2),
#  np.str_('17350.0'): np.int64(1),
#  np.str_('17400.0'): np.int64(3),
#  np.str_('17425.0'): np.int64(4),
#  np.str_('17475.0'): np.int64(1),
#  np.str_('1750.0'): np.int64(1),
#  np.str_('17500.0'): np.int64(27),
#  np.str_('17550.0'): np.int64(2),
#  np.str_('17600.0'): np.int64(7),
#  np.str_('17625.0'): np.int64(5),
#  np.str_('17650.0'): np.int64(1),
#  np.str_('17675.0'): np.int64(1),
#  np.str_('17700.0'): np.int64(1),
#  np.str_('17725.0'): np.int64(1),
#  np.str_('17775.0'): np.int64(1),
#  np.str_('17800.0'): np.int64(2),
#  np.str_('17825.0'): np.int64(2),
#  np.str_('17850.0'): np.int64(3),
#  np.str_('17900.0'): np.int64(4),
#  np.str_('17925.0'): np.int64(1),
#  np.str_('17950.0'): np.int64(1),
#  np.str_('17975.0'): np.int64(2),
#  np.str_('1800.0'): np.int64(6),
#  np.str_('18000.0'): np.int64(250),
#  np.str_('18025.0'): np.int64(4),
#  np.str_('18050.0'): np.int64(2),
#  np.str_('18075.0'): np.int64(1),
#  np.str_('18100.0'): np.int64(2),
#  np.str_('18150.0'): np.int64(4),
#  np.str_('18200.0'): np.int64(4),
#  np.str_('18225.0'): np.int64(1),
#  np.str_('18250.0'): np.int64(2),
#  np.str_('18275.0'): np.int64(1),
#  np.str_('18300.0'): np.int64(1),
#  np.str_('18325.0'): np.int64(2),
#  np.str_('18350.0'): np.int64(7),
#  np.str_('18375.0'): np.int64(1),
#  np.str_('18400.0'): np.int64(8),
#  np.str_('18425.0'): np.int64(2),
#  np.str_('18450.0'): np.int64(4),
#  np.str_('18475.0'): np.int64(3),
#  np.str_('18500.0'): np.int64(15),
#  np.str_('18600.0'): np.int64(1),
#  np.str_('18625.0'): np.int64(1),
#  np.str_('18650.0'): np.int64(1),
#  np.str_('18675.0'): np.int64(2),
#  np.str_('18700.0'): np.int64(2),
#  np.str_('1875.0'): np.int64(1),
#  np.str_('18750.0'): np.int64(1),
#  np.str_('18800.0'): np.int64(3),
#  np.str_('18825.0'): np.int64(2),
#  np.str_('18850.0'): np.int64(2),
#  np.str_('18900.0'): np.int64(6),
#  np.str_('18925.0'): np.int64(1),
#  np.str_('18950.0'): np.int64(1),
#  np.str_('1900.0'): np.int64(2),
#  np.str_('19000.0'): np.int64(32),
#  np.str_('19025.0'): np.int64(2),
#  np.str_('19050.0'): np.int64(2),
#  np.str_('19075.0'): np.int64(2),
#  np.str_('19100.0'): np.int64(2),
#  np.str_('19125.0'): np.int64(1),
#  np.str_('19150.0'): np.int64(2),
#  np.str_('19175.0'): np.int64(1),
#  np.str_('19200.0'): np.int64(42),
#  np.str_('19225.0'): np.int64(1),
#  np.str_('19250.0'): np.int64(2),
#  np.str_('19275.0'): np.int64(3),
#  np.str_('19325.0'): np.int64(2),
#  np.str_('19350.0'): np.int64(1),
#  np.str_('19375.0'): np.int64(2),
#  np.str_('19400.0'): np.int64(1),
#  np.str_('19425.0'): np.int64(1),
#  np.str_('19475.0'): np.int64(3),
#  np.str_('1950.0'): np.int64(1),
#  np.str_('19500.0'): np.int64(3),
#  np.str_('19525.0'): np.int64(1),
#  np.str_('19575.0'): np.int64(2),
#  np.str_('19600.0'): np.int64(3),
#  np.str_('19650.0'): np.int64(2),
#  np.str_('19725.0'): np.int64(2),
#  np.str_('19750.0'): np.int64(2),
#  np.str_('19775.0'): np.int64(3),
#  np.str_('19800.0'): np.int64(10),
#  np.str_('19825.0'): np.int64(1),
#  np.str_('19850.0'): np.int64(1),
#  np.str_('19875.0'): np.int64(3),
#  np.str_('19925.0'): np.int64(2),
#  np.str_('19950.0'): np.int64(3),
#  np.str_('2000.0'): np.int64(42),
#  np.str_('20000.0'): np.int64(569),
#  np.str_('20025.0'): np.int64(1),
#  np.str_('20050.0'): np.int64(4),
#  np.str_('20100.0'): np.int64(1),
#  np.str_('20125.0'): np.int64(2),
#  np.str_('20150.0'): np.int64(5),
#  np.str_('20200.0'): np.int64(1),
#  np.str_('20225.0'): np.int64(4),
#  np.str_('20250.0'): np.int64(1),
#  np.str_('20300.0'): np.int64(1),
#  np.str_('20325.0'): np.int64(1),
#  np.str_('20400.0'): np.int64(14),
#  np.str_('20425.0'): np.int64(2),
#  np.str_('20450.0'): np.int64(1),
#  np.str_('20475.0'): np.int64(4),
#  np.str_('20500.0'): np.int64(6),
#  np.str_('20550.0'): np.int64(1),
#  np.str_('20575.0'): np.int64(1),
#  np.str_('20600.0'): np.int64(4),
#  np.str_('20625.0'): np.int64(2),
#  np.str_('20675.0'): np.int64(2),
#  np.str_('20700.0'): np.int64(7),
#  np.str_('20725.0'): np.int64(1),
#  np.str_('20750.0'): np.int64(3),
#  np.str_('20800.0'): np.int64(2),
#  np.str_('20850.0'): np.int64(1),
#  np.str_('20875.0'): np.int64(1),
#  np.str_('20925.0'): np.int64(1),
#  np.str_('20950.0'): np.int64(5),
#  np.str_('20975.0'): np.int64(3),
#  np.str_('2100.0'): np.int64(3),
#  np.str_('21000.0'): np.int64(145),
#  np.str_('21050.0'): np.int64(3),
#  np.str_('21075.0'): np.int64(1),
#  np.str_('21100.0'): np.int64(3),
#  np.str_('21125.0'): np.int64(1),
#  np.str_('21150.0'): np.int64(1),
#  np.str_('21175.0'): np.int64(3),
#  np.str_('21200.0'): np.int64(1),
#  np.str_('21225.0'): np.int64(1),
#  np.str_('21275.0'): np.int64(2),
#  np.str_('21300.0'): np.int64(3),
#  np.str_('21325.0'): np.int64(1),
#  np.str_('21350.0'): np.int64(1),
#  np.str_('21400.0'): np.int64(1),
#  np.str_('21450.0'): np.int64(1),
#  np.str_('21500.0'): np.int64(7),
#  np.str_('21550.0'): np.int64(2),
#  np.str_('21575.0'): np.int64(2),
#  np.str_('21600.0'): np.int64(23),
#  np.str_('21625.0'): np.int64(1),
#  np.str_('21650.0'): np.int64(1),
#  np.str_('21700.0'): np.int64(1),
#  np.str_('21750.0'): np.int64(4),
#  np.str_('21800.0'): np.int64(1),
#  np.str_('21825.0'): np.int64(2),
#  np.str_('21850.0'): np.int64(2),
#  np.str_('21875.0'): np.int64(1),
#  np.str_('21900.0'): np.int64(1),
#  np.str_('21925.0'): np.int64(1),
#  np.str_('21975.0'): np.int64(1),
#  np.str_('2200.0'): np.int64(5),
#  np.str_('22000.0'): np.int64(60),
#  np.str_('22025.0'): np.int64(1),
#  np.str_('22075.0'): np.int64(2),
#  np.str_('22125.0'): np.int64(1),
#  np.str_('22150.0'): np.int64(1),
#  np.str_('22200.0'): np.int64(3),
#  np.str_('22225.0'): np.int64(3),
#  np.str_('22250.0'): np.int64(1),
#  np.str_('22375.0'): np.int64(1),
#  np.str_('22400.0'): np.int64(22),
#  np.str_('22425.0'): np.int64(1),
#  np.str_('22450.0'): np.int64(1),
#  np.str_('22475.0'): np.int64(1),
#  np.str_('2250.0'): np.int64(2),
#  np.str_('22500.0'): np.int64(5),
#  np.str_('22525.0'): np.int64(1),
#  np.str_('22575.0'): np.int64(1),
#  np.str_('22600.0'): np.int64(2),
#  np.str_('22625.0'): np.int64(1),
#  np.str_('22675.0'): np.int64(1),
#  np.str_('22700.0'): np.int64(1),
#  np.str_('22725.0'): np.int64(1),
#  np.str_('22750.0'): np.int64(2),
#  np.str_('22775.0'): np.int64(1),
#  np.str_('22800.0'): np.int64(10),
#  np.str_('22825.0'): np.int64(1),
#  np.str_('22850.0'): np.int64(1),
#  np.str_('22875.0'): np.int64(3),
#  np.str_('22900.0'): np.int64(2),
#  np.str_('22925.0'): np.int64(1),
#  np.str_('22950.0'): np.int64(5),
#  np.str_('2300.0'): np.int64(2),
#  np.str_('23000.0'): np.int64(40),
#  np.str_('23050.0'): np.int64(2),
#  np.str_('23100.0'): np.int64(4),
#  np.str_('23175.0'): np.int64(1),
#  np.str_('23200.0'): np.int64(2),
#  np.str_('23225.0'): np.int64(3),
#  np.str_('23275.0'): np.int64(1),
#  np.str_('23350.0'): np.int64(3),
#  np.str_('23375.0'): np.int64(2),
#  np.str_('23400.0'): np.int64(2),
#  np.str_('23425.0'): np.int64(1),
#  np.str_('23475.0'): np.int64(1),
#  np.str_('2350.0'): np.int64(1),
#  np.str_('23500.0'): np.int64(4),
#  np.str_('23525.0'): np.int64(1),
#  np.str_('23550.0'): np.int64(1),
#  np.str_('23575.0'): np.int64(1),
#  np.str_('23600.0'): np.int64(1),
#  np.str_('23625.0'): np.int64(1),
#  np.str_('23650.0'): np.int64(1),
#  np.str_('23700.0'): np.int64(2),
#  np.str_('23750.0'): np.int64(3),
#  np.str_('23800.0'): np.int64(1),
#  np.str_('23825.0'): np.int64(1),
#  np.str_('23875.0'): np.int64(3),
#  np.str_('23900.0'): np.int64(1),
#  np.str_('23925.0'): np.int64(2),
#  np.str_('23950.0'): np.int64(2),
#  np.str_('23975.0'): np.int64(3),
#  np.str_('2400.0'): np.int64(23),
#  np.str_('24000.0'): np.int64(255),
#  np.str_('24200.0'): np.int64(5),
#  np.str_('24225.0'): np.int64(2),
#  np.str_('24300.0'): np.int64(2),
#  np.str_('24350.0'): np.int64(1),
#  np.str_('24375.0'): np.int64(2),
#  np.str_('24425.0'): np.int64(2),
#  np.str_('24475.0'): np.int64(2),
#  np.str_('24500.0'): np.int64(3),
#  np.str_('24525.0'): np.int64(2),
#  np.str_('24600.0'): np.int64(3),
#  np.str_('24625.0'): np.int64(2),
#  np.str_('24650.0'): np.int64(3),
#  np.str_('24700.0'): np.int64(3),
#  np.str_('24725.0'): np.int64(1),
#  np.str_('24750.0'): np.int64(1),
#  np.str_('24800.0'): np.int64(2),
#  np.str_('24825.0'): np.int64(1),
#  np.str_('24850.0'): np.int64(1),
#  np.str_('24925.0'): np.int64(2),
#  np.str_('24950.0'): np.int64(3),
#  np.str_('24975.0'): np.int64(2),
#  np.str_('2500.0'): np.int64(23),
#  np.str_('25000.0'): np.int64(301),
#  np.str_('25075.0'): np.int64(1),
#  np.str_('25125.0'): np.int64(2),
#  np.str_('25150.0'): np.int64(1),
#  np.str_('25200.0'): np.int64(5),
#  np.str_('2525.0'): np.int64(1),
#  np.str_('25250.0'): np.int64(1),
#  np.str_('25300.0'): np.int64(2),
#  np.str_('25325.0'): np.int64(2),
#  np.str_('25375.0'): np.int64(1),
#  np.str_('25400.0'): np.int64(1),
#  np.str_('25425.0'): np.int64(1),
#  np.str_('25450.0'): np.int64(1),
#  np.str_('25500.0'): np.int64(2),
#  np.str_('25550.0'): np.int64(3),
#  np.str_('25600.0'): np.int64(5),
#  np.str_('25750.0'): np.int64(1),
#  np.str_('25800.0'): np.int64(3),
#  np.str_('25850.0'): np.int64(1),
#  np.str_('25900.0'): np.int64(1),
#  np.str_('25925.0'): np.int64(1),
#  np.str_('2600.0'): np.int64(4),
#  np.str_('26000.0'): np.int64(18),
#  np.str_('26050.0'): np.int64(1),
#  np.str_('26125.0'): np.int64(2),
#  np.str_('26200.0'): np.int64(1),
#  np.str_('2625.0'): np.int64(3),
#  np.str_('26325.0'): np.int64(1),
#  np.str_('26375.0'): np.int64(4),
#  np.str_('26400.0'): np.int64(9),
#  np.str_('26425.0'): np.int64(1),
#  np.str_('26450.0'): np.int64(1),
#  np.str_('2650.0'): np.int64(1),
#  np.str_('26500.0'): np.int64(2),
#  np.str_('26525.0'): np.int64(1),
#  np.str_('26550.0'): np.int64(1),
#  np.str_('26575.0'): np.int64(2),
#  np.str_('26600.0'): np.int64(2),
#  np.str_('26625.0'): np.int64(1),
#  np.str_('26650.0'): np.int64(1),
#  np.str_('26675.0'): np.int64(1),
#  np.str_('2675.0'): np.int64(1),
#  np.str_('26750.0'): np.int64(3),
#  np.str_('26800.0'): np.int64(2),
#  np.str_('26825.0'): np.int64(2),
#  np.str_('26850.0'): np.int64(1),
#  np.str_('26950.0'): np.int64(1),
#  np.str_('26975.0'): np.int64(1),
#  np.str_('2700.0'): np.int64(3),
#  np.str_('27000.0'): np.int64(22),
#  np.str_('27050.0'): np.int64(2),
#  np.str_('27125.0'): np.int64(2),
#  np.str_('27200.0'): np.int64(9),
#  np.str_('27225.0'): np.int64(1),
#  np.str_('27450.0'): np.int64(1),
#  np.str_('27500.0'): np.int64(7),
#  np.str_('27525.0'): np.int64(1),
#  np.str_('27575.0'): np.int64(4),
#  np.str_('27600.0'): np.int64(6),
#  np.str_('27625.0'): np.int64(1),
#  np.str_('2775.0'): np.int64(2),
#  np.str_('27750.0'): np.int64(1),
#  np.str_('27925.0'): np.int64(1),
#  np.str_('27975.0'): np.int64(1),
#  np.str_('2800.0'): np.int64(12),
#  np.str_('28000.0'): np.int64(196),
#  np.str_('28250.0'): np.int64(2),
#  np.str_('28275.0'): np.int64(1),
#  np.str_('28375.0'): np.int64(1),
#  np.str_('28425.0'): np.int64(1),
#  np.str_('28450.0'): np.int64(1),
#  np.str_('28500.0'): np.int64(3),
#  np.str_('28550.0'): np.int64(1),
#  np.str_('28575.0'): np.int64(1),
#  np.str_('28600.0'): np.int64(3),
#  np.str_('2875.0'): np.int64(4),
#  np.str_('28775.0'): np.int64(2),
#  np.str_('28800.0'): np.int64(7),
#  np.str_('28825.0'): np.int64(1),
#  np.str_('28850.0'): np.int64(1),
#  np.str_('28875.0'): np.int64(1),
#  np.str_('28900.0'): np.int64(1),
#  np.str_('28925.0'): np.int64(1),
#  np.str_('28975.0'): np.int64(1),
#  np.str_('2900.0'): np.int64(2),
#  np.str_('29000.0'): np.int64(11),
#  np.str_('29300.0'): np.int64(1),
#  np.str_('29400.0'): np.int64(3),
#  np.str_('2950.0'): np.int64(1),
#  np.str_('29500.0'): np.int64(1),
#  np.str_('29550.0'): np.int64(1),
#  np.str_('29600.0'): np.int64(1),
#  np.str_('29625.0'): np.int64(1),
#  np.str_('29675.0'): np.int64(1),
#  np.str_('29700.0'): np.int64(1),
#  np.str_('29850.0'): np.int64(3),
#  np.str_('29875.0'): np.int64(3),
#  np.str_('29900.0'): np.int64(1),
#  np.str_('29925.0'): np.int64(1),
#  np.str_('29950.0'): np.int64(1),
#  np.str_('29975.0'): np.int64(3),
#  np.str_('3000.0'): np.int64(82),
#  np.str_('30000.0'): np.int64(208),
#  np.str_('30025.0'): np.int64(1),
#  np.str_('30400.0'): np.int64(1),
#  np.str_('30425.0'): np.int64(1),
#  np.str_('30450.0'): np.int64(1),
#  np.str_('3050.0'): np.int64(2),
#  np.str_('30500.0'): np.int64(1),
#  np.str_('30550.0'): np.int64(2),
#  np.str_('30725.0'): np.int64(1),
#  np.str_('3075.0'): np.int64(2),
#  np.str_('30750.0'): np.int64(2),
#  np.str_('30800.0'): np.int64(2),
#  np.str_('3100.0'): np.int64(1),
#  np.str_('31000.0'): np.int64(4),
#  np.str_('31025.0'): np.int64(1),
#  np.str_('31075.0'): np.int64(2),
#  np.str_('31125.0'): np.int64(1),
#  np.str_('31150.0'): np.int64(1),
#  np.str_('31200.0'): np.int64(3),
#  np.str_('31275.0'): np.int64(1),
#  np.str_('31300.0'): np.int64(1),
#  np.str_('31475.0'): np.int64(1),
#  np.str_('3150.0'): np.int64(1),
#  np.str_('31500.0'): np.int64(5),
#  np.str_('31625.0'): np.int64(1),
#  np.str_('31825.0'): np.int64(1),
#  np.str_('31850.0'): np.int64(1),
#  np.str_('31950.0'): np.int64(1),
#  np.str_('3200.0'): np.int64(13),
#  np.str_('32000.0'): np.int64(40),
#  np.str_('32225.0'): np.int64(1),
#  np.str_('3225.0'): np.int64(1),
#  np.str_('32425.0'): np.int64(1),
#  np.str_('32450.0'): np.int64(1),
#  np.str_('3250.0'): np.int64(6),
#  np.str_('32500.0'): np.int64(1),
#  np.str_('32525.0'): np.int64(1),
#  np.str_('32650.0'): np.int64(2),
#  np.str_('3275.0'): np.int64(4),
#  np.str_('32750.0'): np.int64(2),
#  np.str_('3300.0'): np.int64(1),
#  np.str_('33000.0'): np.int64(10),
#  np.str_('3325.0'): np.int64(1),
#  np.str_('33300.0'): np.int64(2),
#  np.str_('33425.0'): np.int64(2),
#  np.str_('33450.0'): np.int64(2),
#  np.str_('3350.0'): np.int64(2),
#  np.str_('33525.0'): np.int64(1),
#  np.str_('33550.0'): np.int64(1),
#  np.str_('33600.0'): np.int64(4),
#  np.str_('33700.0'): np.int64(1),
#  np.str_('33750.0'): np.int64(1),
#  np.str_('33975.0'): np.int64(1),
#  np.str_('3400.0'): np.int64(1),
#  np.str_('34000.0'): np.int64(12),
#  np.str_('34075.0'): np.int64(1),
#  np.str_('34100.0'): np.int64(1),
#  np.str_('34175.0'): np.int64(1),
#  np.str_('34200.0'): np.int64(1),
#  np.str_('34375.0'): np.int64(1),
#  np.str_('34425.0'): np.int64(1),
#  np.str_('34475.0'): np.int64(1),
#  np.str_('3450.0'): np.int64(2),
#  np.str_('34500.0'): np.int64(4),
#  np.str_('34550.0'): np.int64(1),
#  np.str_('34675.0'): np.int64(1),
#  np.str_('34725.0'): np.int64(1),
#  np.str_('3475.0'): np.int64(2),
#  np.str_('34800.0'): np.int64(3),
#  np.str_('34875.0'): np.int64(1),
#  np.str_('3500.0'): np.int64(42),
#  np.str_('35000.0'): np.int64(452),
#  np.str_('3525.0'): np.int64(2),
#  np.str_('3550.0'): np.int64(2),
#  np.str_('3575.0'): np.int64(1),
#  np.str_('3600.0'): np.int64(30),
#  np.str_('3650.0'): np.int64(2),
#  np.str_('3700.0'): np.int64(5),
#  np.str_('3725.0'): np.int64(3),
#  np.str_('3750.0'): np.int64(2),
#  np.str_('3800.0'): np.int64(5),
#  np.str_('3850.0'): np.int64(1),
#  np.str_('3875.0'): np.int64(1),
#  np.str_('3900.0'): np.int64(3),
#  np.str_('3925.0'): np.int64(1),
#  np.str_('3950.0'): np.int64(2),
#  np.str_('3975.0'): np.int64(1),
#  np.str_('4000.0'): np.int64(98),
#  np.str_('4025.0'): np.int64(1),
#  np.str_('4100.0'): np.int64(3),
#  np.str_('4125.0'): np.int64(1),
#  np.str_('4150.0'): np.int64(1),
#  np.str_('4175.0'): np.int64(3),
#  np.str_('4200.0'): np.int64(19),
#  np.str_('4225.0'): np.int64(2),
#  np.str_('4250.0'): np.int64(3),
#  np.str_('4275.0'): np.int64(1),
#  np.str_('4300.0'): np.int64(1),
#  np.str_('4325.0'): np.int64(2),
#  np.str_('4350.0'): np.int64(1),
#  np.str_('4375.0'): np.int64(2),
#  np.str_('4400.0'): np.int64(3),
#  np.str_('4450.0'): np.int64(3),
#  np.str_('4475.0'): np.int64(2),
#  np.str_('4500.0'): np.int64(28),
#  np.str_('4525.0'): np.int64(2),
#  np.str_('4550.0'): np.int64(2),
#  np.str_('4575.0'): np.int64(1),
#  np.str_('4600.0'): np.int64(2),
#  np.str_('4625.0'): np.int64(1),
#  np.str_('4650.0'): np.int64(1),
#  np.str_('4700.0'): np.int64(2),
#  np.str_('4725.0'): np.int64(3),
#  np.str_('4750.0'): np.int64(4),
#  np.str_('4800.0'): np.int64(51),
#  np.str_('4825.0'): np.int64(1),
#  np.str_('4875.0'): np.int64(1),
#  np.str_('4900.0'): np.int64(3),
#  np.str_('4925.0'): np.int64(1),
#  np.str_('4950.0'): np.int64(4),
#  np.str_('4975.0'): np.int64(1),
#  np.str_('5000.0'): np.int64(301),
#  np.str_('5025.0'): np.int64(3),
#  np.str_('5050.0'): np.int64(7),
#  np.str_('5075.0'): np.int64(1),
#  np.str_('5100.0'): np.int64(5),
#  np.str_('5125.0'): np.int64(2),
#  np.str_('5150.0'): np.int64(1),
#  np.str_('5175.0'): np.int64(3),
#  np.str_('5200.0'): np.int64(7),
#  np.str_('5225.0'): np.int64(4),
#  np.str_('5250.0'): np.int64(1),
#  np.str_('5275.0'): np.int64(3),
#  np.str_('5300.0'): np.int64(3),
#  np.str_('5350.0'): np.int64(1),
#  np.str_('5400.0'): np.int64(8),
#  np.str_('5425.0'): np.int64(1),
#  np.str_('5450.0'): np.int64(1),
#  np.str_('5500.0'): np.int64(23),
#  np.str_('5525.0'): np.int64(1),
#  np.str_('5550.0'): np.int64(2),
#  np.str_('5575.0'): np.int64(1),
#  np.str_('5600.0'): np.int64(29),
#  np.str_('5650.0'): np.int64(3),
#  np.str_('5675.0'): np.int64(1),
#  np.str_('5700.0'): np.int64(3),
#  np.str_('5750.0'): np.int64(2),
#  np.str_('5775.0'): np.int64(2),
#  np.str_('5800.0'): np.int64(2),
#  np.str_('5825.0'): np.int64(3),
#  np.str_('5875.0'): np.int64(1),
#  np.str_('5900.0'): np.int64(2),
#  np.str_('5950.0'): np.int64(2),
#  np.str_('5975.0'): np.int64(1),
#  np.str_('6000.0'): np.int64(272),
#  np.str_('6025.0'): np.int64(5),
#  np.str_('6050.0'): np.int64(2),
#  np.str_('6075.0'): np.int64(1),
#  np.str_('6100.0'): np.int64(3),
#  np.str_('6125.0'): np.int64(2),
#  np.str_('6150.0'): np.int64(3),
#  np.str_('6200.0'): np.int64(7),
#  np.str_('6225.0'): np.int64(3),
#  np.str_('6250.0'): np.int64(3),
#  np.str_('6300.0'): np.int64(3),
#  np.str_('6325.0'): np.int64(2),
#  np.str_('6350.0'): np.int64(3),
#  np.str_('6375.0'): np.int64(2),
#  np.str_('6400.0'): np.int64(33),
#  np.str_('6425.0'): np.int64(3),
#  np.str_('6450.0'): np.int64(2),
#  np.str_('6475.0'): np.int64(2),
#  np.str_('6500.0'): np.int64(44),
#  np.str_('6550.0'): np.int64(1),
#  np.str_('6600.0'): np.int64(5),
#  np.str_('6650.0'): np.int64(3),
#  np.str_('6700.0'): np.int64(2),
#  np.str_('6725.0'): np.int64(3),
#  np.str_('6750.0'): np.int64(2),
#  np.str_('6775.0'): np.int64(2),
#  np.str_('6800.0'): np.int64(4),
#  np.str_('6825.0'): np.int64(1),
#  np.str_('6850.0'): np.int64(2),
#  np.str_('6900.0'): np.int64(2),
#  np.str_('6925.0'): np.int64(1),
#  np.str_('6975.0'): np.int64(1),
#  np.str_('7000.0'): np.int64(149),
#  np.str_('7025.0'): np.int64(2),
#  np.str_('7050.0'): np.int64(4),
#  np.str_('7075.0'): np.int64(2),
#  np.str_('7100.0'): np.int64(4),
#  np.str_('7125.0'): np.int64(4),
#  np.str_('7150.0'): np.int64(2),
#  np.str_('7175.0'): np.int64(1),
#  np.str_('7200.0'): np.int64(66),
#  np.str_('7225.0'): np.int64(1),
#  np.str_('7250.0'): np.int64(5),
#  np.str_('7300.0'): np.int64(3),
#  np.str_('7325.0'): np.int64(2),
#  np.str_('7350.0'): np.int64(3),
#  np.str_('7375.0'): np.int64(1),
#  np.str_('7400.0'): np.int64(1),
#  np.str_('7425.0'): np.int64(2),
#  np.str_('7450.0'): np.int64(1),
#  np.str_('7475.0'): np.int64(1),
#  np.str_('7500.0'): np.int64(51),
#  np.str_('7525.0'): np.int64(1),
#  np.str_('7575.0'): np.int64(3),
#  np.str_('7600.0'): np.int64(5),
#  np.str_('7625.0'): np.int64(3),
#  np.str_('7650.0'): np.int64(2),
#  np.str_('7675.0'): np.int64(1),
#  np.str_('7700.0'): np.int64(4),
#  np.str_('7725.0'): np.int64(1),
#  np.str_('7750.0'): np.int64(1),
#  np.str_('7800.0'): np.int64(19),
#  np.str_('7825.0'): np.int64(1),
#  np.str_('7850.0'): np.int64(3),
#  np.str_('7875.0'): np.int64(3),
#  np.str_('7900.0'): np.int64(9),
#  np.str_('7925.0'): np.int64(1),
#  np.str_('7950.0'): np.int64(2),
#  np.str_('7975.0'): np.int64(2),
#  np.str_('8000.0'): np.int64(303),
#  np.str_('8025.0'): np.int64(2),
#  np.str_('8075.0'): np.int64(6),
#  np.str_('8100.0'): np.int64(2),
#  np.str_('8125.0'): np.int64(3),
#  np.str_('8150.0'): np.int64(2),
#  np.str_('8200.0'): np.int64(5),
#  np.str_('8225.0'): np.int64(2),
#  np.str_('8250.0'): np.int64(3),
#  np.str_('8275.0'): np.int64(5),
#  np.str_('8300.0'): np.int64(4),
#  np.str_('8325.0'): np.int64(1),
#  np.str_('8350.0'): np.int64(2),
#  np.str_('8375.0'): np.int64(2),
#  np.str_('8400.0'): np.int64(41),
#  np.str_('8425.0'): np.int64(2),
#  np.str_('8475.0'): np.int64(2),
#  np.str_('8500.0'): np.int64(40),
#  np.str_('8525.0'): np.int64(2),
#  np.str_('8550.0'): np.int64(2),
#  np.str_('8600.0'): np.int64(3),
#  np.str_('8625.0'): np.int64(1),
#  np.str_('8650.0'): np.int64(5),
#  np.str_('8675.0'): np.int64(2),
#  np.str_('8700.0'): np.int64(2),
#  np.str_('8725.0'): np.int64(1),
#  np.str_('8750.0'): np.int64(2),
#  np.str_('8775.0'): np.int64(3),
#  np.str_('8800.0'): np.int64(9),
#  np.str_('8825.0'): np.int64(1),
#  np.str_('8850.0'): np.int64(2),
#  np.str_('8875.0'): np.int64(4),
#  np.str_('8900.0'): np.int64(1),
#  np.str_('8925.0'): np.int64(1),
#  np.str_('8950.0'): np.int64(4),
#  np.str_('8975.0'): np.int64(1),
#  np.str_('9000.0'): np.int64(97),
#  np.str_('9025.0'): np.int64(4),
#  np.str_('9075.0'): np.int64(1),
#  np.str_('9100.0'): np.int64(5),
#  np.str_('9125.0'): np.int64(2),
#  np.str_('9150.0'): np.int64(2),
#  np.str_('9175.0'): np.int64(4),
#  np.str_('9200.0'): np.int64(3),
#  np.str_('9225.0'): np.int64(3),
#  np.str_('9250.0'): np.int64(4),
#  np.str_('9275.0'): np.int64(2),
#  np.str_('9300.0'): np.int64(1),
#  np.str_('9350.0'): np.int64(3),
#  np.str_('9375.0'): np.int64(2),
#  np.str_('9400.0'): np.int64(3),
#  np.str_('9425.0'): np.int64(3),
#  np.str_('9450.0'): np.int64(5),
#  np.str_('9500.0'): np.int64(18),
#  np.str_('9525.0'): np.int64(3),
#  np.str_('9550.0'): np.int64(2),
#  np.str_('9575.0'): np.int64(3),
#  np.str_('9600.0'): np.int64(68),
#  np.str_('9650.0'): np.int64(1),
#  np.str_('9675.0'): np.int64(2),
#  np.str_('9700.0'): np.int64(4),
#  np.str_('9725.0'): np.int64(2),
#  np.str_('9775.0'): np.int64(1),
#  np.str_('9800.0'): np.int64(16),
#  np.str_('9825.0'): np.int64(1),
#  np.str_('9900.0'): np.int64(3),
#  np.str_('9925.0'): np.int64(1),
#  np.str_('9950.0'): np.int64(1),
#  np.str_('9975.0'): np.int64(5)}

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'loan_amnt' se observa lo siguiente:
#
# - Los registros proporcionados corresponden al monto de los préstamos aceptados que se encuentran asociados a cada solicitud contenida en la base de datos.
# - Los valores almacenados representan cantidades numéricas y, por tanto, pueden ser tratados como datos de tipo flotante para facilitar su análisis y procesamiento.
# - Se detectan 500 registros en los que el monto del préstamo no fue almacenado correctamente, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron valores con formatos atípicos o inconsistentes en comparación con el resto de los registros de esta categoría, lo que indica una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.
# - Convertir los valores válidos de la categoría desde cadenas de texto a un tipo de dato numérico (por ejemplo, float), permitiendo la aplicación de técnicas estadísticas y de análisis cuantitativo sobre esta variable.

# %% [markdown]
# ### Categoría 'term'

# %% [markdown]
# Esta categoría indica el plazo de amortización del préstamo, expresado en meses.
#
# Los valores posibles son 36 y 60 meses, correspondientes a los dos esquemas de financiamiento ofrecidos para los préstamos registrados en la base de datos.
#
# Esta variable permite identificar el horizonte temporal establecido para la liquidación de cada préstamo.

# %%
caracteristicas_data[label_data[5]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_(' 36 months'): np.int64(6281),
#  np.str_(' 60 months'): np.int64(3219)}

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'term' se observa lo siguiente:
#
# - Los registros proporcionados corresponden al plazo de amortización asociado a cada préstamo, expresado en meses.
# - Los valores almacenados representan cantidades numéricas discretas y, por tanto, pueden ser tratados como datos de tipo entero. No obstante, es necesario eliminar la unidad de medida ("months") para facilitar su procesamiento y análisis.
# - Se detectan 500 registros cuyos plazos no fueron almacenados correctamente, encontrándose representados mediante una cadena vacía ('').
# - No se identificaron valores con formatos atípicos o inconsistentes en comparación con el resto de los registros de esta categoría, lo que evidencia una adecuada uniformidad en la representación de los datos.
# - Los únicos plazos observados en los registros válidos corresponden a 36 y 60 meses.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.
# - Eliminar la unidad de medida ("months") y convertir los valores válidos de la categoría desde cadenas de texto a un tipo de dato numérico entero (int).
# - En caso de requerirse una representación más descriptiva de la información, conservar la unidad de medida mediante la documentación de la variable o la generación de una columna derivada para fines de presentación.

# %% [markdown]
# ### Categoría 'int_rate'

# %% [markdown]
# Datos que se corresponden con la tasa de interés asociada al préstamo concedido al solicitante, expresada como un porcentaje sobre el monto financiado.

# %%
caracteristicas_data[label_data[6]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('12.ìàé'): np.int64(48),
#  np.str_('13.18'): np.int64(100),
#  np.str_('13.33'): np.int64(418),
#  np.str_('13.44'): np.int64(10),
#  np.str_('13.66'): np.int64(56),
#  np.str_('13.67'): np.int64(111),
#  np.str_('13.99'): np.int64(402),
#  np.str_('14.31'): np.int64(50),
#  np.str_('14.33'): np.int64(33),
#  np.str_('14.48'): np.int64(37),
#  np.str_('14.65'): np.int64(306),
#  np.str_('14.85'): np.int64(6),
#  np.str_('14.99'): np.int64(39),
#  np.str_('15.41'): np.int64(56),
#  np.str_('15.59'): np.int64(50),
#  np.str_('15.61'): np.int64(281),
#  np.str_('15.77'): np.int64(6),
#  np.str_('15.99'): np.int64(36),
#  np.str_('16.49'): np.int64(26),
#  np.str_('16.55'): np.int64(228),
#  np.str_('16.59'): np.int64(5),
#  np.str_('16.99'): np.int64(211),
#  np.str_('17.14'): np.int64(25),
#  np.str_('17.27'): np.int64(4),
#  np.str_('17.57'): np.int64(222),
#  np.str_('17.86'): np.int64(222),
#  np.str_('17.97'): np.int64(5),
#  np.str_('18.25'): np.int64(159),
#  np.str_('18.49'): np.int64(31),
#  np.str_('18.54'): np.int64(30),
#  np.str_('18.55'): np.int64(85),
#  np.str_('18.84'): np.int64(34),
#  np.str_('18.99'): np.int64(23),
#  np.str_('18.ôåâ'): np.int64(45),
#  np.str_('19.19'): np.int64(85),
#  np.str_('19.24'): np.int64(18),
#  np.str_('19.48'): np.int64(1),
#  np.str_('19.52'): np.int64(39),
#  np.str_('19.89'): np.int64(6),
#  np.str_('19.99'): np.int64(102),
#  np.str_('20.49'): np.int64(38),
#  np.str_('20.99'): np.int64(100),
#  np.str_('21.67'): np.int64(26),
#  np.str_('21.99'): np.int64(65),
#  np.str_('22.99'): np.int64(73),
#  np.str_('23.99'): np.int64(43),
#  np.str_('24.24'): np.int64(1),
#  np.str_('24.99'): np.int64(40),
#  np.str_('24.ìàé'): np.int64(9),
#  np.str_('25.57'): np.int64(8),
#  np.str_('25.78'): np.int64(9),
#  np.str_('25.83'): np.int64(5),
#  np.str_('25.89'): np.int64(1),
#  np.str_('25.99'): np.int64(4),
#  np.str_('25.àâã'): np.int64(8),
#  np.str_('26.77'): np.int64(8),
#  np.str_('26.99'): np.int64(1),
#  np.str_('26.þíè'): np.int64(1),
#  np.str_('27.31'): np.int64(5),
#  np.str_('27.49'): np.int64(1),
#  np.str_('27.88'): np.int64(2),
#  np.str_('28.49'): np.int64(4),
#  np.str_('28.99'): np.int64(3),
#  np.str_('6.0'): np.int64(1),
#  np.str_('6.ìàð'): np.int64(17),
#  np.str_('9.àâã'): np.int64(7),
#  np.str_('àâã.18'): np.int64(409),
#  np.str_('àâã.19'): np.int64(52),
#  np.str_('àâã.38'): np.int64(50),
#  np.str_('àâã.49'): np.int64(8),
#  np.str_('àâã.67'): np.int64(41),
#  np.str_('äåê.29'): np.int64(451),
#  np.str_('äåê.39'): np.int64(67),
#  np.str_('äåê.59'): np.int64(85),
#  np.str_('äåê.69'): np.int64(423),
#  np.str_('äåê.88'): np.int64(8),
#  np.str_('äåê.99'): np.int64(63),
#  np.str_('ìàé.32'): np.int64(217),
#  np.str_('ìàé.93'): np.int64(47),
#  np.str_('íîå.22'): np.int64(51),
#  np.str_('íîå.44'): np.int64(46),
#  np.str_('íîå.48'): np.int64(10),
#  np.str_('íîå.49'): np.int64(54),
#  np.str_('íîå.53'): np.int64(327),
#  np.str_('íîå.99'): np.int64(118),
#  np.str_('îêò.49'): np.int64(41),
#  np.str_('îêò.64'): np.int64(54),
#  np.str_('îêò.78'): np.int64(12),
#  np.str_('îêò.99'): np.int64(440),
#  np.str_('ñåï.17'): np.int64(458),
#  np.str_('ñåï.49'): np.int64(53),
#  np.str_('ñåï.76'): np.int64(56),
#  np.str_('ñåï.99'): np.int64(428),
#  np.str_('þëè.26'): np.int64(198),
#  np.str_('þëè.49'): np.int64(39),
#  np.str_('þëè.89'): np.int64(451),
#  np.str_('þëè.91'): np.int64(8),
#  np.str_('þíè.24'): np.int64(184),
#  np.str_('þíè.39'): np.int64(60),
#  np.str_('þíè.49'): np.int64(39),
#  np.str_('þíè.68'): np.int64(48),
#  np.str_('þíè.89'): np.int64(148),
#  np.str_('þíè.92'): np.int64(92),
#  np.str_('þíè.99'): np.int64(33)}

# %%
valores_invalidos_rate = []
for key, _ in caracteristicas_data[label_data[6]].items():
    try:
        x = float(key)
    except:
        valores_invalidos_rate.append(key)
valores_invalidos_rate
# Out:
# [np.str_(''),
#  np.str_('12.ìàé'),
#  np.str_('18.ôåâ'),
#  np.str_('24.ìàé'),
#  np.str_('25.àâã'),
#  np.str_('26.þíè'),
#  np.str_('6.ìàð'),
#  np.str_('9.àâã'),
#  np.str_('àâã.18'),
#  np.str_('àâã.19'),
#  np.str_('àâã.38'),
#  np.str_('àâã.49'),
#  np.str_('àâã.67'),
#  np.str_('äåê.29'),
#  np.str_('äåê.39'),
#  np.str_('äåê.59'),
#  np.str_('äåê.69'),
#  np.str_('äåê.88'),
#  np.str_('äåê.99'),
#  np.str_('ìàé.32'),
#  np.str_('ìàé.93'),
#  np.str_('íîå.22'),
#  np.str_('íîå.44'),
#  np.str_('íîå.48'),
#  np.str_('íîå.49'),
#  np.str_('íîå.53'),
#  np.str_('íîå.99'),
#  np.str_('îêò.49'),
#  np.str_('îêò.64'),
#  np.str_('îêò.78'),
#  np.str_('îêò.99'),
#  np.str_('ñåï.17'),
#  np.str_('ñåï.49'),
#  np.str_('ñåï.76'),
#  np.str_('ñåï.99'),
#  np.str_('þëè.26'),
#  np.str_('þëè.49'),
#  np.str_('þëè.89'),
#  np.str_('þëè.91'),
#  np.str_('þíè.24'),
#  np.str_('þíè.39'),
#  np.str_('þíè.49'),
#  np.str_('þíè.68'),
#  np.str_('þíè.89'),
#  np.str_('þíè.92'),
#  np.str_('þíè.99')]

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'int_rate' se observa lo siguiente:
#
# - Los registros proporcionados corresponden a las tasas de interés establecidas a cada préstamo, expresada en porcentaje.
# - Los valores almacenados representan cantidades numéricas y, por tanto, pueden ser tratados como datos de tipo flotante.
# - Se detectan 500 registros cuyas tasas de interés no fueron almacenados correctamente, encontrándose representados mediante una cadena vacía ('').
# - Se identificaron valores con formatos atípicos o inconsistentes en comparación con el resto de los registros de esta categoría, los cuales fueron agrupados dentro del arreglo valores_invalidos_rate.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') y los valores atípicos identificados por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ### Categoría 'installment'

# %% [markdown]
# En esta categoría se agrega el pago mensual que deberá realizar el prestatario en caso de que el préstamo sea otorgado.

# %%
caracteristicas_data[label_data[7]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('100.04'): np.int64(1),
#  np.str_('100.06'): np.int64(6),
#  np.str_('100.21'): np.int64(1),
#  np.str_('100.5'): np.int64(1),
#  np.str_('100.64'): np.int64(11),
#  np.str_('100.68'): np.int64(1),
#  np.str_('1000.37'): np.int64(1),
#  np.str_('1000.59'): np.int64(4),
#  np.str_('1001.15'): np.int64(3),
#  np.str_('1002.03'): np.int64(1),
#  np.str_('1002.9'): np.int64(1),
#  np.str_('1004.91'): np.int64(3),
#  np.str_('1005.43'): np.int64(1),
#  np.str_('1006.35'): np.int64(4),
#  np.str_('1006.68'): np.int64(3),
#  np.str_('1007.52'): np.int64(1),
#  np.str_('1009.09'): np.int64(1),
#  np.str_('101.35'): np.int64(1),
#  np.str_('101.56'): np.int64(3),
#  np.str_('101.73'): np.int64(1),
#  np.str_('1010.68'): np.int64(1),
#  np.str_('1013.11'): np.int64(1),
#  np.str_('1015.6'): np.int64(3),
#  np.str_('1015.79'): np.int64(1),
#  np.str_('102.02'): np.int64(1),
#  np.str_('102.06'): np.int64(1),
#  np.str_('102.52'): np.int64(2),
#  np.str_('102.57'): np.int64(1),
#  np.str_('102.91'): np.int64(1),
#  np.str_('1020.13'): np.int64(2),
#  np.str_('1024.58'): np.int64(1),
#  np.str_('1025.19'): np.int64(3),
#  np.str_('1027.1'): np.int64(4),
#  np.str_('1027.45'): np.int64(1),
#  np.str_('1028.35'): np.int64(1),
#  np.str_('103.16'): np.int64(1),
#  np.str_('103.24'): np.int64(2),
#  np.str_('103.26'): np.int64(1),
#  np.str_('103.49'): np.int64(1),
#  np.str_('103.61'): np.int64(1),
#  np.str_('103.99'): np.int64(1),
#  np.str_('1030.15'): np.int64(1),
#  np.str_('1032.34'): np.int64(1),
#  np.str_('1032.4'): np.int64(1),
#  np.str_('1037.69'): np.int64(1),
#  np.str_('1039.03'): np.int64(1),
#  np.str_('104.28'): np.int64(1),
#  np.str_('104.6'): np.int64(1),
#  np.str_('104.74'): np.int64(1),
#  np.str_('104.9'): np.int64(5),
#  np.str_('1042.68'): np.int64(1),
#  np.str_('1043.37'): np.int64(2),
#  np.str_('1043.78'): np.int64(1),
#  np.str_('1046.0'): np.int64(1),
#  np.str_('1048.95'): np.int64(2),
#  np.str_('105.21'): np.int64(1),
#  np.str_('105.41'): np.int64(1),
#  np.str_('105.57'): np.int64(1),
#  np.str_('105.67'): np.int64(1),
#  np.str_('105.94'): np.int64(1),
#  np.str_('1051.31'): np.int64(1),
#  np.str_('1052.01'): np.int64(1),
#  np.str_('1052.08'): np.int64(1),
#  np.str_('1053.87'): np.int64(1),
#  np.str_('1054.04'): np.int64(1),
#  np.str_('1058.74'): np.int64(1),
#  np.str_('1059.22'): np.int64(1),
#  np.str_('106.07'): np.int64(1),
#  np.str_('106.15'): np.int64(1),
#  np.str_('106.2'): np.int64(1),
#  np.str_('106.28'): np.int64(1),
#  np.str_('106.29'): np.int64(5),
#  np.str_('106.73'): np.int64(1),
#  np.str_('1061.92'): np.int64(1),
#  np.str_('1062.88'): np.int64(2),
#  np.str_('1063.94'): np.int64(2),
#  np.str_('1067.3'): np.int64(2),
#  np.str_('1068.53'): np.int64(1),
#  np.str_('1069.44'): np.int64(3),
#  np.str_('1069.97'): np.int64(1),
#  np.str_('107.26'): np.int64(1),
#  np.str_('107.35'): np.int64(2),
#  np.str_('107.56'): np.int64(2),
#  np.str_('107.82'): np.int64(2),
#  np.str_('107.9'): np.int64(1),
#  np.str_('1073.93'): np.int64(1),
#  np.str_('1074.35'): np.int64(1),
#  np.str_('1075.24'): np.int64(1),
#  np.str_('1076.22'): np.int64(1),
#  np.str_('1077.01'): np.int64(1),
#  np.str_('1078.12'): np.int64(2),
#  np.str_('1078.94'): np.int64(1),
#  np.str_('1079.42'): np.int64(2),
#  np.str_('108.1'): np.int64(1),
#  np.str_('108.25'): np.int64(1),
#  np.str_('108.33'): np.int64(1),
#  np.str_('108.87'): np.int64(1),
#  np.str_('1080.99'): np.int64(1),
#  np.str_('1082.47'): np.int64(3),
#  np.str_('1083.89'): np.int64(1),
#  np.str_('1084.02'): np.int64(1),
#  np.str_('1084.87'): np.int64(7),
#  np.str_('1085.22'): np.int64(1),
#  np.str_('1088.56'): np.int64(3),
#  np.str_('1088.57'): np.int64(1),
#  np.str_('109.18'): np.int64(1),
#  np.str_('109.29'): np.int64(2),
#  np.str_('109.36'): np.int64(2),
#  np.str_('109.97'): np.int64(2),
#  np.str_('1092.72'): np.int64(1),
#  np.str_('1095.0'): np.int64(14),
#  np.str_('1095.33'): np.int64(1),
#  np.str_('1099.69'): np.int64(12),
#  np.str_('1099.85'): np.int64(1),
#  np.str_('110.77'): np.int64(1),
#  np.str_('1100.13'): np.int64(1),
#  np.str_('1102.57'): np.int64(1),
#  np.str_('1102.92'): np.int64(1),
#  np.str_('111.58'): np.int64(1),
#  np.str_('1110.11'): np.int64(1),
#  np.str_('1113.43'): np.int64(1),
#  np.str_('1115.77'): np.int64(15),
#  np.str_('1119.44'): np.int64(1),
#  np.str_('112.55'): np.int64(1),
#  np.str_('112.63'): np.int64(2),
#  np.str_('112.92'): np.int64(4),
#  np.str_('1120.99'): np.int64(1),
#  np.str_('1125.42'): np.int64(2),
#  np.str_('1129.19'): np.int64(17),
#  np.str_('113.01'): np.int64(1),
#  np.str_('113.38'): np.int64(2),
#  np.str_('113.45'): np.int64(1),
#  np.str_('113.61'): np.int64(1),
#  np.str_('113.63'): np.int64(1),
#  np.str_('113.76'): np.int64(1),
#  np.str_('113.99'): np.int64(1),
#  np.str_('1135.06'): np.int64(1),
#  np.str_('1135.69'): np.int64(1),
#  np.str_('1137.43'): np.int64(1),
#  np.str_('1139.82'): np.int64(1),
#  np.str_('114.57'): np.int64(2),
#  np.str_('114.77'): np.int64(2),
#  np.str_('1142.76'): np.int64(1),
#  np.str_('1145.56'): np.int64(1),
#  np.str_('1145.69'): np.int64(2),
#  np.str_('1149.51'): np.int64(2),
#  np.str_('115.0'): np.int64(1),
#  np.str_('115.32'): np.int64(1),
#  np.str_('115.4'): np.int64(1),
#  np.str_('115.47'): np.int64(2),
#  np.str_('115.76'): np.int64(1),
#  np.str_('115.86'): np.int64(1),
#  np.str_('1154.66'): np.int64(5),
#  np.str_('1155.46'): np.int64(1),
#  np.str_('116.09'): np.int64(1),
#  np.str_('116.15'): np.int64(2),
#  np.str_('116.21'): np.int64(1),
#  np.str_('116.24'): np.int64(2),
#  np.str_('116.26'): np.int64(1),
#  np.str_('116.74'): np.int64(4),
#  np.str_('116.91'): np.int64(1),
#  np.str_('1162.34'): np.int64(2),
#  np.str_('1163.34'): np.int64(1),
#  np.str_('1165.57'): np.int64(1),
#  np.str_('1167.36'): np.int64(8),
#  np.str_('1169.04'): np.int64(2),
#  np.str_('117.41'): np.int64(5),
#  np.str_('117.85'): np.int64(1),
#  np.str_('117.95'): np.int64(1),
#  np.str_('1172.39'): np.int64(1),
#  np.str_('1172.81'): np.int64(1),
#  np.str_('1174.07'): np.int64(7),
#  np.str_('1176.38'): np.int64(2),
#  np.str_('1179.12'): np.int64(2),
#  np.str_('118.24'): np.int64(1),
#  np.str_('118.49'): np.int64(1),
#  np.str_('118.68'): np.int64(1),
#  np.str_('118.69'): np.int64(1),
#  np.str_('118.73'): np.int64(1),
#  np.str_('118.77'): np.int64(3),
#  np.str_('118.82'): np.int64(1),
#  np.str_('118.89'): np.int64(1),
#  np.str_('1182.33'): np.int64(1),
#  np.str_('1184.86'): np.int64(19),
#  np.str_('1185.11'): np.int64(1),
#  np.str_('1185.93'): np.int64(1),
#  np.str_('1186.72'): np.int64(1),
#  np.str_('119.31'): np.int64(1),
#  np.str_('119.4'): np.int64(2),
#  np.str_('119.61'): np.int64(2),
#  np.str_('1190.45'): np.int64(3),
#  np.str_('1190.62'): np.int64(3),
#  np.str_('1196.05'): np.int64(8),
#  np.str_('120.08'): np.int64(3),
#  np.str_('120.22'): np.int64(1),
#  np.str_('120.25'): np.int64(1),
#  np.str_('120.35'): np.int64(1),
#  np.str_('120.39'): np.int64(1),
#  np.str_('120.55'): np.int64(1),
#  np.str_('120.59'): np.int64(1),
#  np.str_('120.73'): np.int64(2),
#  np.str_('120.77'): np.int64(4),
#  np.str_('1201.5'): np.int64(2),
#  np.str_('1204.4'): np.int64(2),
#  np.str_('1207.3'): np.int64(8),
#  np.str_('122.02'): np.int64(1),
#  np.str_('122.13'): np.int64(3),
#  np.str_('122.38'): np.int64(1),
#  np.str_('122.47'): np.int64(1),
#  np.str_('122.54'): np.int64(1),
#  np.str_('122.58'): np.int64(1),
#  np.str_('122.81'): np.int64(1),
#  np.str_('122.93'): np.int64(1),
#  np.str_('1220.33'): np.int64(1),
#  np.str_('1223.43'): np.int64(1),
#  np.str_('1223.77'): np.int64(6),
#  np.str_('123.03'): np.int64(1),
#  np.str_('123.31'): np.int64(1),
#  np.str_('123.37'): np.int64(2),
#  np.str_('123.62'): np.int64(1),
#  np.str_('123.92'): np.int64(1),
#  np.str_('123.99'): np.int64(1),
#  np.str_('1230.33'): np.int64(4),
#  np.str_('1238.98'): np.int64(1),
#  np.str_('124.13'): np.int64(1),
#  np.str_('124.18'): np.int64(1),
#  np.str_('124.39'): np.int64(1),
#  np.str_('124.41'): np.int64(1),
#  np.str_('124.49'): np.int64(1),
#  np.str_('124.77'): np.int64(2),
#  np.str_('1240.03'): np.int64(5),
#  np.str_('1247.68'): np.int64(8),
#  np.str_('1249.58'): np.int64(1),
#  np.str_('125.15'): np.int64(1),
#  np.str_('125.26'): np.int64(1),
#  np.str_('125.68'): np.int64(5),
#  np.str_('125.7'): np.int64(1),
#  np.str_('125.78'): np.int64(1),
#  np.str_('125.88'): np.int64(2),
#  np.str_('1250.29'): np.int64(1),
#  np.str_('1257.8'): np.int64(3),
#  np.str_('126.39'): np.int64(1),
#  np.str_('1262.88'): np.int64(4),
#  np.str_('1269.73'): np.int64(1),
#  np.str_('127.44'): np.int64(1),
#  np.str_('127.52'): np.int64(4),
#  np.str_('127.55'): np.int64(1),
#  np.str_('127.72'): np.int64(1),
#  np.str_('128.12'): np.int64(1),
#  np.str_('128.34'): np.int64(1),
#  np.str_('128.62'): np.int64(2),
#  np.str_('1286.33'): np.int64(1),
#  np.str_('1287.22'): np.int64(1),
#  np.str_('129.05'): np.int64(4),
#  np.str_('129.36'): np.int64(1),
#  np.str_('129.37'): np.int64(1),
#  np.str_('129.38'): np.int64(1),
#  np.str_('1292.19'): np.int64(1),
#  np.str_('130.28'): np.int64(1),
#  np.str_('130.48'): np.int64(1),
#  np.str_('130.52'): np.int64(1),
#  np.str_('130.94'): np.int64(2),
#  np.str_('1300.55'): np.int64(2),
#  np.str_('131.38'): np.int64(1),
#  np.str_('131.4'): np.int64(1),
#  np.str_('131.75'): np.int64(1),
#  np.str_('131.87'): np.int64(1),
#  np.str_('131.97'): np.int64(9),
#  np.str_('132.01'): np.int64(1),
#  np.str_('132.96'): np.int64(1),
#  np.str_('133.42'): np.int64(4),
#  np.str_('133.9'): np.int64(2),
#  np.str_('1330.7'): np.int64(2),
#  np.str_('134.15'): np.int64(1),
#  np.str_('134.18'): np.int64(7),
#  np.str_('134.31'): np.int64(1),
#  np.str_('134.76'): np.int64(3),
#  np.str_('134.79'): np.int64(1),
#  np.str_('135.13'): np.int64(2),
#  np.str_('135.27'): np.int64(1),
#  np.str_('135.42'): np.int64(7),
#  np.str_('135.51'): np.int64(3),
#  np.str_('135.68'): np.int64(1),
#  np.str_('135.89'): np.int64(1),
#  np.str_('136.08'): np.int64(2),
#  np.str_('136.09'): np.int64(1),
#  np.str_('136.26'): np.int64(1),
#  np.str_('136.41'): np.int64(1),
#  np.str_('136.67'): np.int64(1),
#  np.str_('136.7'): np.int64(1),
#  np.str_('137.3'): np.int64(1),
#  np.str_('137.32'): np.int64(3),
#  np.str_('137.39'): np.int64(1),
#  np.str_('137.47'): np.int64(1),
#  np.str_('137.49'): np.int64(1),
#  np.str_('137.65'): np.int64(1),
#  np.str_('137.95'): np.int64(1),
#  np.str_('137.98'): np.int64(6),
#  np.str_('1372.97'): np.int64(1),
#  np.str_('138.65'): np.int64(1),
#  np.str_('138.73'): np.int64(2),
#  np.str_('139.35'): np.int64(1),
#  np.str_('139.49'): np.int64(1),
#  np.str_('139.86'): np.int64(5),
#  np.str_('140.09'): np.int64(1),
#  np.str_('140.27'): np.int64(1),
#  np.str_('140.3'): np.int64(1),
#  np.str_('140.69'): np.int64(2),
#  np.str_('140.79'): np.int64(1),
#  np.str_('140.93'): np.int64(1),
#  np.str_('141.39'): np.int64(2),
#  np.str_('141.6'): np.int64(1),
#  np.str_('141.72'): np.int64(3),
#  np.str_('141.88'): np.int64(1),
#  np.str_('142.19'): np.int64(1),
#  np.str_('142.6'): np.int64(1),
#  np.str_('142.88'): np.int64(1),
#  np.str_('142.89'): np.int64(1),
#  np.str_('142.97'): np.int64(1),
#  np.str_('143.16'): np.int64(1),
#  np.str_('143.53'): np.int64(3),
#  np.str_('143.75'): np.int64(2),
#  np.str_('144.23'): np.int64(1),
#  np.str_('144.33'): np.int64(2),
#  np.str_('144.56'): np.int64(1),
#  np.str_('144.78'): np.int64(1),
#  np.str_('145.12'): np.int64(1),
#  np.str_('145.19'): np.int64(2),
#  np.str_('145.24'): np.int64(1),
#  np.str_('145.7'): np.int64(1),
#  np.str_('146.13'): np.int64(1),
#  np.str_('146.16'): np.int64(1),
#  np.str_('146.24'): np.int64(1),
#  np.str_('146.81'): np.int64(1),
#  np.str_('146.86'): np.int64(1),
#  np.str_('147.97'): np.int64(2),
#  np.str_('148.04'): np.int64(1),
#  np.str_('148.43'): np.int64(1),
#  np.str_('148.81'): np.int64(1),
#  np.str_('149.27'): np.int64(1),
#  np.str_('149.74'): np.int64(1),
#  np.str_('150.09'): np.int64(2),
#  np.str_('150.18'): np.int64(1),
#  np.str_('150.54'): np.int64(1),
#  np.str_('150.58'): np.int64(13),
#  np.str_('150.62'): np.int64(1),
#  np.str_('150.65'): np.int64(2),
#  np.str_('150.74'): np.int64(1),
#  np.str_('150.82'): np.int64(4),
#  np.str_('150.96'): np.int64(6),
#  np.str_('151.06'): np.int64(1),
#  np.str_('151.51'): np.int64(2),
#  np.str_('151.96'): np.int64(1),
#  np.str_('152.34'): np.int64(3),
#  np.str_('152.66'): np.int64(7),
#  np.str_('153.0'): np.int64(2),
#  np.str_('153.02'): np.int64(1),
#  np.str_('153.23'): np.int64(2),
#  np.str_('153.45'): np.int64(1),
#  np.str_('153.66'): np.int64(3),
#  np.str_('153.78'): np.int64(1),
#  np.str_('154.14'): np.int64(8),
#  np.str_('154.18'): np.int64(1),
#  np.str_('154.21'): np.int64(6),
#  np.str_('154.35'): np.int64(1),
#  np.str_('154.37'): np.int64(2),
#  np.str_('154.48'): np.int64(1),
#  np.str_('154.86'): np.int64(1),
#  np.str_('154.99'): np.int64(3),
#  np.str_('155.09'): np.int64(1),
#  np.str_('155.23'): np.int64(1),
#  np.str_('155.51'): np.int64(1),
#  np.str_('155.99'): np.int64(1),
#  np.str_('156.33'): np.int64(2),
#  np.str_('156.43'): np.int64(26),
#  np.str_('156.86'): np.int64(1),
#  np.str_('157.1'): np.int64(19),
#  np.str_('157.12'): np.int64(1),
#  np.str_('157.13'): np.int64(5),
#  np.str_('157.56'): np.int64(2),
#  np.str_('157.65'): np.int64(1),
#  np.str_('157.86'): np.int64(1),
#  np.str_('158.22'): np.int64(1),
#  np.str_('158.27'): np.int64(1),
#  np.str_('158.36'): np.int64(1),
#  np.str_('158.47'): np.int64(1),
#  np.str_('158.64'): np.int64(1),
#  np.str_('158.67'): np.int64(1),
#  np.str_('158.68'): np.int64(1),
#  np.str_('158.86'): np.int64(1),
#  np.str_('159.16'): np.int64(1),
#  np.str_('159.4'): np.int64(15),
#  np.str_('159.44'): np.int64(1),
#  np.str_('159.56'): np.int64(1),
#  np.str_('159.7'): np.int64(1),
#  np.str_('160.1'): np.int64(2),
#  np.str_('160.15'): np.int64(3),
#  np.str_('160.78'): np.int64(2),
#  np.str_('160.79'): np.int64(2),
#  np.str_('161.02'): np.int64(3),
#  np.str_('161.32'): np.int64(13),
#  np.str_('161.59'): np.int64(1),
#  np.str_('161.71'): np.int64(1),
#  np.str_('161.72'): np.int64(1),
#  np.str_('161.96'): np.int64(1),
#  np.str_('162.13'): np.int64(1),
#  np.str_('162.15'): np.int64(1),
#  np.str_('162.2'): np.int64(1),
#  np.str_('162.49'): np.int64(2),
#  np.str_('162.5'): np.int64(1),
#  np.str_('162.73'): np.int64(1),
#  np.str_('162.85'): np.int64(3),
#  np.str_('163.14'): np.int64(1),
#  np.str_('163.27'): np.int64(1),
#  np.str_('163.29'): np.int64(2),
#  np.str_('163.38'): np.int64(1),
#  np.str_('163.39'): np.int64(2),
#  np.str_('163.41'): np.int64(1),
#  np.str_('163.67'): np.int64(18),
#  np.str_('164.03'): np.int64(6),
#  np.str_('164.22'): np.int64(4),
#  np.str_('164.37'): np.int64(1),
#  np.str_('164.47'): np.int64(1),
#  np.str_('164.49'): np.int64(1),
#  np.str_('164.78'): np.int64(2),
#  np.str_('164.84'): np.int64(1),
#  np.str_('164.86'): np.int64(1),
#  np.str_('164.96'): np.int64(12),
#  np.str_('165.0'): np.int64(1),
#  np.str_('165.08'): np.int64(1),
#  np.str_('165.18'): np.int64(1),
#  np.str_('165.31'): np.int64(1),
#  np.str_('165.39'): np.int64(1),
#  np.str_('165.58'): np.int64(3),
#  np.str_('165.64'): np.int64(1),
#  np.str_('165.82'): np.int64(1),
#  np.str_('165.89'): np.int64(1),
#  np.str_('166.05'): np.int64(5),
#  np.str_('166.2'): np.int64(3),
#  np.str_('166.61'): np.int64(1),
#  np.str_('166.77'): np.int64(11),
#  np.str_('166.88'): np.int64(1),
#  np.str_('166.89'): np.int64(1),
#  np.str_('166.98'): np.int64(1),
#  np.str_('167.01'): np.int64(2),
#  np.str_('167.02'): np.int64(1),
#  np.str_('167.49'): np.int64(4),
#  np.str_('167.73'): np.int64(17),
#  np.str_('167.77'): np.int64(1),
#  np.str_('167.84'): np.int64(2),
#  np.str_('168.19'): np.int64(1),
#  np.str_('168.44'): np.int64(1),
#  np.str_('168.45'): np.int64(2),
#  np.str_('168.58'): np.int64(1),
#  np.str_('168.91'): np.int64(5),
#  np.str_('169.27'): np.int64(21),
#  np.str_('169.4'): np.int64(1),
#  np.str_('169.45'): np.int64(1),
#  np.str_('169.55'): np.int64(1),
#  np.str_('169.67'): np.int64(1),
#  np.str_('169.69'): np.int64(1),
#  np.str_('169.7'): np.int64(1),
#  np.str_('169.81'): np.int64(1),
#  np.str_('170.07'): np.int64(2),
#  np.str_('170.09'): np.int64(1),
#  np.str_('170.11'): np.int64(1),
#  np.str_('170.22'): np.int64(1),
#  np.str_('170.48'): np.int64(1),
#  np.str_('170.75'): np.int64(1),
#  np.str_('170.87'): np.int64(8),
#  np.str_('170.96'): np.int64(1),
#  np.str_('171.11'): np.int64(2),
#  np.str_('171.55'): np.int64(1),
#  np.str_('171.65'): np.int64(1),
#  np.str_('171.66'): np.int64(1),
#  np.str_('171.84'): np.int64(1),
#  np.str_('172.06'): np.int64(2),
#  np.str_('172.15'): np.int64(2),
#  np.str_('172.48'): np.int64(7),
#  np.str_('172.5'): np.int64(2),
#  np.str_('172.81'): np.int64(1),
#  np.str_('172.84'): np.int64(2),
#  np.str_('173.31'): np.int64(1),
#  np.str_('173.32'): np.int64(2),
#  np.str_('173.83'): np.int64(1),
#  np.str_('174.03'): np.int64(1),
#  np.str_('174.29'): np.int64(1),
#  np.str_('174.38'): np.int64(1),
#  np.str_('174.44'): np.int64(1),
#  np.str_('174.78'): np.int64(2),
#  np.str_('174.83'): np.int64(5),
#  np.str_('175.2'): np.int64(2),
#  np.str_('175.38'): np.int64(1),
#  np.str_('175.57'): np.int64(1),
#  np.str_('175.98'): np.int64(2),
#  np.str_('176.74'): np.int64(1),
#  np.str_('176.79'): np.int64(1),
#  np.str_('176.85'): np.int64(1),
#  np.str_('176.86'): np.int64(1),
#  np.str_('177.0'): np.int64(1),
#  np.str_('177.15'): np.int64(4),
#  np.str_('178.05'): np.int64(1),
#  np.str_('178.15'): np.int64(1),
#  np.str_('178.24'): np.int64(6),
#  np.str_('178.53'): np.int64(2),
#  np.str_('178.56'): np.int64(1),
#  np.str_('179.43'): np.int64(1),
#  np.str_('179.49'): np.int64(1),
#  np.str_('179.62'): np.int64(1),
#  np.str_('179.69'): np.int64(7),
#  np.str_('180.04'): np.int64(2),
#  np.str_('180.18'): np.int64(1),
#  np.str_('180.27'): np.int64(1),
#  np.str_('180.28'): np.int64(1),
#  np.str_('180.42'): np.int64(3),
#  np.str_('180.67'): np.int64(1),
#  np.str_('180.69'): np.int64(10),
#  np.str_('181.09'): np.int64(1),
#  np.str_('181.39'): np.int64(1),
#  np.str_('181.45'): np.int64(1),
#  np.str_('182.0'): np.int64(1),
#  np.str_('182.15'): np.int64(1),
#  np.str_('182.31'): np.int64(1),
#  np.str_('182.66'): np.int64(1),
#  np.str_('183.06'): np.int64(1),
#  np.str_('183.08'): np.int64(1),
#  np.str_('183.19'): np.int64(6),
#  np.str_('183.26'): np.int64(1),
#  np.str_('183.28'): np.int64(1),
#  np.str_('183.45'): np.int64(2),
#  np.str_('183.6'): np.int64(3),
#  np.str_('183.77'): np.int64(1),
#  np.str_('183.87'): np.int64(3),
#  np.str_('183.93'): np.int64(3),
#  np.str_('183.94'): np.int64(2),
#  np.str_('184.02'): np.int64(1),
#  np.str_('184.39'): np.int64(2),
#  np.str_('184.5'): np.int64(2),
#  np.str_('184.54'): np.int64(1),
#  np.str_('184.75'): np.int64(3),
#  np.str_('184.97'): np.int64(4),
#  np.str_('185.05'): np.int64(2),
#  np.str_('185.12'): np.int64(1),
#  np.str_('185.24'): np.int64(1),
#  np.str_('185.62'): np.int64(1),
#  np.str_('185.8'): np.int64(1),
#  np.str_('185.98'): np.int64(9),
#  np.str_('186.14'): np.int64(1),
#  np.str_('186.2'): np.int64(1),
#  np.str_('186.61'): np.int64(1),
#  np.str_('186.62'): np.int64(1),
#  np.str_('186.78'): np.int64(4),
#  np.str_('186.8'): np.int64(1),
#  np.str_('187.72'): np.int64(25),
#  np.str_('187.74'): np.int64(1),
#  np.str_('187.86'): np.int64(1),
#  np.str_('188.09'): np.int64(1),
#  np.str_('188.52'): np.int64(11),
#  np.str_('188.55'): np.int64(2),
#  np.str_('188.66'): np.int64(2),
#  np.str_('189.04'): np.int64(1),
#  np.str_('189.08'): np.int64(1),
#  np.str_('189.44'): np.int64(1),
#  np.str_('190.94'): np.int64(1),
#  np.str_('191.28'): np.int64(21),
#  np.str_('191.35'): np.int64(2),
#  np.str_('191.37'): np.int64(2),
#  np.str_('192.16'): np.int64(1),
#  np.str_('192.17'): np.int64(2),
#  np.str_('192.31'): np.int64(2),
#  np.str_('192.74'): np.int64(3),
#  np.str_('192.89'): np.int64(1),
#  np.str_('192.93'): np.int64(1),
#  np.str_('193.05'): np.int64(1),
#  np.str_('193.17'): np.int64(1),
#  np.str_('193.53'): np.int64(1),
#  np.str_('193.58'): np.int64(11),
#  np.str_('193.85'): np.int64(1),
#  np.str_('194.1'): np.int64(1),
#  np.str_('194.9'): np.int64(1),
#  np.str_('194.93'): np.int64(1),
#  np.str_('194.99'): np.int64(2),
#  np.str_('195.42'): np.int64(4),
#  np.str_('195.49'): np.int64(1),
#  np.str_('195.75'): np.int64(5),
#  np.str_('195.76'): np.int64(1),
#  np.str_('195.81'): np.int64(1),
#  np.str_('196.13'): np.int64(1),
#  np.str_('196.14'): np.int64(1),
#  np.str_('196.41'): np.int64(18),
#  np.str_('197.06'): np.int64(5),
#  np.str_('197.2'): np.int64(1),
#  np.str_('197.23'): np.int64(1),
#  np.str_('197.38'): np.int64(3),
#  np.str_('197.54'): np.int64(1),
#  np.str_('197.65'): np.int64(1),
#  np.str_('197.66'): np.int64(1),
#  np.str_('197.69'): np.int64(1),
#  np.str_('197.83'): np.int64(4),
#  np.str_('197.88'): np.int64(1),
#  np.str_('197.95'): np.int64(13),
#  np.str_('198.38'): np.int64(2),
#  np.str_('198.42'): np.int64(1),
#  np.str_('198.46'): np.int64(1),
#  np.str_('198.89'): np.int64(1),
#  np.str_('198.9'): np.int64(2),
#  np.str_('199.25'): np.int64(1),
#  np.str_('199.26'): np.int64(6),
#  np.str_('199.34'): np.int64(1),
#  np.str_('200.03'): np.int64(2),
#  np.str_('200.12'): np.int64(22),
#  np.str_('200.38'): np.int64(1),
#  np.str_('200.41'): np.int64(2),
#  np.str_('200.84'): np.int64(1),
#  np.str_('200.93'): np.int64(1),
#  np.str_('200.96'): np.int64(2),
#  np.str_('200.99'): np.int64(4),
#  np.str_('201.09'): np.int64(2),
#  np.str_('201.25'): np.int64(1),
#  np.str_('201.27'): np.int64(21),
#  np.str_('201.48'): np.int64(1),
#  np.str_('202.14'): np.int64(3),
#  np.str_('202.24'): np.int64(4),
#  np.str_('202.34'): np.int64(1),
#  np.str_('202.53'): np.int64(1),
#  np.str_('203.03'): np.int64(1),
#  np.str_('203.12'): np.int64(14),
#  np.str_('203.28'): np.int64(1),
#  np.str_('203.36'): np.int64(2),
#  np.str_('203.63'): np.int64(3),
#  np.str_('204.08'): np.int64(1),
#  np.str_('204.11'): np.int64(2),
#  np.str_('204.23'): np.int64(2),
#  np.str_('204.43'): np.int64(1),
#  np.str_('204.56'): np.int64(1),
#  np.str_('204.59'): np.int64(1),
#  np.str_('204.83'): np.int64(1),
#  np.str_('204.97'): np.int64(1),
#  np.str_('204.98'): np.int64(1),
#  np.str_('205.04'): np.int64(6),
#  np.str_('205.16'): np.int64(1),
#  np.str_('206.48'): np.int64(1),
#  np.str_('206.51'): np.int64(1),
#  np.str_('206.97'): np.int64(8),
#  np.str_('207.22'): np.int64(4),
#  np.str_('207.87'): np.int64(1),
#  np.str_('207.97'): np.int64(2),
#  np.str_('208.2'): np.int64(1),
#  np.str_('208.41'): np.int64(3),
#  np.str_('208.46'): np.int64(1),
#  np.str_('209.16'): np.int64(1),
#  np.str_('209.2'): np.int64(2),
#  np.str_('209.36'): np.int64(1),
#  np.str_('209.5'): np.int64(1),
#  np.str_('209.71'): np.int64(4),
#  np.str_('209.73'): np.int64(1),
#  np.str_('209.79'): np.int64(7),
#  np.str_('210.33'): np.int64(1),
#  np.str_('210.81'): np.int64(6),
#  np.str_('211.02'): np.int64(1),
#  np.str_('211.14'): np.int64(4),
#  np.str_('211.24'): np.int64(2),
#  np.str_('211.27'): np.int64(1),
#  np.str_('211.3'): np.int64(1),
#  np.str_('211.73'): np.int64(1),
#  np.str_('212.43'): np.int64(6),
#  np.str_('212.58'): np.int64(3),
#  np.str_('212.7'): np.int64(1),
#  np.str_('212.78'): np.int64(1),
#  np.str_('212.94'): np.int64(1),
#  np.str_('213.28'): np.int64(1),
#  np.str_('213.46'): np.int64(3),
#  np.str_('213.47'): np.int64(1),
#  np.str_('213.72'): np.int64(2),
#  np.str_('213.77'): np.int64(1),
#  np.str_('213.85'): np.int64(1),
#  np.str_('213.89'): np.int64(3),
#  np.str_('214.2'): np.int64(2),
#  np.str_('214.32'): np.int64(1),
#  np.str_('214.35'): np.int64(1),
#  np.str_('214.38'): np.int64(1),
#  np.str_('214.73'): np.int64(1),
#  np.str_('214.97'): np.int64(1),
#  np.str_('215.12'): np.int64(2),
#  np.str_('215.17'): np.int64(1),
#  np.str_('215.79'): np.int64(5),
#  np.str_('215.89'): np.int64(3),
#  np.str_('215.97'): np.int64(1),
#  np.str_('216.18'): np.int64(1),
#  np.str_('216.2'): np.int64(1),
#  np.str_('216.5'): np.int64(1),
#  np.str_('216.66'): np.int64(5),
#  np.str_('216.67'): np.int64(1),
#  np.str_('216.79'): np.int64(1),
#  np.str_('216.8'): np.int64(2),
#  np.str_('216.83'): np.int64(2),
#  np.str_('216.98'): np.int64(6),
#  np.str_('217.01'): np.int64(1),
#  np.str_('217.11'): np.int64(1),
#  np.str_('217.32'): np.int64(1),
#  np.str_('217.38'): np.int64(7),
#  np.str_('217.58'): np.int64(1),
#  np.str_('217.67'): np.int64(1),
#  np.str_('217.72'): np.int64(5),
#  np.str_('217.73'): np.int64(1),
#  np.str_('218.05'): np.int64(1),
#  np.str_('218.53'): np.int64(3),
#  np.str_('218.55'): np.int64(1),
#  np.str_('218.81'): np.int64(1),
#  np.str_('219.0'): np.int64(15),
#  np.str_('219.17'): np.int64(1),
#  np.str_('219.22'): np.int64(1),
#  np.str_('219.63'): np.int64(1),
#  np.str_('219.83'): np.int64(1),
#  np.str_('219.88'): np.int64(1),
#  np.str_('219.94'): np.int64(12),
#  np.str_('219.97'): np.int64(1),
#  np.str_('220.05'): np.int64(2),
#  np.str_('220.08'): np.int64(2),
#  np.str_('220.47'): np.int64(1),
#  np.str_('220.59'): np.int64(3),
#  np.str_('220.92'): np.int64(1),
#  np.str_('221.09'): np.int64(1),
#  np.str_('221.63'): np.int64(1),
#  np.str_('221.96'): np.int64(1),
#  np.str_('222.06'): np.int64(1),
#  np.str_('222.13'): np.int64(2),
#  np.str_('222.29'): np.int64(1),
#  np.str_('222.4'): np.int64(1),
#  np.str_('222.6'): np.int64(1),
#  np.str_('222.88'): np.int64(1),
#  np.str_('222.91'): np.int64(1),
#  np.str_('223.16'): np.int64(12),
#  np.str_('223.18'): np.int64(3),
#  np.str_('223.2'): np.int64(1),
#  np.str_('223.34'): np.int64(1),
#  np.str_('223.44'): np.int64(1),
#  np.str_('223.78'): np.int64(2),
#  np.str_('223.92'): np.int64(4),
#  np.str_('224.22'): np.int64(2),
#  np.str_('224.34'): np.int64(1),
#  np.str_('225.04'): np.int64(1),
#  np.str_('225.09'): np.int64(1),
#  np.str_('225.14'): np.int64(1),
#  np.str_('225.26'): np.int64(1),
#  np.str_('225.55'): np.int64(1),
#  np.str_('225.84'): np.int64(7),
#  np.str_('225.87'): np.int64(2),
#  np.str_('225.95'): np.int64(2),
#  np.str_('226.23'): np.int64(1),
#  np.str_('226.59'): np.int64(1),
#  np.str_('226.82'): np.int64(1),
#  np.str_('227.28'): np.int64(2),
#  np.str_('227.45'): np.int64(1),
#  np.str_('227.48'): np.int64(1),
#  np.str_('227.8'): np.int64(1),
#  np.str_('227.93'): np.int64(1),
#  np.str_('227.94'): np.int64(1),
#  np.str_('227.98'): np.int64(2),
#  np.str_('228.11'): np.int64(1),
#  np.str_('228.46'): np.int64(4),
#  np.str_('228.99'): np.int64(1),
#  np.str_('229.14'): np.int64(10),
#  np.str_('229.23'): np.int64(4),
#  np.str_('229.5'): np.int64(1),
#  np.str_('229.53'): np.int64(7),
#  np.str_('230.07'): np.int64(1),
#  np.str_('230.29'): np.int64(2),
#  np.str_('230.49'): np.int64(1),
#  np.str_('230.8'): np.int64(2),
#  np.str_('230.9'): np.int64(1),
#  np.str_('230.93'): np.int64(1),
#  np.str_('230.94'): np.int64(7),
#  np.str_('230.98'): np.int64(4),
#  np.str_('231.29'): np.int64(1),
#  np.str_('231.53'): np.int64(1),
#  np.str_('232.29'): np.int64(3),
#  np.str_('232.48'): np.int64(2),
#  np.str_('232.64'): np.int64(9),
#  np.str_('232.67'): np.int64(1),
#  np.str_('232.73'): np.int64(1),
#  np.str_('232.88'): np.int64(1),
#  np.str_('233.48'): np.int64(9),
#  np.str_('233.67'): np.int64(3),
#  np.str_('233.81'): np.int64(3),
#  np.str_('234.3'): np.int64(1),
#  np.str_('234.48'): np.int64(1),
#  np.str_('234.5'): np.int64(1),
#  np.str_('234.65'): np.int64(2),
#  np.str_('234.82'): np.int64(7),
#  np.str_('234.9'): np.int64(1),
#  np.str_('235.11'): np.int64(1),
#  np.str_('235.18'): np.int64(2),
#  np.str_('235.61'): np.int64(1),
#  np.str_('235.65'): np.int64(4),
#  np.str_('235.69'): np.int64(7),
#  np.str_('235.83'): np.int64(1),
#  np.str_('236.07'): np.int64(4),
#  np.str_('236.23'): np.int64(1),
#  np.str_('236.34'): np.int64(1),
#  np.str_('236.54'): np.int64(1),
#  np.str_('236.98'): np.int64(6),
#  np.str_('237.19'): np.int64(1),
#  np.str_('237.25'): np.int64(1),
#  np.str_('237.36'): np.int64(1),
#  np.str_('237.37'): np.int64(1),
#  np.str_('237.4'): np.int64(2),
#  np.str_('237.53'): np.int64(3),
#  np.str_('237.69'): np.int64(1),
#  np.str_('237.7'): np.int64(1),
#  np.str_('238.15'): np.int64(2),
#  np.str_('238.17'): np.int64(1),
#  np.str_('238.27'): np.int64(1),
#  np.str_('238.36'): np.int64(1),
#  np.str_('238.79'): np.int64(2),
#  np.str_('239.06'): np.int64(1),
#  np.str_('239.09'): np.int64(1),
#  np.str_('239.1'): np.int64(8),
#  np.str_('239.12'): np.int64(2),
#  np.str_('239.21'): np.int64(4),
#  np.str_('239.32'): np.int64(1),
#  np.str_('239.51'): np.int64(1),
#  np.str_('239.68'): np.int64(3),
#  np.str_('239.94'): np.int64(1),
#  np.str_('240.06'): np.int64(2),
#  np.str_('240.15'): np.int64(6),
#  np.str_('240.22'): np.int64(1),
#  np.str_('240.36'): np.int64(1),
#  np.str_('240.56'): np.int64(1),
#  np.str_('240.6'): np.int64(1),
#  np.str_('240.68'): np.int64(1),
#  np.str_('240.69'): np.int64(2),
#  np.str_('240.92'): np.int64(9),
#  np.str_('241.01'): np.int64(1),
#  np.str_('241.12'): np.int64(5),
#  np.str_('241.16'): np.int64(1),
#  np.str_('241.18'): np.int64(2),
#  np.str_('241.46'): np.int64(4),
#  np.str_('241.53'): np.int64(5),
#  np.str_('242.28'): np.int64(1),
#  np.str_('242.57'): np.int64(1),
#  np.str_('242.63'): np.int64(1),
#  np.str_('242.69'): np.int64(3),
#  np.str_('242.77'): np.int64(1),
#  np.str_('243.13'): np.int64(3),
#  np.str_('243.19'): np.int64(1),
#  np.str_('243.23'): np.int64(1),
#  np.str_('243.74'): np.int64(1),
#  np.str_('243.75'): np.int64(2),
#  np.str_('244.03'): np.int64(2),
#  np.str_('244.05'): np.int64(1),
#  np.str_('244.07'): np.int64(1),
#  np.str_('244.13'): np.int64(1),
#  np.str_('244.22'): np.int64(1),
#  np.str_('244.25'): np.int64(11),
#  np.str_('244.27'): np.int64(2),
#  np.str_('244.29'): np.int64(1),
#  np.str_('244.36'): np.int64(8),
#  np.str_('244.46'): np.int64(1),
#  np.str_('244.76'): np.int64(4),
#  np.str_('244.8'): np.int64(3),
#  np.str_('244.91'): np.int64(1),
#  np.str_('244.96'): np.int64(1),
#  np.str_('245.15'): np.int64(1),
#  np.str_('245.16'): np.int64(2),
#  np.str_('245.31'): np.int64(1),
#  np.str_('245.51'): np.int64(8),
#  np.str_('245.78'): np.int64(2),
#  np.str_('245.85'): np.int64(2),
#  np.str_('246.12'): np.int64(5),
#  np.str_('246.15'): np.int64(1),
#  np.str_('246.31'): np.int64(1),
#  np.str_('246.51'): np.int64(1),
#  np.str_('246.62'): np.int64(6),
#  np.str_('246.73'): np.int64(3),
#  np.str_('247.16'): np.int64(1),
#  np.str_('247.43'): np.int64(1),
#  np.str_('247.45'): np.int64(1),
#  np.str_('247.56'): np.int64(1),
#  np.str_('247.57'): np.int64(1),
#  np.str_('247.76'): np.int64(1),
#  np.str_('247.97'): np.int64(9),
#  np.str_('248.01'): np.int64(4),
#  np.str_('248.21'): np.int64(1),
#  np.str_('248.36'): np.int64(4),
#  np.str_('248.48'): np.int64(3),
#  np.str_('248.66'): np.int64(2),
#  np.str_('248.78'): np.int64(1),
#  np.str_('248.82'): np.int64(1),
#  np.str_('248.89'): np.int64(1),
#  np.str_('249.04'): np.int64(1),
#  np.str_('249.07'): np.int64(1),
#  np.str_('249.08'): np.int64(1),
#  np.str_('249.54'): np.int64(3),
#  np.str_('250.1'): np.int64(7),
#  np.str_('250.15'): np.int64(1),
#  np.str_('250.29'): np.int64(25),
#  np.str_('250.36'): np.int64(1),
#  np.str_('250.73'): np.int64(1),
#  np.str_('250.79'): np.int64(1),
#  np.str_('251.23'): np.int64(1),
#  np.str_('251.24'): np.int64(1),
#  np.str_('251.29'): np.int64(1),
#  np.str_('251.3'): np.int64(1),
#  np.str_('251.32'): np.int64(1),
#  np.str_('251.36'): np.int64(14),
#  np.str_('251.4'): np.int64(3),
#  np.str_('251.56'): np.int64(1),
#  np.str_('251.59'): np.int64(1),
#  np.str_('251.61'): np.int64(6),
#  np.str_('251.65'): np.int64(3),
#  np.str_('251.68'): np.int64(2),
#  np.str_('251.75'): np.int64(2),
#  np.str_('252.15'): np.int64(1),
#  np.str_('252.21'): np.int64(1),
#  np.str_('252.44'): np.int64(1),
#  np.str_('252.46'): np.int64(1),
#  np.str_('252.49'): np.int64(2),
#  np.str_('252.62'): np.int64(1),
#  np.str_('252.67'): np.int64(1),
#  np.str_('252.78'): np.int64(1),
#  np.str_('253.07'): np.int64(2),
#  np.str_('253.1'): np.int64(1),
#  np.str_('253.17'): np.int64(1),
#  np.str_('253.18'): np.int64(10),
#  np.str_('253.32'): np.int64(1),
#  np.str_('253.36'): np.int64(1),
#  np.str_('253.42'): np.int64(1),
#  np.str_('253.55'): np.int64(1),
#  np.str_('253.57'): np.int64(1),
#  np.str_('253.9'): np.int64(3),
#  np.str_('254.03'): np.int64(2),
#  np.str_('254.07'): np.int64(1),
#  np.str_('254.08'): np.int64(1),
#  np.str_('254.54'): np.int64(1),
#  np.str_('254.88'): np.int64(1),
#  np.str_('254.91'): np.int64(5),
#  np.str_('255.04'): np.int64(20),
#  np.str_('255.1'): np.int64(2),
#  np.str_('255.27'): np.int64(1),
#  np.str_('255.29'): np.int64(1),
#  np.str_('255.3'): np.int64(4),
#  np.str_('255.72'): np.int64(1),
#  np.str_('255.78'): np.int64(1),
#  np.str_('255.9'): np.int64(3),
#  np.str_('255.96'): np.int64(1),
#  np.str_('256.23'): np.int64(2),
#  np.str_('256.3'): np.int64(1),
#  np.str_('256.46'): np.int64(1),
#  np.str_('256.55'): np.int64(1),
#  np.str_('256.94'): np.int64(3),
#  np.str_('256.98'): np.int64(1),
#  np.str_('257.04'): np.int64(1),
#  np.str_('257.09'): np.int64(1),
#  np.str_('257.24'): np.int64(1),
#  np.str_('257.85'): np.int64(1),
#  np.str_('258.1'): np.int64(22),
#  np.str_('258.22'): np.int64(1),
#  np.str_('258.32'): np.int64(2),
#  np.str_('258.42'): np.int64(1),
#  np.str_('258.44'): np.int64(1),
#  np.str_('258.49'): np.int64(1),
#  np.str_('258.53'): np.int64(3),
#  np.str_('258.6'): np.int64(1),
#  np.str_('258.7'): np.int64(2),
#  np.str_('258.71'): np.int64(2),
#  np.str_('258.76'): np.int64(1),
#  np.str_('258.86'): np.int64(1),
#  np.str_('259.35'): np.int64(1),
#  np.str_('259.52'): np.int64(1),
#  np.str_('259.53'): np.int64(1),
#  np.str_('259.62'): np.int64(1),
#  np.str_('259.65'): np.int64(2),
#  np.str_('259.72'): np.int64(1),
#  np.str_('259.8'): np.int64(1),
#  np.str_('259.99'): np.int64(1),
#  np.str_('260.04'): np.int64(1),
#  np.str_('260.11'): np.int64(1),
#  np.str_('260.16'): np.int64(1),
#  np.str_('260.41'): np.int64(1),
#  np.str_('260.46'): np.int64(2),
#  np.str_('260.52'): np.int64(1),
#  np.str_('260.53'): np.int64(1),
#  np.str_('260.55'): np.int64(6),
#  np.str_('260.73'): np.int64(2),
#  np.str_('260.85'): np.int64(3),
#  np.str_('261.08'): np.int64(1),
#  np.str_('261.22'): np.int64(1),
#  np.str_('261.32'): np.int64(1),
#  np.str_('261.5'): np.int64(1),
#  np.str_('261.61'): np.int64(1),
#  np.str_('261.64'): np.int64(1),
#  np.str_('261.65'): np.int64(2),
#  np.str_('261.88'): np.int64(14),
#  np.str_('261.93'): np.int64(1),
#  np.str_('262.03'): np.int64(1),
#  np.str_('262.15'): np.int64(1),
#  np.str_('262.23'): np.int64(1),
#  np.str_('262.24'): np.int64(1),
#  ...}

# %% [markdown]
# Del análisis de los datos contenidos en la categoría 'installment' se observa lo siguiente:
#
# - Los registros proporcionados corresponden al pago mensual que debe efectuar cada cliente.
# - Los valores almacenados representan cantidades numéricas y, por tanto, pueden ser tratados como datos de tipo flotante para facilitar su análisis y procesamiento.
# - Se detectan 500 registros en los que el monto del préstamo no fue almacenado correctamente, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron valores con formatos atípicos o inconsistentes en comparación con el resto de los registros de esta categoría, lo que indica una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.
# - Convertir los valores válidos de la categoría desde cadenas de texto a un tipo de dato numérico (por ejemplo, float), permitiendo la aplicación de técnicas estadísticas y de análisis cuantitativo sobre esta variable.

# %% [markdown]
# ### Categoría 'grade'

# %% [markdown]
# Calificación del préstamo asignada por Lending Club (LC).

# %%
caracteristicas_data[label_data[8]]
# Out:
# {np.str_(''): np.int64(515),
#  np.str_('A'): np.int64(1632),
#  np.str_('B'): np.int64(2606),
#  np.str_('C'): np.int64(2766),
#  np.str_('D'): np.int64(1389),
#  np.str_('E'): np.int64(816),
#  np.str_('F'): np.int64(236),
#  np.str_('G'): np.int64(40)}

# %% [markdown]
# Los registros contenidos en esta categoría corresponden a la calificación crediticia asignada al préstamo por la entidad financiera. Dicha calificación se expresa mediante categorías ordenadas de la letra A a la G, donde las categorías más cercanas a A representan un menor nivel de riesgo crediticio, mientras que las categorías próximas a G indican un mayor riesgo asociado al préstamo.
#
# Del análisis de los datos contenidos en la categoría 'grade' se observa lo siguiente:
#
# - Los registros proporcionados describen la clasificación de cada uno de los préstamos efectuados por la entidad.
# - Los valores almacenados corresponden a categorías cualitativas y, por tanto, pueden ser representados mediante cadenas de texto.
# - Se detectan 515 registros en los que la categoría no está definida de manera adecuada, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ### Categoría 'sub_grade'

# %% [markdown]
# Calificación del préstamo asignada por Lending Club (LC). (clasificación basada en sub-grados)

# %%
caracteristicas_data[label_data[9]]
# Out:
# {np.str_(''): np.int64(514),
#  np.str_('A1'): np.int64(285),
#  np.str_('A2'): np.int64(278),
#  np.str_('A3'): np.int64(239),
#  np.str_('A4'): np.int64(323),
#  np.str_('A5'): np.int64(502),
#  np.str_('B1'): np.int64(509),
#  np.str_('B2'): np.int64(517),
#  np.str_('B3'): np.int64(530),
#  np.str_('B4'): np.int64(553),
#  np.str_('B5'): np.int64(494),
#  np.str_('C1'): np.int64(629),
#  np.str_('C2'): np.int64(567),
#  np.str_('C3'): np.int64(586),
#  np.str_('C4'): np.int64(564),
#  np.str_('C5'): np.int64(423),
#  np.str_('D1'): np.int64(391),
#  np.str_('D2'): np.int64(267),
#  np.str_('D3'): np.int64(250),
#  np.str_('D4'): np.int64(255),
#  np.str_('D5'): np.int64(223),
#  np.str_('E1'): np.int64(235),
#  np.str_('E2'): np.int64(162),
#  np.str_('E3'): np.int64(171),
#  np.str_('E4'): np.int64(139),
#  np.str_('E5'): np.int64(114),
#  np.str_('F1'): np.int64(94),
#  np.str_('F2'): np.int64(52),
#  np.str_('F3'): np.int64(34),
#  np.str_('F4'): np.int64(43),
#  np.str_('F5'): np.int64(16),
#  np.str_('G1'): np.int64(19),
#  np.str_('G2'): np.int64(10),
#  np.str_('G3'): np.int64(3),
#  np.str_('G4'): np.int64(7),
#  np.str_('G5'): np.int64(2)}

# %% [markdown]
# Esta variable representa la subcalificación crediticia asignada al préstamo por la entidad financiera. La clasificación se expresa mediante una combinación de una letra y un número, donde la letra identifica la categoría general de riesgo y el número establece una graduación más específica dentro de dicha categoría. Esta variable permite una caracterización más detallada del perfil de riesgo asociado al préstamo.
#
# Del análisis de los datos contenidos en la categoría 'sub_grade' se observa lo siguiente:
#
# - Los registros proporcionados describen la clasificación de cada uno de los préstamos efectuados por la entidad por medio de sub-grados identificados por la asignación numérica de la clasificación.
# - Los valores almacenados corresponden a categorías cualitativas y, por tanto, pueden ser representados mediante cadenas de texto.
# - Se detectan 514 registros en los que la categoría no está definida de manera adecuada, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ### Categoría 'verification_status'

# %% [markdown]
# Indica el estado de verificación de los ingresos declarados por el solicitante, especificando si dichos ingresos fueron verificados por la entidad financiera, no fueron verificados o si únicamente se verificó la fuente de ingresos.

# %%
caracteristicas_data[label_data[10]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('Not Verified'): np.int64(2673),
#  np.str_('Source Verified'): np.int64(4116),
#  np.str_('Verified'): np.int64(2711)}

# %% [markdown]
# Los registros contenidos en esta categoría corresponden al estado de verificación de los ingresos declarados por el prestatario durante el proceso de solicitud del préstamo. En particular, la variable distingue entre ingresos no verificados (Not Verified), ingresos cuya fuente fue verificada (Source Verified) e ingresos completamente verificados por la entidad financiera (Verified).
#
# Del análisis de los datos contenidos en la categoría 'verification_status' se observa lo siguiente:
#
# - Los registros proporcionados describen el estado de verificación de los ingresos del cliente que solicitó el préstamo a la entidad.
# - Los valores almacenados corresponden a categorías cualitativas y, por tanto, pueden ser representados mediante cadenas de texto.
# - Se detectan 500 registros en los que la categoría no está definida de manera adecuada, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ### Categoría 'url'

# %% [markdown]
# URL de la página de Lending Club que contiene la información asociada a la solicitud o publicación del préstamo.

# %%
caracteristicas_data[label_data[11]]
# Out:
# {np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=12606806'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=13026045'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=1312426'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=14187903'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=14428496'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=14470171'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=14550531'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=14669896'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=15389420'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=16130931'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=19137119'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=19646726'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=22403153'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=25276117'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=31207716'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=31888135'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=34462110'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=34883768'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=35683282'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36169417'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36201871'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36241014'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36561402'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36763239'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36802496'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36806601'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=36950419'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37011266'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37051229'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37068509'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37107114'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37257668'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37267742'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37329129'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=373332'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37600541'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37601431'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37612109'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37612196'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37620643'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37621437'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37621803'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37640409'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37641179'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37641650'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37651425'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37652106'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37671458'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37671833'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37672125'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37680706'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37680875'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37691298'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37691377'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37691997'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37692393'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37700602'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37730598'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37731126'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37750229'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37750958'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37751648'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37752011'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37811574'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37811673'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37821356'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37841440'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37866237'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37866544'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37887123'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37887364'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37907332'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37917304'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37927296'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37927549'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37938334'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37948249'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37948610'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37958255'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37978181'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37998364'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=37998603'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38018251'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38028516'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38058468'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38078645'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38098252'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38108327'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38141178'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38141958'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38151414'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38151481'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38151638'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38162231'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38162496'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38171495'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38171566'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38171736'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38171949'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38171990'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38172140'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38181359'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38182010'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38191359'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38201230'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38211297'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38211876'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38212467'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38212617'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38212702'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38221902'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38232469'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38242030'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38242401'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38261283'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38261765'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38272059'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38272154'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38281530'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38282489'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38291244'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38301173'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38311414'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38311693'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38312082'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38312255'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38321857'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38341427'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38342108'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38342391'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38342504'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38362671'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38382064'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38413636'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38413974'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38414180'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38414664'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38414904'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38415266'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38415532'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38416309'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38417018'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38417249'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38417514'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38417815'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38419045'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38425210'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38426634'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38426735'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38426884'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38427284'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38427410'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38427713'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38428098'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38428632'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38428667'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38429476'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38429497'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38429690'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38434284'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38434338'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38434390'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38434416'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38434647'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38435127'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38435159'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38435222'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38435515'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38435631'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436092'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436311'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436314'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436474'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436492'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38436495'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38437174'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38437586'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38439103'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38439595'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38439668'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38439758'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38439893'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38444939'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38445485'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38445586'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38446091'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38446337'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38447759'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38448056'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38448057'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38448211'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38448348'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38449284'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38449346'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38449503'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38450494'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38454679'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38455220'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38455361'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38455422'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38455671'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38455740'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38456609'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38456848'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38456879'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38457485'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38457561'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38457668'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38458678'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38458785'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38459357'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38459726'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38459802'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38464726'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38465066'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38465134'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38465473'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38465877'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38467100'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38467122'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38467316'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38467857'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38468646'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38469313'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38469626'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38470015'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38474257'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38474546'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38476233'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38476464'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38477213'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38477292'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38477419'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38477648'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38477891'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38478413'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38478641'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38479225'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38479270'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38479558'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38479775'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38480061'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38480400'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38484479'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38484682'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38485781'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38494184'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38494616'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38495019'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38495196'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38495839'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38496080'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38496714'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38497610'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38497750'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38498199'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38498304'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38498680'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38500334'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38504696'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38504905'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38505703'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38505862'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38506488'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38506528'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38507183'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38507637'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38508138'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38508253'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38508580'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38509090'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38509242'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38509947'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38515018'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38515863'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38516011'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38516054'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38517448'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38518138'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38518155'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38518809'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519042'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519064'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519068'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519245'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519327'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519742'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38519839'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38520209'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38524353'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38524611'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38525079'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38525761'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38525848'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38526030'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38526448'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38527247'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38527442'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38528338'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38528662'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38529134'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38529138'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38534197'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38534445'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38534584'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38534727'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38534884'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38535013'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38535165'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38535478'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38535676'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38536432'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38537661'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38537676'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38538355'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38544832'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38545991'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38546208'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38546363'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38548704'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38549165'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38550070'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38554633'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38554825'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38555408'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38555647'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38556527'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38557516'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38557749'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38558918'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38559051'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38559841'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38559923'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38559964'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38559971'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38560190'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38560580'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38565646'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38565781'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38566235'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38568231'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38568445'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38568923'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38574329'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38574688'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38575020'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38575427'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38575507'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38575647'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38576232'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38576432'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578152'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578253'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578316'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578335'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578771'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38578931'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38579491'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38579703'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38580404'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38584625'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38585064'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38585277'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38586210'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38586639'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38586770'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587208'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587222'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587453'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587664'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587667'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38587850'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38589003'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38589249'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38589397'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38589992'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38596011'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38596064'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38596666'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38597008'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38597444'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38597623'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38598686'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38598730'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38598757'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38599004'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38599307'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38599875'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38604429'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38605496'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38606303'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38607129'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38607774'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38608511'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38608899'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38609776'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38610104'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38614123'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38614136'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38614453'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38614686'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38614987'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38615026'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38615856'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38619221'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38619427'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38619484'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38624147'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38624484'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38625595'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38625960'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38626358'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38626539'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38626776'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38627361'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38627577'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38627820'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38628265'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38628800'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38628823'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38629293'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38629302'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38629429'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38630171'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38630522'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38634333'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38634902'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38635104'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38635231'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38635267'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38636413'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38636452'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38636540'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38636713'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38637029'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38637943'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638030'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638088'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638104'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638436'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638464'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38638818'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38640466'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38644242'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38644517'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38644866'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645079'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645088'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645124'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645450'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645585'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38645761'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38646795'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38647108'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38648002'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38648480'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38648684'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38649441'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38654540'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38656135'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38656672'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38656934'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38657174'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38657221'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38658314'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38658847'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38659637'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38659640'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38659673'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38660125'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38660226'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38676187'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38697764'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38697859'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38697967'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38699481'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38699512'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38700451'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38700485'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38762135'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38762271'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38762530'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38772119'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38802324'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38812524'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38812579'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38832159'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38862362'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38882248'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38892180'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38892250'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38902508'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38922367'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38922413'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38942214'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38942256'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38988185'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38988234'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=38998263'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=39048278'): np.int64(1),
# ...
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40198057'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40207609'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40207654'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40207716'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40227434'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40227982'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40237830'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40238227'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40247530'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40247792'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40247818'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40257152'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40257398'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40277306'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40277437'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40277838'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40278243'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40278432'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40278450'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40287177'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40287182'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40287591'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40287602'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40287639'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40288176'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40297405'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40297586'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40297845'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40297965'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40298097'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40298157'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40307781'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317498'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317524'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317686'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317777'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317917'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40317923'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40318017'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40318214'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40327372'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40327388'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40327799'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40337449'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40337954'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40350535'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40351221'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40351451'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40352068'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40353115'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40353543'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40353819'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40353941'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40354398'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40354465'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40355705'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40355978'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40360547'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40361860'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40362564'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40362953'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40363003'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40370487'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40370548'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40370555'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40370940'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40371236'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40371294'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40371340'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40371748'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40372163'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40373016'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40373432'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40373750'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40374030'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40380886'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40381857'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40381892'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40382671'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40382999'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40383569'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40385571'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40385677'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40386161'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40386670'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40386976'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40390116'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40390177'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40390915'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40391120'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40392063'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40392082'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40392106'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40392183'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40392383'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40393112'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40393128'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40400294'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40400432'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40401029'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40401923'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410530'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410609'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410767'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410869'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410895'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40410999'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40411440'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40412356'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40412749'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40412780'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40413028'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40413463'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40413857'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40420175'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40420481'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40420486'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40420550'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40421263'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40421561'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40421656'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40422290'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40422488'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40422579'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40422791'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40422955'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40423455'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40430209'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40431558'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40431779'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40431975'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40432239'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40432754'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40440185'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40440338'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40440654'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40441043'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40441627'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40442015'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40442429'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40443816'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40450227'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40451331'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40451886'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40451890'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40452204'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40452937'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40453066'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40453665'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40453767'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40453979'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40460385'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40461150'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40461164'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40462361'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40462752'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40463001'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40463110'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40463741'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40470280'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40470420'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40470700'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40471138'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40471729'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40472332'): np.int64(1),
#  np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=40472398'): np.int64(1),
#  ...}

# %%
arreglo_count = [item for _, item in caracteristicas_data[label_data[11]].items()]
max(arreglo_count)
# Out:
# np.int64(1)

# %% [markdown]
# El análisis de las direcciones contenidas en la categoría 'url' evidencia que:
#
# - Mantienen una correspondencia única con cada uno de los registros extraídos, por lo que pueden considerarse direcciones electrónicas únicas dentro del conjunto de datos, mediante las cuales se extrajeron los datos que fueron registrados.
# - Se descarta la presencia de registros duplicados, ya que cada dirección posee una única ocurrencia en la base de datos analizada.

# %% [markdown]
# ### Categoría 'addr_state'

# %% [markdown]
# El estado (entidad federativa) reportado por el prestatario en la solicitud del préstamo.

# %%
caracteristicas_data[label_data[12]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('AK'): np.int64(26),
#  np.str_('AL'): np.int64(119),
#  np.str_('AR'): np.int64(74),
#  np.str_('AZ'): np.int64(220),
#  np.str_('CA'): np.int64(1336),
#  np.str_('CO'): np.int64(201),
#  np.str_('CT'): np.int64(143),
#  np.str_('DC'): np.int64(27),
#  np.str_('DE'): np.int64(27),
#  np.str_('FL'): np.int64(690),
#  np.str_('GA'): np.int64(321),
#  np.str_('HI'): np.int64(44),
#  np.str_('IL'): np.int64(389),
#  np.str_('IN'): np.int64(152),
#  np.str_('KS'): np.int64(84),
#  np.str_('KY'): np.int64(84),
#  np.str_('LA'): np.int64(116),
#  np.str_('MA'): np.int64(210),
#  np.str_('MD'): np.int64(222),
#  np.str_('ME'): np.int64(10),
#  np.str_('MI'): np.int64(267),
#  np.str_('MN'): np.int64(156),
#  np.str_('MO'): np.int64(160),
#  np.str_('MS'): np.int64(61),
#  np.str_('MT'): np.int64(28),
#  np.str_('NC'): np.int64(261),
#  np.str_('ND'): np.int64(16),
#  np.str_('NE'): np.int64(25),
#  np.str_('NH'): np.int64(58),
#  np.str_('NJ'): np.int64(341),
#  np.str_('NM'): np.int64(57),
#  np.str_('NV'): np.int64(130),
#  np.str_('NY'): np.int64(777),
#  np.str_('OH'): np.int64(312),
#  np.str_('OK'): np.int64(83),
#  np.str_('OR'): np.int64(108),
#  np.str_('PA'): np.int64(320),
#  np.str_('RI'): np.int64(40),
#  np.str_('SC'): np.int64(107),
#  np.str_('SD'): np.int64(24),
#  np.str_('TN'): np.int64(143),
#  np.str_('TX'): np.int64(758),
#  np.str_('UT'): np.int64(74),
#  np.str_('VA'): np.int64(242),
#  np.str_('VT'): np.int64(17),
#  np.str_('WA'): np.int64(216),
#  np.str_('WI'): np.int64(148),
#  np.str_('WV'): np.int64(49),
#  np.str_('WY'): np.int64(27)}

# %% [markdown]
# Los registros contenidos en esta categoría corresponden al estado de residencia declarado por el prestatario durante el proceso de solicitud del préstamo. La información se encuentra representada mediante abreviaturas oficiales de los estados y territorios de los Estados Unidos, por lo que la variable proporciona una referencia geográfica asociada a cada solicitante.
#
# Del análisis de los datos contenidos en la categoría 'addr_state' se observa lo siguiente:
#
# - Los registros proporcionados describen el estado de la persona que solicitó el préstamo.
# - Los valores almacenados corresponden a categorías cualitativas y, por tanto, pueden ser representados mediante cadenas de texto.
# - Se detectan 500 registros en los que la categoría no está definida de manera adecuada, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ### Categoría 'total_pymnt'

# %% [markdown]
# Representa el monto acumulado que el prestatario ha reembolsado hasta la fecha respecto al capital financiado, incluyendo los pagos efectuados durante la vigencia del préstamo.

# %%
caracteristicas_data[label_data[13]]
# Out:
# {np.str_(''): np.int64(500),
#  np.str_('0.0'): np.int64(384),
#  np.str_('0.74'): np.int64(1),
#  np.str_('100.0'): np.int64(1),
#  np.str_('1000.62'): np.int64(1),
#  np.str_('1000.81'): np.int64(2),
#  np.str_('10002.6'): np.int64(1),
#  np.str_('10006.27'): np.int64(1),
#  np.str_('1001.69'): np.int64(1),
#  np.str_('1001.71'): np.int64(1),
#  np.str_('1001.73'): np.int64(1),
#  np.str_('1001.8'): np.int64(3),
#  np.str_('1001.96'): np.int64(1),
#  np.str_('1002.1'): np.int64(1),
#  np.str_('1002.12'): np.int64(2),
#  np.str_('1002.17'): np.int64(1),
#  np.str_('1002.66'): np.int64(1),
#  np.str_('1002.82'): np.int64(2),
#  np.str_('10024.1'): np.int64(1),
#  np.str_('1003.56'): np.int64(1),
#  np.str_('1003.84'): np.int64(1),
#  np.str_('10030.73'): np.int64(1),
#  np.str_('10033.58'): np.int64(1),
#  np.str_('1004.0'): np.int64(1),
#  np.str_('1004.28'): np.int64(1),
#  np.str_('1004.34'): np.int64(1),
#  np.str_('1004.62'): np.int64(1),
#  np.str_('10047.8'): np.int64(1),
#  np.str_('1005.55'): np.int64(1),
#  np.str_('10054.96'): np.int64(1),
#  np.str_('10058.0'): np.int64(1),
#  np.str_('1006.28'): np.int64(1),
#  np.str_('1006.34'): np.int64(1),
#  np.str_('1006.78'): np.int64(1),
#  np.str_('10065.06'): np.int64(1),
#  np.str_('1007.08'): np.int64(1),
#  np.str_('1008.16'): np.int64(1),
#  np.str_('1008.21'): np.int64(2),
#  np.str_('10085.5'): np.int64(1),
#  np.str_('1009.06'): np.int64(2),
#  np.str_('1009.5'): np.int64(1),
#  np.str_('1009.65'): np.int64(1),
#  np.str_('10108.38'): np.int64(1),
#  np.str_('1011.16'): np.int64(1),
#  np.str_('1012.01'): np.int64(2),
#  np.str_('1012.44'): np.int64(1),
#  np.str_('1013.46'): np.int64(1),
#  np.str_('1013.53'): np.int64(1),
#  np.str_('10139.52'): np.int64(1),
#  np.str_('1014.28'): np.int64(1),
#  np.str_('1014.5'): np.int64(1),
#  np.str_('1015.12'): np.int64(1),
#  np.str_('1015.57'): np.int64(1),
#  np.str_('1015.59'): np.int64(1),
#  np.str_('10153.89'): np.int64(1),
#  np.str_('1016.08'): np.int64(2),
#  np.str_('1016.59'): np.int64(1),
#  np.str_('10164.14'): np.int64(1),
#  np.str_('10166.43'): np.int64(1),
#  np.str_('1017.02'): np.int64(1),
#  np.str_('1017.39'): np.int64(1),
#  np.str_('1017.42'): np.int64(1),
#  np.str_('10171.05'): np.int64(1),
#  np.str_('10173.99'): np.int64(1),
#  np.str_('10175.11'): np.int64(1),
#  np.str_('10176.33'): np.int64(1),
#  np.str_('10181.2'): np.int64(1),
#  np.str_('10182.02'): np.int64(1),
#  np.str_('1019.48'): np.int64(1),
#  np.str_('10199.53'): np.int64(1),
#  np.str_('1020.32'): np.int64(1),
#  np.str_('1020.41'): np.int64(2),
#  np.str_('1021.33'): np.int64(3),
#  np.str_('1021.55'): np.int64(1),
#  np.str_('1023.52'): np.int64(1),
#  np.str_('10238.58'): np.int64(1),
#  np.str_('1024.79'): np.int64(1),
#  np.str_('10251.07'): np.int64(1),
#  np.str_('1026.63'): np.int64(1),
#  np.str_('1026.71'): np.int64(1),
#  np.str_('10265.62'): np.int64(1),
#  np.str_('1027.27'): np.int64(1),
#  np.str_('1027.96'): np.int64(1),
#  np.str_('10271.36'): np.int64(1),
#  np.str_('10275.76'): np.int64(1),
#  np.str_('1028.75'): np.int64(1),
#  np.str_('1028.85'): np.int64(1),
#  np.str_('1028.9'): np.int64(1),
#  np.str_('1028.99'): np.int64(1),
#  np.str_('10284.01'): np.int64(1),
#  np.str_('1029.2'): np.int64(1),
#  np.str_('1029.58'): np.int64(1),
#  np.str_('1029.79'): np.int64(1),
#  np.str_('1029.97'): np.int64(1),
#  np.str_('1029.99'): np.int64(1),
#  np.str_('10299.7'): np.int64(1),
#  np.str_('1030.18'): np.int64(1),
#  np.str_('1030.32'): np.int64(1),
#  np.str_('1030.85'): np.int64(1),
#  np.str_('1030.89'): np.int64(1),
#  np.str_('1032.32'): np.int64(1),
#  np.str_('10338.87'): np.int64(1),
#  np.str_('1034.14'): np.int64(1),
#  np.str_('1034.36'): np.int64(1),
#  np.str_('1034.37'): np.int64(1),
#  np.str_('1034.87'): np.int64(1),
#  np.str_('10344.55'): np.int64(1),
#  np.str_('1035.08'): np.int64(1),
#  np.str_('10359.99'): np.int64(1),
#  np.str_('1036.45'): np.int64(1),
#  np.str_('1036.96'): np.int64(2),
#  np.str_('1037.18'): np.int64(1),
#  np.str_('1037.88'): np.int64(3),
#  np.str_('1038.36'): np.int64(1),
#  np.str_('1038.79'): np.int64(1),
#  np.str_('1039.33'): np.int64(1),
#  np.str_('1039.62'): np.int64(1),
#  np.str_('1039.78'): np.int64(1),
#  np.str_('10391.37'): np.int64(1),
#  np.str_('1041.03'): np.int64(1),
#  np.str_('1041.31'): np.int64(1),
#  np.str_('1041.97'): np.int64(1),
#  np.str_('1042.53'): np.int64(1),
#  np.str_('1042.74'): np.int64(1),
#  np.str_('1042.77'): np.int64(1),
#  np.str_('1042.98'): np.int64(1),
#  np.str_('10426.9'): np.int64(1),
#  np.str_('1043.12'): np.int64(1),
#  np.str_('1043.35'): np.int64(1),
#  np.str_('1043.76'): np.int64(1),
#  np.str_('10443.25'): np.int64(1),
#  np.str_('1045.47'): np.int64(2),
#  np.str_('1046.14'): np.int64(1),
#  np.str_('1047.52'): np.int64(1),
#  np.str_('1047.57'): np.int64(1),
#  np.str_('1047.86'): np.int64(1),
#  np.str_('10473.2'): np.int64(1),
#  np.str_('10477.53'): np.int64(1),
#  np.str_('1048.48'): np.int64(1),
#  np.str_('1048.53'): np.int64(1),
#  np.str_('1048.71'): np.int64(1),
#  np.str_('10482.34'): np.int64(1),
#  np.str_('10482.82'): np.int64(1),
#  np.str_('1049.12'): np.int64(1),
#  np.str_('1049.38'): np.int64(1),
#  np.str_('1049.94'): np.int64(1),
#  np.str_('10495.98'): np.int64(1),
#  np.str_('1050.08'): np.int64(1),
#  np.str_('1050.09'): np.int64(1),
#  np.str_('1050.33'): np.int64(1),
#  np.str_('1050.41'): np.int64(1),
#  np.str_('1050.43'): np.int64(1),
#  np.str_('1050.6'): np.int64(3),
#  np.str_('1050.64'): np.int64(1),
#  np.str_('10504.38'): np.int64(1),
#  np.str_('10508.77'): np.int64(1),
#  np.str_('1052.24'): np.int64(1),
#  np.str_('1052.4'): np.int64(2),
#  np.str_('1052.83'): np.int64(1),
#  np.str_('1052.93'): np.int64(1),
#  np.str_('10522.79'): np.int64(1),
#  np.str_('1053.14'): np.int64(1),
#  np.str_('1053.56'): np.int64(1),
#  np.str_('10545.65'): np.int64(1),
#  np.str_('1056.19'): np.int64(1),
#  np.str_('1056.4'): np.int64(1),
#  np.str_('1056.6'): np.int64(1),
#  np.str_('1056.64'): np.int64(1),
#  np.str_('1058.12'): np.int64(1),
#  np.str_('1058.38'): np.int64(1),
#  np.str_('1058.41'): np.int64(3),
#  np.str_('10589.93'): np.int64(1),
#  np.str_('1059.15'): np.int64(1),
#  np.str_('10596.98'): np.int64(1),
#  np.str_('10601.59'): np.int64(1),
#  np.str_('10603.46'): np.int64(2),
#  np.str_('1061.08'): np.int64(1),
#  np.str_('1061.4'): np.int64(1),
#  np.str_('1061.43'): np.int64(1),
#  np.str_('1061.86'): np.int64(1),
#  np.str_('10618.33'): np.int64(1),
#  np.str_('1062.36'): np.int64(1),
#  np.str_('1063.58'): np.int64(1),
#  np.str_('1063.79'): np.int64(1),
#  np.str_('1063.89'): np.int64(1),
#  np.str_('1064.32'): np.int64(1),
#  np.str_('1064.72'): np.int64(1),
#  np.str_('1065.12'): np.int64(1),
#  np.str_('1065.15'): np.int64(1),
#  np.str_('1066.61'): np.int64(1),
#  np.str_('1066.94'): np.int64(1),
#  np.str_('10666.08'): np.int64(1),
#  np.str_('1067.2'): np.int64(1),
#  np.str_('1068.2'): np.int64(1),
#  np.str_('1068.38'): np.int64(1),
#  np.str_('1069.62'): np.int64(1),
#  np.str_('1070.62'): np.int64(1),
#  np.str_('1071.03'): np.int64(1),
#  np.str_('1071.47'): np.int64(1),
#  np.str_('1071.62'): np.int64(2),
#  np.str_('10716.98'): np.int64(1),
#  np.str_('1072.0'): np.int64(2),
#  np.str_('1072.24'): np.int64(1),
#  np.str_('1072.82'): np.int64(1),
#  np.str_('1073.2'): np.int64(1),
#  np.str_('1073.26'): np.int64(1),
#  np.str_('1073.28'): np.int64(1),
#  np.str_('1073.82'): np.int64(2),
#  np.str_('1074.69'): np.int64(1),
#  np.str_('1074.79'): np.int64(1),
#  np.str_('10740.43'): np.int64(1),
#  np.str_('1075.15'): np.int64(1),
#  np.str_('1075.27'): np.int64(1),
#  np.str_('1076.1'): np.int64(1),
#  np.str_('10764.52'): np.int64(1),
#  np.str_('1077.15'): np.int64(1),
#  np.str_('1077.4'): np.int64(1),
#  np.str_('1077.73'): np.int64(1),
#  np.str_('1077.8'): np.int64(1),
#  np.str_('10770.85'): np.int64(1),
#  np.str_('1078.56'): np.int64(1),
#  np.str_('1078.69'): np.int64(1),
#  np.str_('1078.82'): np.int64(1),
#  np.str_('10780.74'): np.int64(1),
#  np.str_('1079.01'): np.int64(2),
#  np.str_('1079.26'): np.int64(1),
#  np.str_('1079.66'): np.int64(1),
#  np.str_('10795.35'): np.int64(1),
#  np.str_('10796.73'): np.int64(1),
#  np.str_('10798.29'): np.int64(1),
#  np.str_('1080.11'): np.int64(1),
#  np.str_('1080.59'): np.int64(3),
#  np.str_('1080.79'): np.int64(1),
#  np.str_('1080.9'): np.int64(1),
#  np.str_('1081.47'): np.int64(1),
#  np.str_('1081.75'): np.int64(1),
#  np.str_('1082.22'): np.int64(1),
#  np.str_('1082.91'): np.int64(1),
#  np.str_('1083.26'): np.int64(1),
#  np.str_('10839.4'): np.int64(1),
#  np.str_('1084.2'): np.int64(1),
#  np.str_('1084.83'): np.int64(1),
#  np.str_('1086.8'): np.int64(1),
#  np.str_('10863.51'): np.int64(1),
#  np.str_('1087.23'): np.int64(1),
#  np.str_('1087.97'): np.int64(1),
#  np.str_('1088.4'): np.int64(1),
#  np.str_('1088.71'): np.int64(1),
#  np.str_('1088.86'): np.int64(1),
#  np.str_('1089.47'): np.int64(1),
#  np.str_('1089.53'): np.int64(1),
#  np.str_('109.73'): np.int64(1),
#  np.str_('1090.46'): np.int64(1),
#  np.str_('1090.63'): np.int64(1),
#  np.str_('1090.82'): np.int64(1),
#  np.str_('1091.39'): np.int64(2),
#  np.str_('1091.93'): np.int64(1),
#  np.str_('10917.31'): np.int64(1),
#  np.str_('1092.79'): np.int64(1),
#  np.str_('1092.82'): np.int64(1),
#  np.str_('1092.88'): np.int64(1),
#  np.str_('1093.0'): np.int64(1),
#  np.str_('1093.34'): np.int64(1),
#  np.str_('1093.99'): np.int64(1),
#  np.str_('1094.75'): np.int64(2),
#  np.str_('1095.01'): np.int64(1),
#  np.str_('1095.16'): np.int64(2),
#  np.str_('1095.2'): np.int64(1),
#  np.str_('1096.0'): np.int64(1),
#  np.str_('1096.29'): np.int64(1),
#  np.str_('1096.52'): np.int64(3),
#  np.str_('10961.22'): np.int64(1),
#  np.str_('10965.09'): np.int64(1),
#  np.str_('1097.06'): np.int64(1),
#  np.str_('1097.43'): np.int64(1),
#  np.str_('1097.91'): np.int64(1),
#  np.str_('1097.93'): np.int64(1),
#  np.str_('1097.94'): np.int64(2),
#  np.str_('1098.19'): np.int64(1),
#  np.str_('10988.62'): np.int64(1),
#  np.str_('1099.56'): np.int64(1),
#  np.str_('110.1'): np.int64(1),
#  np.str_('110.65'): np.int64(1),
#  np.str_('1100.57'): np.int64(1),
#  np.str_('1100.6'): np.int64(1),
#  np.str_('1102.13'): np.int64(1),
#  np.str_('1102.4'): np.int64(1),
#  np.str_('11028.28'): np.int64(1),
#  np.str_('11029.61'): np.int64(1),
#  np.str_('1103.1'): np.int64(1),
#  np.str_('1103.78'): np.int64(1),
#  np.str_('1104.72'): np.int64(1),
#  np.str_('1105.2'): np.int64(1),
#  np.str_('1105.34'): np.int64(1),
#  np.str_('1105.36'): np.int64(1),
#  np.str_('1106.2'): np.int64(2),
#  np.str_('1106.36'): np.int64(1),
#  np.str_('1106.44'): np.int64(1),
#  np.str_('1107.31'): np.int64(3),
#  np.str_('11072.03'): np.int64(1),
#  np.str_('1108.46'): np.int64(1),
#  np.str_('1108.62'): np.int64(1),
#  np.str_('11082.36'): np.int64(1),
#  np.str_('1109.13'): np.int64(1),
#  np.str_('1109.58'): np.int64(1),
#  np.str_('111.58'): np.int64(1),
#  np.str_('111.86'): np.int64(1),
#  np.str_('1111.04'): np.int64(3),
#  np.str_('1111.8'): np.int64(1),
#  np.str_('11119.21'): np.int64(1),
#  np.str_('1112.32'): np.int64(1),
#  np.str_('1112.96'): np.int64(1),
#  np.str_('1113.03'): np.int64(1),
#  np.str_('1113.25'): np.int64(1),
#  np.str_('1113.46'): np.int64(1),
#  np.str_('11139.87'): np.int64(1),
#  np.str_('1114.08'): np.int64(1),
#  np.str_('1114.76'): np.int64(1),
#  np.str_('1115.37'): np.int64(1),
#  np.str_('1115.71'): np.int64(1),
#  np.str_('1115.77'): np.int64(2),
#  np.str_('1115.94'): np.int64(1),
#  np.str_('11151.04'): np.int64(1),
#  np.str_('1116.88'): np.int64(1),
#  np.str_('1116.91'): np.int64(1),
#  np.str_('1117.41'): np.int64(1),
#  np.str_('1117.49'): np.int64(2),
#  np.str_('1117.86'): np.int64(1),
#  np.str_('11174.58'): np.int64(1),
#  np.str_('1118.41'): np.int64(1),
#  np.str_('1118.78'): np.int64(1),
#  np.str_('11193.32'): np.int64(1),
#  np.str_('112.11'): np.int64(1),
#  np.str_('1120.11'): np.int64(1),
#  np.str_('1120.39'): np.int64(1),
#  np.str_('1120.41'): np.int64(1),
#  np.str_('1120.66'): np.int64(1),
#  np.str_('1121.06'): np.int64(1),
#  np.str_('1121.43'): np.int64(1),
#  np.str_('11210.88'): np.int64(1),
#  np.str_('1122.3'): np.int64(1),
#  np.str_('1122.49'): np.int64(1),
#  np.str_('1122.94'): np.int64(1),
#  np.str_('11223.4'): np.int64(1),
#  np.str_('1123.69'): np.int64(2),
#  np.str_('1123.76'): np.int64(1),
#  np.str_('1123.84'): np.int64(1),
#  np.str_('1123.97'): np.int64(1),
#  np.str_('1124.25'): np.int64(1),
#  np.str_('1124.55'): np.int64(1),
#  np.str_('11240.85'): np.int64(1),
#  np.str_('11245.87'): np.int64(1),
#  np.str_('1125.67'): np.int64(2),
#  np.str_('1125.92'): np.int64(1),
#  np.str_('1126.09'): np.int64(1),
#  np.str_('1126.16'): np.int64(1),
#  np.str_('1126.45'): np.int64(1),
#  np.str_('1126.94'): np.int64(1),
#  np.str_('1127.12'): np.int64(1),
#  np.str_('1127.13'): np.int64(1),
#  np.str_('1127.69'): np.int64(2),
#  np.str_('1129.14'): np.int64(1),
#  np.str_('113.09'): np.int64(1),
#  np.str_('1131.34'): np.int64(1),
#  np.str_('11318.47'): np.int64(1),
#  np.str_('1133.15'): np.int64(1),
#  np.str_('1134.57'): np.int64(1),
#  np.str_('1134.69'): np.int64(1),
#  np.str_('1135.18'): np.int64(1),
#  np.str_('1135.42'): np.int64(1),
#  np.str_('11354.19'): np.int64(1),
#  np.str_('1136.06'): np.int64(1),
#  np.str_('1136.36'): np.int64(1),
#  np.str_('1137.06'): np.int64(1),
#  np.str_('1137.15'): np.int64(1),
#  np.str_('1138.72'): np.int64(1),
#  np.str_('1138.75'): np.int64(1),
#  np.str_('1139.23'): np.int64(1),
#  np.str_('1139.41'): np.int64(1),
#  np.str_('1139.65'): np.int64(1),
#  np.str_('1140.34'): np.int64(1),
#  np.str_('1140.77'): np.int64(1),
#  np.str_('1141.05'): np.int64(1),
#  np.str_('1141.48'): np.int64(1),
#  np.str_('1142.13'): np.int64(1),
#  np.str_('1142.64'): np.int64(3),
#  np.str_('1143.37'): np.int64(1),
#  np.str_('1143.49'): np.int64(1),
#  np.str_('1143.98'): np.int64(1),
#  np.str_('11431.41'): np.int64(1),
#  np.str_('11448.46'): np.int64(1),
#  np.str_('1145.04'): np.int64(1),
#  np.str_('1145.67'): np.int64(1),
#  np.str_('1145.87'): np.int64(1),
#  np.str_('1146.1'): np.int64(1),
#  np.str_('1147.01'): np.int64(1),
#  np.str_('1147.52'): np.int64(1),
#  np.str_('1147.91'): np.int64(1),
#  np.str_('11474.72'): np.int64(1),
#  np.str_('1148.13'): np.int64(1),
#  np.str_('1148.31'): np.int64(1),
#  np.str_('1148.99'): np.int64(1),
#  np.str_('11489.88'): np.int64(1),
#  np.str_('1149.7'): np.int64(1),
#  np.str_('115.68'): np.int64(1),
#  np.str_('1150.22'): np.int64(1),
#  np.str_('1150.67'): np.int64(1),
#  np.str_('1150.77'): np.int64(1),
#  np.str_('1151.24'): np.int64(1),
#  np.str_('1151.44'): np.int64(1),
#  np.str_('1151.52'): np.int64(1),
#  np.str_('1152.1'): np.int64(1),
#  np.str_('1153.1'): np.int64(1),
#  np.str_('1153.46'): np.int64(1),
#  np.str_('1154.24'): np.int64(1),
#  np.str_('1154.79'): np.int64(1),
#  np.str_('1154.82'): np.int64(2),
#  np.str_('1155.43'): np.int64(1),
#  np.str_('1156.39'): np.int64(1),
#  np.str_('11566.58'): np.int64(1),
#  np.str_('1157.27'): np.int64(1),
#  np.str_('1157.45'): np.int64(2),
#  np.str_('1157.94'): np.int64(1),
#  np.str_('11572.44'): np.int64(1),
#  np.str_('1158.48'): np.int64(1),
#  np.str_('1159.99'): np.int64(1),
#  np.str_('11599.36'): np.int64(1),
#  np.str_('1160.56'): np.int64(2),
#  np.str_('11604.6'): np.int64(1),
#  np.str_('1162.77'): np.int64(1),
#  np.str_('1163.04'): np.int64(1),
#  np.str_('1164.04'): np.int64(1),
#  np.str_('1164.82'): np.int64(1),
#  np.str_('11642.22'): np.int64(1),
#  np.str_('11644.84'): np.int64(1),
#  np.str_('1166.1'): np.int64(1),
#  np.str_('1166.5'): np.int64(1),
#  np.str_('1167.08'): np.int64(1),
#  np.str_('1167.45'): np.int64(2),
#  np.str_('1167.62'): np.int64(1),
#  np.str_('1167.84'): np.int64(1),
#  np.str_('1167.89'): np.int64(1),
#  np.str_('1169.0'): np.int64(1),
#  np.str_('1169.66'): np.int64(1),
#  np.str_('11691.35'): np.int64(1),
#  np.str_('117.0'): np.int64(1),
#  np.str_('117.27'): np.int64(1),
#  np.str_('117.65'): np.int64(1),
#  np.str_('117.67'): np.int64(1),
#  np.str_('1170.22'): np.int64(1),
#  np.str_('1171.43'): np.int64(1),
#  np.str_('1172.25'): np.int64(1),
#  np.str_('1172.74'): np.int64(1),
#  np.str_('11722.41'): np.int64(1),
#  np.str_('11734.21'): np.int64(1),
#  np.str_('11738.13'): np.int64(1),
#  np.str_('1174.05'): np.int64(1),
#  np.str_('1174.14'): np.int64(1),
#  np.str_('1174.24'): np.int64(1),
#  np.str_('1174.53'): np.int64(1),
#  np.str_('1175.49'): np.int64(1),
#  np.str_('1175.68'): np.int64(1),
#  np.str_('1176.24'): np.int64(2),
#  np.str_('1176.64'): np.int64(1),
#  np.str_('1177.48'): np.int64(1),
#  np.str_('11770.23'): np.int64(1),
#  np.str_('1178.21'): np.int64(1),
#  np.str_('1178.43'): np.int64(1),
#  np.str_('1178.51'): np.int64(1),
#  np.str_('1178.72'): np.int64(1),
#  np.str_('1178.85'): np.int64(1),
#  np.str_('1178.9'): np.int64(1),
#  np.str_('1179.72'): np.int64(1),
#  np.str_('1179.95'): np.int64(1),
#  np.str_('1179.98'): np.int64(2),
#  np.str_('118.07'): np.int64(1),
#  np.str_('1180.01'): np.int64(1),
#  np.str_('1180.34'): np.int64(1),
#  np.str_('1180.6'): np.int64(1),
#  np.str_('1180.96'): np.int64(1),
#  np.str_('1181.05'): np.int64(1),
#  np.str_('1181.15'): np.int64(1),
#  np.str_('1181.27'): np.int64(1),
#  np.str_('1181.35'): np.int64(1),
#  np.str_('1181.86'): np.int64(1),
#  np.str_('1181.92'): np.int64(1),
#  np.str_('1182.24'): np.int64(1),
#  np.str_('1183.04'): np.int64(2),
#  np.str_('1183.09'): np.int64(1),
#  np.str_('1183.66'): np.int64(1),
#  np.str_('1183.86'): np.int64(1),
#  np.str_('1183.9'): np.int64(1),
#  np.str_('1184.08'): np.int64(1),
#  np.str_('1184.74'): np.int64(1),
#  np.str_('1185.67'): np.int64(1),
#  np.str_('1187.31'): np.int64(1),
#  np.str_('1188.12'): np.int64(1),
#  np.str_('1188.5'): np.int64(1),
#  np.str_('1188.51'): np.int64(1),
#  np.str_('119.89'): np.int64(1),
#  np.str_('1190.07'): np.int64(1),
#  np.str_('1190.26'): np.int64(1),
#  np.str_('1190.5'): np.int64(1),
#  np.str_('1190.61'): np.int64(1),
#  np.str_('1190.77'): np.int64(1),
#  np.str_('11909.83'): np.int64(1),
#  np.str_('1191.54'): np.int64(1),
#  np.str_('1191.68'): np.int64(1),
#  np.str_('1192.2'): np.int64(1),
#  np.str_('1192.53'): np.int64(2),
#  np.str_('1193.86'): np.int64(1),
#  np.str_('11933.3'): np.int64(1),
#  np.str_('11939.78'): np.int64(1),
#  np.str_('1194.05'): np.int64(1),
#  np.str_('1194.57'): np.int64(1),
#  np.str_('11945.03'): np.int64(1),
#  np.str_('1195.78'): np.int64(1),
#  np.str_('1195.88'): np.int64(1),
#  np.str_('1196.25'): np.int64(1),
#  np.str_('1196.57'): np.int64(1),
#  np.str_('1196.6'): np.int64(1),
#  np.str_('1196.62'): np.int64(2),
#  np.str_('1196.75'): np.int64(1),
#  np.str_('1196.86'): np.int64(2),
#  np.str_('1197.04'): np.int64(1),
#  np.str_('1197.27'): np.int64(1),
#  np.str_('11972.74'): np.int64(1),
#  np.str_('1198.34'): np.int64(1),
#  np.str_('1198.69'): np.int64(2),
#  np.str_('11989.02'): np.int64(1),
#  np.str_('1199.22'): np.int64(1),
#  np.str_('1199.85'): np.int64(1),
#  np.str_('1200.82'): np.int64(1),
#  np.str_('1202.75'): np.int64(1),
#  np.str_('1203.39'): np.int64(2),
#  np.str_('1204.15'): np.int64(1),
#  np.str_('1204.45'): np.int64(1),
#  np.str_('1204.51'): np.int64(1),
#  np.str_('12044.51'): np.int64(1),
#  np.str_('1205.23'): np.int64(1),
#  np.str_('1205.39'): np.int64(1),
#  np.str_('1205.96'): np.int64(1),
#  np.str_('1206.4'): np.int64(1),
#  np.str_('12063.45'): np.int64(1),
#  np.str_('1207.44'): np.int64(2),
#  np.str_('1207.59'): np.int64(1),
#  np.str_('1207.64'): np.int64(1),
#  np.str_('12073.0'): np.int64(1),
#  np.str_('12073.26'): np.int64(1),
#  np.str_('1208.07'): np.int64(1),
#  np.str_('1208.57'): np.int64(1),
#  np.str_('1208.91'): np.int64(1),
#  np.str_('1209.49'): np.int64(1),
#  np.str_('1209.83'): np.int64(1),
#  np.str_('12097.93'): np.int64(1),
#  np.str_('1210.44'): np.int64(1),
#  np.str_('1210.67'): np.int64(1),
#  np.str_('1210.89'): np.int64(1),
#  np.str_('12100.51'): np.int64(1),
#  np.str_('1212.69'): np.int64(2),
#  np.str_('12124.95'): np.int64(1),
#  np.str_('1213.42'): np.int64(1),
#  np.str_('1213.92'): np.int64(1),
#  np.str_('1214.31'): np.int64(1),
#  np.str_('1214.33'): np.int64(1),
#  np.str_('1214.64'): np.int64(1),
#  np.str_('1214.91'): np.int64(1),
#  np.str_('1214.94'): np.int64(2),
#  np.str_('12141.38'): np.int64(1),
#  np.str_('1215.56'): np.int64(1),
#  np.str_('1215.7'): np.int64(1),
#  np.str_('1215.82'): np.int64(1),
#  np.str_('1215.86'): np.int64(1),
#  np.str_('1215.91'): np.int64(1),
#  np.str_('12156.06'): np.int64(1),
#  np.str_('1216.27'): np.int64(1),
#  np.str_('1216.35'): np.int64(1),
#  np.str_('1216.38'): np.int64(1),
#  np.str_('12163.61'): np.int64(1),
#  np.str_('1217.73'): np.int64(1),
#  np.str_('1218.06'): np.int64(1),
#  np.str_('1218.48'): np.int64(1),
#  np.str_('1219.22'): np.int64(1),
#  np.str_('1219.87'): np.int64(1),
#  np.str_('1219.89'): np.int64(1),
#  np.str_('1220.65'): np.int64(1),
#  np.str_('1220.91'): np.int64(1),
#  np.str_('1220.95'): np.int64(1),
#  np.str_('12207.12'): np.int64(1),
#  np.str_('12207.35'): np.int64(1),
#  np.str_('1222.38'): np.int64(1),
#  np.str_('1223.11'): np.int64(1),
#  np.str_('1223.24'): np.int64(1),
#  np.str_('1223.73'): np.int64(1),
#  np.str_('12232.9'): np.int64(1),
#  np.str_('12233.21'): np.int64(1),
#  np.str_('1224.5'): np.int64(1),
#  np.str_('1224.51'): np.int64(1),
#  np.str_('1225.43'): np.int64(1),
#  np.str_('1225.56'): np.int64(1),
#  np.str_('1225.58'): np.int64(1),
#  np.str_('1227.15'): np.int64(1),
#  np.str_('1227.56'): np.int64(1),
#  np.str_('1227.76'): np.int64(1),
#  np.str_('1227.82'): np.int64(1),
#  np.str_('1227.98'): np.int64(1),
#  np.str_('12277.94'): np.int64(1),
#  np.str_('1228.22'): np.int64(1),
#  np.str_('1228.66'): np.int64(1),
#  np.str_('12286.69'): np.int64(1),
#  np.str_('1229.28'): np.int64(1),
#  np.str_('1229.85'): np.int64(1),
#  np.str_('123.4'): np.int64(1),
#  np.str_('123.86'): np.int64(1),
#  np.str_('1230.08'): np.int64(2),
#  np.str_('1230.86'): np.int64(1),
#  np.str_('1232.05'): np.int64(1),
#  np.str_('1232.96'): np.int64(1),
#  np.str_('1233.13'): np.int64(1),
#  np.str_('1233.91'): np.int64(2),
#  np.str_('12335.94'): np.int64(1),
#  np.str_('1234.48'): np.int64(1),
#  np.str_('1235.0'): np.int64(1),
#  np.str_('1236.1'): np.int64(1),
#  np.str_('1236.56'): np.int64(1),
#  np.str_('1236.62'): np.int64(1),
#  np.str_('1236.67'): np.int64(1),
#  np.str_('1238.14'): np.int64(1),
#  np.str_('1238.27'): np.int64(1),
#  np.str_('1238.29'): np.int64(1),
#  np.str_('1239.33'): np.int64(1),
#  np.str_('12396.42'): np.int64(1),
#  np.str_('124.24'): np.int64(1),
#  np.str_('124.82'): np.int64(1),
#  np.str_('1240.27'): np.int64(1),
#  np.str_('1240.48'): np.int64(1),
#  np.str_('12402.63'): np.int64(1),
#  np.str_('1241.07'): np.int64(1),
#  np.str_('1242.23'): np.int64(1),
#  np.str_('1242.53'): np.int64(1),
#  np.str_('1242.67'): np.int64(4),
#  np.str_('1242.84'): np.int64(1),
#  np.str_('12427.91'): np.int64(1),
#  np.str_('1243.05'): np.int64(1),
#  np.str_('1243.11'): np.int64(1),
#  np.str_('1243.98'): np.int64(1),
#  np.str_('1244.34'): np.int64(1),
#  np.str_('1244.36'): np.int64(1),
#  np.str_('1244.39'): np.int64(1),
#  np.str_('1244.44'): np.int64(1),
#  np.str_('1244.79'): np.int64(1),
#  np.str_('1245.37'): np.int64(1),
#  np.str_('1246.26'): np.int64(1),
#  np.str_('1246.59'): np.int64(1),
#  np.str_('1247.06'): np.int64(1),
#  np.str_('1247.37'): np.int64(1),
#  np.str_('1247.43'): np.int64(1),
#  np.str_('1247.52'): np.int64(1),
#  np.str_('1247.71'): np.int64(2),
#  np.str_('1247.94'): np.int64(2),
#  np.str_('12470.94'): np.int64(1),
#  np.str_('12478.59'): np.int64(1),
#  np.str_('1248.33'): np.int64(1),
#  np.str_('1249.25'): np.int64(1),
#  np.str_('1249.53'): np.int64(1),
#  np.str_('1249.56'): np.int64(1),
#  np.str_('1249.84'): np.int64(1),
#  np.str_('1249.86'): np.int64(1),
#  np.str_('125.55'): np.int64(1),
#  np.str_('1250.95'): np.int64(1),
#  np.str_('1251.15'): np.int64(1),
#  np.str_('1252.26'): np.int64(3),
#  np.str_('1252.68'): np.int64(1),
#  np.str_('1252.78'): np.int64(1),
#  np.str_('1253.54'): np.int64(1),
#  np.str_('1253.92'): np.int64(1),
#  np.str_('1254.78'): np.int64(1),
#  np.str_('1255.55'): np.int64(1),
#  np.str_('1255.89'): np.int64(1),
#  np.str_('1256.74'): np.int64(1),
#  np.str_('12563.4'): np.int64(1),
#  np.str_('1257.89'): np.int64(1),
#  np.str_('1257.98'): np.int64(1),
#  np.str_('1258.63'): np.int64(1),
#  np.str_('12593.64'): np.int64(1),
#  np.str_('12594.01'): np.int64(1),
#  np.str_('12596.28'): np.int64(1),
#  np.str_('126.39'): np.int64(1),
#  np.str_('126.45'): np.int64(2),
#  np.str_('126.5'): np.int64(1),
#  np.str_('126.62'): np.int64(1),
#  np.str_('1260.11'): np.int64(1),
#  np.str_('1260.69'): np.int64(1),
#  np.str_('1260.72'): np.int64(1),
#  np.str_('12605.41'): np.int64(1),
#  np.str_('12605.96'): np.int64(1),
#  np.str_('12609.59'): np.int64(1),
#  np.str_('1261.14'): np.int64(1),
#  np.str_('1261.28'): np.int64(1),
#  np.str_('1261.86'): np.int64(1),
#  np.str_('12615.96'): np.int64(1),
#  np.str_('1262.4'): np.int64(1),
#  np.str_('1262.74'): np.int64(1),
#  np.str_('1262.98'): np.int64(1),
#  np.str_('1264.9'): np.int64(1),
#  np.str_('1264.92'): np.int64(1),
#  np.str_('1264.97'): np.int64(4),
#  np.str_('12641.01'): np.int64(1),
#  np.str_('1265.57'): np.int64(1),
#  np.str_('1265.7'): np.int64(1),
#  np.str_('1266.24'): np.int64(1),
#  np.str_('1266.63'): np.int64(1),
#  np.str_('12662.63'): np.int64(1),
#  np.str_('12663.33'): np.int64(1),
#  np.str_('1267.05'): np.int64(1),
#  np.str_('12678.84'): np.int64(2),
#  np.str_('1268.42'): np.int64(1),
#  np.str_('1268.8'): np.int64(1),
#  np.str_('12680.73'): np.int64(1),
#  np.str_('12688.74'): np.int64(1),
#  np.str_('1270.07'): np.int64(3),
#  np.str_('1270.31'): np.int64(1),
#  np.str_('1271.12'): np.int64(1),
#  np.str_('1271.19'): np.int64(1),
#  np.str_('1271.65'): np.int64(1),
#  np.str_('1272.61'): np.int64(1),
#  np.str_('1272.65'): np.int64(3),
#  np.str_('12720.01'): np.int64(1),
#  np.str_('1273.32'): np.int64(1),
#  np.str_('12739.11'): np.int64(1),
#  np.str_('1274.47'): np.int64(1),
#  np.str_('1275.01'): np.int64(1),
#  np.str_('1275.75'): np.int64(1),
#  np.str_('1276.31'): np.int64(1),
#  np.str_('1277.05'): np.int64(1),
#  np.str_('1277.38'): np.int64(1),
#  np.str_('1278.17'): np.int64(2),
#  np.str_('1279.4'): np.int64(1),
#  np.str_('128.98'): np.int64(1),
#  np.str_('12806.73'): np.int64(1),
#  np.str_('1281.0'): np.int64(1),
#  np.str_('1281.11'): np.int64(1),
#  np.str_('1281.62'): np.int64(3),
#  np.str_('12820.73'): np.int64(1),
#  np.str_('1283.6'): np.int64(1),
#  np.str_('12835.35'): np.int64(1),
#  np.str_('1284.56'): np.int64(1),
#  np.str_('1284.94'): np.int64(1),
#  np.str_('1284.96'): np.int64(1),
#  np.str_('1285.86'): np.int64(1),
#  np.str_('12857.9'): np.int64(1),
#  np.str_('1286.06'): np.int64(2),
#  np.str_('1286.31'): np.int64(1),
#  np.str_('1286.42'): np.int64(1),
#  np.str_('1286.75'): np.int64(1),
#  np.str_('1287.58'): np.int64(1),
#  np.str_('1287.78'): np.int64(1),
#  np.str_('1288.15'): np.int64(1),
#  np.str_('1288.25'): np.int64(1),
#  np.str_('1288.59'): np.int64(1),
#  np.str_('1288.95'): np.int64(1),
#  np.str_('1289.18'): np.int64(1),
#  np.str_('1289.38'): np.int64(2),
#  np.str_('1289.6'): np.int64(1),
#  np.str_('129.27'): np.int64(1),
#  np.str_('129.36'): np.int64(1),
#  np.str_('129.41'): np.int64(1),
#  np.str_('129.56'): np.int64(1),
#  np.str_('1290.72'): np.int64(1),
#  np.str_('1291.32'): np.int64(1),
#  np.str_('12912.59'): np.int64(1),
#  np.str_('1292.69'): np.int64(1),
#  np.str_('12923.66'): np.int64(1),
#  np.str_('1294.0'): np.int64(1),
#  np.str_('1294.09'): np.int64(1),
#  np.str_('1294.58'): np.int64(1),
#  np.str_('1294.77'): np.int64(1),
#  np.str_('12945.06'): np.int64(1),
#  np.str_('1295.22'): np.int64(1),
#  np.str_('1295.53'): np.int64(1),
#  np.str_('12957.68'): np.int64(1),
#  np.str_('1296.02'): np.int64(1),
#  np.str_('1296.12'): np.int64(1),
#  np.str_('1296.92'): np.int64(1),
#  np.str_('1297.06'): np.int64(1),
#  np.str_('1297.15'): np.int64(2),
#  np.str_('1298.17'): np.int64(1),
#  np.str_('1299.19'): np.int64(1),
#  np.str_('12995.78'): np.int64(1),
#  np.str_('1300.11'): np.int64(1),
#  np.str_('13001.46'): np.int64(1),
#  np.str_('1301.26'): np.int64(1),
#  np.str_('1301.71'): np.int64(1),
#  np.str_('1302.31'): np.int64(1),
#  np.str_('1303.14'): np.int64(1),
#  np.str_('1303.25'): np.int64(1),
#  np.str_('1303.3'): np.int64(1),
#  np.str_('1303.89'): np.int64(1),
#  np.str_('13033.59'): np.int64(1),
#  np.str_('13034.35'): np.int64(1),
#  np.str_('1304.26'): np.int64(1),
#  np.str_('1304.37'): np.int64(1),
#  np.str_('1304.52'): np.int64(1),
#  np.str_('13041.12'): np.int64(1),
#  np.str_('13048.16'): np.int64(1),
#  np.str_('1306.11'): np.int64(1),
#  np.str_('1306.31'): np.int64(1),
#  np.str_('1306.83'): np.int64(1),
#  np.str_('1306.92'): np.int64(1),
#  np.str_('1307.46'): np.int64(1),
#  np.str_('1307.67'): np.int64(1),
#  np.str_('1308.51'): np.int64(1),
#  np.str_('1308.78'): np.int64(2),
#  np.str_('1309.05'): np.int64(1),
#  np.str_('1309.4'): np.int64(1),
#  np.str_('131.76'): np.int64(1),
#  np.str_('1310.08'): np.int64(1),
#  np.str_('1310.69'): np.int64(1),
#  np.str_('1311.07'): np.int64(1),
#  np.str_('1311.41'): np.int64(1),
#  np.str_('1311.57'): np.int64(1),
#  np.str_('1312.36'): np.int64(1),
#  np.str_('1312.81'): np.int64(1),
#  np.str_('1313.23'): np.int64(1),
#  np.str_('1313.55'): np.int64(1),
#  np.str_('1313.6'): np.int64(1),
#  np.str_('1313.92'): np.int64(1),
#  np.str_('1314.07'): np.int64(1),
#  np.str_('1315.5'): np.int64(1),
#  np.str_('1315.63'): np.int64(1),
#  np.str_('1316.15'): np.int64(1),
#  np.str_('1316.46'): np.int64(1),
#  np.str_('1316.48'): np.int64(1),
#  np.str_('13160.85'): np.int64(1),
#  np.str_('13168.24'): np.int64(1),
#  np.str_('1317.04'): np.int64(1),
#  np.str_('1317.14'): np.int64(1),
#  np.str_('13183.54'): np.int64(1),
#  np.str_('13187.62'): np.int64(1),
#  np.str_('13188.68'): np.int64(1),
#  np.str_('1319.06'): np.int64(1),
#  np.str_('1319.75'): np.int64(1),
#  np.str_('1319.77'): np.int64(1),
#  np.str_('132.77'): np.int64(1),
#  np.str_('1320.24'): np.int64(1),
#  np.str_('1320.46'): np.int64(2),
#  np.str_('1320.64'): np.int64(1),
#  np.str_('13215.03'): np.int64(1),
#  np.str_('1322.68'): np.int64(1),
#  np.str_('1322.87'): np.int64(1),
#  np.str_('13228.75'): np.int64(1),
#  np.str_('1323.23'): np.int64(1),
#  np.str_('1323.96'): np.int64(1),
#  np.str_('1325.06'): np.int64(1),
#  np.str_('1325.67'): np.int64(1),
#  np.str_('1325.83'): np.int64(1),
#  np.str_('1325.89'): np.int64(1),
#  np.str_('1325.96'): np.int64(1),
#  np.str_('1326.69'): np.int64(1),
#  np.str_('1326.94'): np.int64(1),
#  np.str_('1327.29'): np.int64(5),
#  np.str_('1327.33'): np.int64(2),
#  np.str_('1327.39'): np.int64(1),
#  np.str_('1327.5'): np.int64(1),
#  np.str_('1327.55'): np.int64(1),
#  np.str_('1327.59'): np.int64(1),
#  np.str_('1328.69'): np.int64(2),
#  np.str_('1329.01'): np.int64(1),
#  np.str_('1329.25'): np.int64(1),
#  np.str_('1329.83'): np.int64(2),
#  np.str_('13298.44'): np.int64(1),
#  np.str_('133.04'): np.int64(2),
#  np.str_('1330.52'): np.int64(1),
#  np.str_('1331.66'): np.int64(1),
#  np.str_('1332.85'): np.int64(1),
#  np.str_('1333.09'): np.int64(1),
#  np.str_('1333.1'): np.int64(1),
#  np.str_('1333.17'): np.int64(1),
#  np.str_('1333.95'): np.int64(1),
#  np.str_('13333.53'): np.int64(1),
#  np.str_('13336.65'): np.int64(1),
#  np.str_('1334.06'): np.int64(1),
#  np.str_('1334.75'): np.int64(2),
#  np.str_('1335.31'): np.int64(2),
#  np.str_('1335.39'): np.int64(2),
#  np.str_('1335.83'): np.int64(1),
#  np.str_('1335.84'): np.int64(1),
#  np.str_('1336.32'): np.int64(1),
#  np.str_('1336.69'): np.int64(1),
#  np.str_('1337.94'): np.int64(1),
#  np.str_('1338.78'): np.int64(1),
#  np.str_('1339.35'): np.int64(2),
#  np.str_('1339.51'): np.int64(1),
#  np.str_('1339.61'): np.int64(1),
#  np.str_('134.81'): np.int64(1),
#  np.str_('134.84'): np.int64(1),
#  np.str_('1340.33'): np.int64(1),
#  np.str_('1340.88'): np.int64(1),
#  np.str_('1341.1'): np.int64(2),
#  np.str_('1341.57'): np.int64(1),
#  np.str_('1341.6'): np.int64(1),
#  np.str_('1341.61'): np.int64(1),
#  np.str_('1342.3'): np.int64(2),
#  np.str_('1342.32'): np.int64(1),
#  np.str_('1342.93'): np.int64(1),
#  np.str_('1342.94'): np.int64(1),
#  np.str_('1343.06'): np.int64(1),
#  np.str_('1343.16'): np.int64(1),
#  np.str_('13433.43'): np.int64(1),
#  np.str_('13435.46'): np.int64(1),
#  np.str_('1344.92'): np.int64(1),
#  np.str_('1345.73'): np.int64(4),
#  np.str_('1345.74'): np.int64(1),
#  np.str_('1346.75'): np.int64(1),
#  np.str_('1347.22'): np.int64(2),
#  np.str_('1347.24'): np.int64(3),
#  np.str_('1347.39'): np.int64(1),
#  np.str_('1348.23'): np.int64(2),
#  np.str_('1348.93'): np.int64(1),
#  np.str_('1349.88'): np.int64(1),
#  np.str_('135.33'): np.int64(1),
#  np.str_('1350.14'): np.int64(1),
#  np.str_('1350.46'): np.int64(2),
#  np.str_('1350.76'): np.int64(2),
#  np.str_('1350.93'): np.int64(1),
#  np.str_('13507.76'): np.int64(1),
#  np.str_('1351.38'): np.int64(1),
#  np.str_('1351.73'): np.int64(1),
#  np.str_('1351.94'): np.int64(1),
#  np.str_('13529.51'): np.int64(1),
#  np.str_('13534.87'): np.int64(1),
#  np.str_('1354.32'): np.int64(1),
#  np.str_('1354.85'): np.int64(1),
#  np.str_('13549.89'): np.int64(1),
#  np.str_('1356.86'): np.int64(1),
#  np.str_('1357.58'): np.int64(1),
#  np.str_('1357.62'): np.int64(2),
#  np.str_('1357.67'): np.int64(1),
#  np.str_('1357.69'): np.int64(1),
#  np.str_('1357.94'): np.int64(1),
#  np.str_('1359.15'): np.int64(2),
#  np.str_('1359.19'): np.int64(2),
#  np.str_('1359.61'): np.int64(1),
#  np.str_('1359.7'): np.int64(1),
#  np.str_('1359.97'): np.int64(1),
#  np.str_('136.28'): np.int64(1),
#  np.str_('136.37'): np.int64(1),
#  np.str_('13609.16'): np.int64(1),
#  np.str_('1361.35'): np.int64(1),
#  np.str_('1361.9'): np.int64(1),
#  np.str_('1362.95'): np.int64(1),
#  np.str_('1363.8'): np.int64(1),
#  np.str_('1364.3'): np.int64(1),
#  np.str_('1365.67'): np.int64(1),
#  np.str_('1365.71'): np.int64(1),
#  np.str_('1366.15'): np.int64(1),
#  np.str_('1366.29'): np.int64(1),
#  np.str_('1366.41'): np.int64(1),
#  np.str_('1366.65'): np.int64(1),
#  np.str_('1367.73'): np.int64(1),
#  np.str_('1368.33'): np.int64(1),
#  np.str_('1368.44'): np.int64(1),
#  np.str_('1368.71'): np.int64(2),
#  np.str_('1369.07'): np.int64(1),
#  np.str_('1369.08'): np.int64(1),
#  np.str_('1369.84'): np.int64(1),
#  np.str_('1370.82'): np.int64(1),
#  np.str_('1371.21'): np.int64(1),
#  np.str_('1371.66'): np.int64(1),
#  np.str_('1371.68'): np.int64(1),
#  np.str_('1372.3'): np.int64(1),
#  np.str_('1372.48'): np.int64(1),
#  np.str_('1372.69'): np.int64(1),
#  np.str_('1373.29'): np.int64(2),
#  np.str_('1373.45'): np.int64(1),
#  np.str_('1373.83'): np.int64(1),
#  np.str_('1375.57'): np.int64(1),
#  np.str_('1376.33'): np.int64(1),
#  np.str_('1376.54'): np.int64(1),
#  np.str_('1377.48'): np.int64(1),
#  np.str_('1378.87'): np.int64(1),
#  np.str_('13791.04'): np.int64(1),
#  np.str_('13795.49'): np.int64(1),
#  np.str_('1380.27'): np.int64(2),
#  np.str_('1381.26'): np.int64(2),
#  np.str_('1381.62'): np.int64(1),
#  np.str_('1381.81'): np.int64(2),
#  np.str_('1381.94'): np.int64(1),
#  np.str_('1382.75'): np.int64(1),
#  np.str_('1383.38'): np.int64(1),
#  np.str_('1384.09'): np.int64(1),
#  np.str_('1384.12'): np.int64(1),
#  np.str_('1384.14'): np.int64(1),
#  np.str_('1384.85'): np.int64(1),
#  np.str_('1385.45'): np.int64(1),
#  np.str_('1385.97'): np.int64(2),
#  np.str_('1386.47'): np.int64(2),
#  np.str_('1388.02'): np.int64(1),
#  np.str_('1388.07'): np.int64(2),
#  np.str_('1388.72'): np.int64(1),
#  ...}

# %% [markdown]
# Los registros contenidos en esta categoría corresponden al pago efectuado por los clientes en el momento en el cual se realizó la recopilación de los datos.
#
# Del análisis de los datos contenidos en la categoría 'total_pymnt' se observa lo siguiente:
#
# - Los registros proporcionados describen el pago efectuado por los clientes.
# - Los valores almacenados corresponden a categorías cuantitativas y, por tanto, pueden ser representados mediante valores de punto flotante.
# - Se detectan 500 registros en los que la categoría no está definida de manera adecuada, encontrándose representado mediante una cadena vacía ('').
# - No se identificaron categorías redundantes, formatos inconsistentes ni etiquetas atípicas en comparación con el resto de los registros, lo que evidencia una adecuada uniformidad en la representación de los datos.
#
# Recomendaciones:
#
# - Reemplazar las cadenas vacías ('') por el valor np.nan, con el fin de normalizar la representación de datos faltantes y facilitar su identificación, tratamiento y análisis posterior.

# %% [markdown]
# ## Casteo de datos

# %%
raw_data_copy = raw_data_np.copy()
casted_data_np = np.empty_like(raw_data_copy[:,1:], dtype=object)

for i in range(raw_data_np.shape[0]):
    for j in range(1, raw_data_np.shape[1]):
        try:
            if raw_data_copy[i, 0] != 'id':
                casted_data_np[i, j-1] = float(raw_data_copy[i, j])
            else:
                casted_data_np[i, j-1] = raw_data_copy[i, j]
        except ValueError:
            casted_data_np[i, j-1] = raw_data_copy[i, j]
casted_data_np
# Out:
# array([[np.str_('48010226'), np.str_('57693261'), np.str_('59432726'), ..., np.str_('50415990'),
#         np.str_('46154151'), np.str_('66055249')],
#        [np.str_('May-15'), np.str_(''), np.str_('Sep-15'), ..., np.str_('Jun-15'),
#         np.str_('Apr-15'), np.str_('Dec-15')],
#        [35000.0, 30000.0, 15000.0, ..., 10000.0, np.str_(''), 10000.0],
#        ...,
#        [np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726'), ...,
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249')],
#        [np.str_('CA'), np.str_('NY'), np.str_('PA'), ..., np.str_('CA'), np.str_('OH'),
#         np.str_('IL')],
#        [9452.96, 4679.7, 1969.83, ..., 2185.64, 3199.4, 301.9]], shape=(14, 10000), dtype=object)

# %% [markdown]
# ## Definición y Corrección de la Estructura de Datos

# %% [markdown]
# ### Estructuración del diccionario de categorías

# %%
data_dict = {}
for i in range(len(raw_data_np[:,0])):
    data_dict[raw_data_np[i,0]] = casted_data_np[i]
data_dict
# Out:
# {np.str_('id'): array([np.str_('48010226'), np.str_('57693261'), np.str_('59432726'), ..., np.str_('50415990'),
#         np.str_('46154151'), np.str_('66055249')], shape=(10000,), dtype=object),
#  np.str_('issue_d'): array([np.str_('May-15'), np.str_(''), np.str_('Sep-15'), ..., np.str_('Jun-15'),
#         np.str_('Apr-15'), np.str_('Dec-15')], shape=(10000,), dtype=object),
#  np.str_('loan_amnt'): array([35000.0, 30000.0, 15000.0, ..., 10000.0, np.str_(''), 10000.0], shape=(10000,), dtype=object),
#  np.str_('loan_status'): array([np.str_('Current'), np.str_('Current'), np.str_('Current'), ..., np.str_('Current'),
#         np.str_('Current'), np.str_('Current')], shape=(10000,), dtype=object),
#  np.str_('funded_amnt'): array([35000.0, 30000.0, 15000.0, ..., 10000.0, 10000.0, 10000.0], shape=(10000,), dtype=object),
#  np.str_('term'): array([np.str_(' 36 months'), np.str_(' 36 months'), np.str_(' 36 months'), ...,
#         np.str_(' 36 months'), np.str_(' 36 months'), np.str_(' 36 months')],
#        shape=(10000,), dtype=object),
#  np.str_('int_rate'): array([13.33, np.str_('þëè.89'), np.str_('íîå.53'), ..., np.str_('þëè.89'), 16.55,
#         np.str_('þëè.26')], shape=(10000,), dtype=object),
#  np.str_('installment'): array([1184.86, 938.57, 494.86, ..., np.str_(''), 354.3, 309.97], shape=(10000,), dtype=object),
#  np.str_('grade'): array([np.str_('C'), np.str_('A'), np.str_('B'), ..., np.str_('A'), np.str_('D'), np.str_('A')],
#        shape=(10000,), dtype=object),
#  np.str_('sub_grade'): array([np.str_('C3'), np.str_('A5'), np.str_('B5'), ..., np.str_('A5'), np.str_('D2'),
#         np.str_('A4')], shape=(10000,), dtype=object),
#  np.str_('verification_status'): array([np.str_('Verified'), np.str_('Source Verified'), np.str_('Verified'), ...,
#         np.str_('Source Verified'), np.str_('Source Verified'), np.str_('')],
#        shape=(10000,), dtype=object),
#  np.str_('url'): array([np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726'), ...,
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151'),
#         np.str_('https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249')],
#        shape=(10000,), dtype=object),
#  np.str_('addr_state'): array([np.str_('CA'), np.str_('NY'), np.str_('PA'), ..., np.str_('CA'), np.str_('OH'),
#         np.str_('IL')], shape=(10000,), dtype=object),
#  np.str_('total_pymnt'): array([9452.96, 4679.7, 1969.83, ..., 2185.64, 3199.4, 301.9], shape=(10000,), dtype=object)}

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'issue_d'

# %%
data_dict['issue_d'] = np.where(
    data_dict['issue_d'] == '',
    np.nan,
    data_dict['issue_d']
)
registros_faltantes = np.sum(pd.isna(data_dict['issue_d']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['issue_d'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'issue_d', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'loan_amnt'

# %%
data_dict['loan_amnt'] = np.where(
    data_dict['loan_amnt'] == '',
    np.nan,
    data_dict['loan_amnt']
)
registros_faltantes = np.sum(pd.isna(data_dict['loan_amnt']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['loan_amnt'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'loan_amnt', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'loan_status'

# %%
data_dict['loan_status'] = np.where(
    data_dict['loan_status'] == '',
    np.nan,
    data_dict['loan_status']
)
registros_faltantes = np.sum(pd.isna(data_dict['loan_status']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['loan_status'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'loan_status', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'funded_amnt'

# %%
data_dict['funded_amnt'] = np.where(
    data_dict['funded_amnt'] == '',
    np.nan,
    data_dict['funded_amnt']
)
registros_faltantes = np.sum(pd.isna(data_dict['funded_amnt']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['funded_amnt'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'funded_amnt', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'term'

# %%
for i in range(len(data_dict['term'])):
    if data_dict['term'][i] != "":
        data_dict['term'][i] = int((data_dict['term'][i].split()[0]))
    else:
        data_dict['term'][i] = np.nan
type(data_dict['term'])
# Out:
# numpy.ndarray

# %%
registros_faltantes = np.sum(pd.isna(data_dict['term']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['term'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevaron a cabo dos procesos de transformación sobre los datos contenidos en esta categoría:
#
# - Los registros válidos fueron convertidos a valores enteros, ya que representan la cantidad de meses correspondiente al plazo del préstamo otorgado.
# - Los registros vacíos fueron reemplazados por valores np.nan con el fin de identificar explícitamente los datos faltantes.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado evidencia un alto nivel de completitud en la información asociada a esta variable. No obstante, la presencia de datos faltantes deberá ser considerada en las etapas posteriores de preprocesamiento y análisis para garantizar la validez de los resultados obtenidos.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'int_rate'

# %%
data_dict['int_rate'] = np.where(
    np.isin(data_dict['int_rate'], valores_invalidos_rate),
    np.nan,
    data_dict['int_rate']
)
registros_faltantes = np.sum(pd.isna(data_dict['int_rate']))
print(registros_faltantes)
# Out:
# 6004

# %%
total_registros = np.size(data_dict['int_rate'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 60.040000000000006

# %% [markdown]
# Se llevó a cabo un proceso de depuración de los datos registrados en esta categoría, encontrándose que el 60.04 % de los registros presentaban un formato inadecuado. Este resultado evidencia una baja calidad de los datos asociados a la variable, lo que dificulta la aplicación de procedimientos de corrección sin introducir un sesgo significativo en los resultados o comprometer la representatividad de la información original.
#
# En consecuencia, se determinó que los datos contenidos en esta columna no poseen la confiabilidad necesaria para ser considerados en etapas posteriores del análisis. Por ello, la variable fue descartada del estudio, imposibilitando la evaluación de aspectos como la influencia de la tasa de interés sobre la capacidad o voluntad de pago de los clientes de la institución financiera.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'installment'

# %%
data_dict['installment'] = np.where(
    data_dict['installment'] == '',
    np.nan,
    data_dict['installment']
)
registros_faltantes = np.sum(pd.isna(data_dict['installment']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['int_rate'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'installment', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'grade'

# %%
data_dict['grade'] = np.where(
    data_dict['grade'] == '',
    np.nan,
    data_dict['grade']
)
registros_faltantes = np.sum(pd.isna(data_dict['grade']))
print(registros_faltantes)
# Out:
# 515

# %%
total_registros = np.size(data_dict['grade'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.1499999999999995

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'installment', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5.15 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'sub_grade'

# %%
data_dict['sub_grade'] = np.where(
    data_dict['sub_grade'] == '',
    np.nan,
    data_dict['sub_grade']
)
registros_faltantes = np.sum(pd.isna(data_dict['sub_grade']))
print(registros_faltantes)
# Out:
# 514

# %%
total_registros = np.size(data_dict['sub_grade'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.140000000000001

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'installment', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5.14 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'verification_status'

# %%
data_dict['verification_status'] = np.where(
    data_dict['verification_status'] == '',
    np.nan,
    data_dict['verification_status']
)
registros_faltantes = np.sum(pd.isna(data_dict['verification_status']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['verification_status'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'verification_status', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5.00 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'addr_state'

# %%
data_dict['addr_state'] = np.where(
    data_dict['addr_state'] == '',
    np.nan,
    data_dict['addr_state']
)
registros_faltantes = np.sum(pd.isna(data_dict['addr_state']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['addr_state'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'verification_status', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5.00 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ### Corrección de los elementos integrados a la categoría 'total_pymnt'

# %%
data_dict['total_pymnt'] = np.where(
    data_dict['total_pymnt'] == '',
    np.nan,
    data_dict['total_pymnt']
)
registros_faltantes = np.sum(pd.isna(data_dict['total_pymnt']))
print(registros_faltantes)
# Out:
# 500

# %%
total_registros = np.size(data_dict['total_pymnt'])
pct_b = registros_faltantes/total_registros*100
print(pct_b)
# Out:
# 5.0

# %% [markdown]
# Se llevó a cabo la corrección de los registros contenidos en la categoría 'verification_status', reemplazando las etiquetas vacías ('') por el valor np.nan, con el propósito de estandarizar la representación de datos faltantes dentro de la estructura de datos.
#
# Posteriormente, se calculó la proporción de valores faltantes respecto al total de registros disponibles, obteniéndose un porcentaje del 5.00 %. Este resultado indica que la completitud de la información asociada a esta variable es elevada, aunque la presencia de datos faltantes deberá considerarse durante las etapas posteriores de análisis y preprocesamiento.

# %% [markdown]
# ## Splitting the Dataset

# %% [markdown]
# ### Splitting the Columns

# %% [markdown]
# ### Re-importing the Dataset

# %% [markdown]
# ### The Names of the Columns

# %% [markdown]
# ## Creating Checkpoints:

# %%
def checkpoint(file_name, checkpoint_header, checkpoint_data):
    np.savez(file_name, header = checkpoint_header, data = checkpoint_data)
    checkpoint_variable = np.load(file_name + ".npz")
    return(checkpoint_variable)

# %% [markdown]
# ## Manipulating String Columns

# %% [markdown]
# ### Issue Date

# %%
months = np.array(['', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
for i in range(13):
        loan_data_strings[:,0] = np.where(loan_data_strings[:,0] == months[i],
                                          i,
                                          loan_data_strings[:,0])

# %% [markdown]
# ### Loan Status

# %% [markdown]
# ### Term

# %% [markdown]
# ### Grade and Subgrade

# %% [markdown]
# #### Filling Sub Grade

# %%
for i in np.unique(loan_data_strings[:,3])[1:]:
    loan_data_strings[:,4] = np.where((loan_data_strings[:,4] == '') & (loan_data_strings[:,3] == i),
                                      i + '5',
                                      loan_data_strings[:,4])

# %% [markdown]
# #### Removing Grade

# %% [markdown]
# #### Converting Sub Grade

# %%
keys = list(np.unique(loan_data_strings[:,3]))                         
values = list(range(1, np.unique(loan_data_strings[:,3]).shape[0] + 1)) 
dict_sub_grade = dict(zip(keys, values))

# %%
for i in np.unique(loan_data_strings[:,3]):
        loan_data_strings[:,3] = np.where(loan_data_strings[:,3] == i, 
                                          dict_sub_grade[i],
                                          loan_data_strings[:,3])

# %% [markdown]
# ### Verification Status

# %% [markdown]
# ### URL

# %% [markdown]
# ### State Address

# %%
states_west = np.array(['WA', 'OR','CA','NV','ID','MT', 'WY','UT','CO', 'AZ','NM','HI','AK'])
states_south = np.array(['TX','OK','AR','LA','MS','AL','TN','KY','FL','GA','SC','NC','VA','WV','MD','DE','DC'])
states_midwest = np.array(['ND','SD','NE','KS','MN','IA','MO','WI','IL','IN','MI','OH'])
states_east = np.array(['PA','NY','NJ','CT','MA','VT','NH','ME','RI'])

# %% [markdown]
# https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf

# %% [markdown]
# ## Converting to Numbers

# %% [markdown]
# ### Checkpoint 1: Strings

# %% [markdown]
# ## Manipulating Numeric Columns

# %% [markdown]
# ### Substitute "Filler" Values

# %% [markdown]
# #### ID

# %% [markdown]
# #### Temporary Stats

# %% [markdown]
# #### Funded Amount

# %%
loan_data_numeric[:,2] = np.where(loan_data_numeric[:,2] == temporary_fill, 
                                  temporary_stats[0, columns_numeric[2]],
                                  loan_data_numeric[:,2])
loan_data_numeric[:,2]

# %% [markdown]
# #### Loaned Amount, Interest Rate, Total Payment, Installment

# %% [markdown]
# ### Currency Change

# %% [markdown]
# #### The Exchange Rate

# %%
for i in range(1,13):
    exchange_rate = np.where(exchange_rate == i,
                             EUR_USD[i-1],
                             exchange_rate)

# %% [markdown]
# #### From USD to EUR

# %%
for i in columns_dollar:
    loan_data_numeric = np.hstack((loan_data_numeric, np.reshape(loan_data_numeric[:,i] / loan_data_numeric[:,6], (10000,1))))

# %% [markdown]
# #### Expanding the header

# %%
header_additional = np.array([column_name + '_EUR' for column_name in header_numeric[columns_dollar]])

# %%
columns_index_order = [0,1,7,2,8,3,4,9,5,10,6]

# %% [markdown]
# ### Interest Rate

# %% [markdown]
# ### Checkpoint 2: Numeric

# %%
checkpoint_numeric['header'], checkpoint_numeric['data']

# %% [markdown]
# ## Creating the "Complete" Dataset

# %% [markdown]
# ## Sorting the New Dataset

# %% [markdown]
# ## Storing the New Dataset
